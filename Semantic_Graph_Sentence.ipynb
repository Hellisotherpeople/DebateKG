# %% [markdown]
# # Introducing the Semantic Graph
#
# _This notebook is part of a tutorial series on [txtai](https://github.com/neuml/txtai), an AI-powered semantic search platform._
#
# [txtai](https://github.com/neuml/txtai) executes machine-learning workflows to transform data and build AI-powered semantic search applications.
#
# One of the main use cases of txtai is semantic search over a corpus of data. Semantic search provides an understanding of natural language and identifies results that have the same meaning, not necessarily the same keywords. Within an Embeddings instance sits a wealth of implied knowledge and relationships between rows. Many approximate nearest neighbor (ANN) indexes are even backed by graphs. What if we are able to tap into this knowledge?
#
# Semantic graphs, also known as knowledge graphs or semantic networks, build a graph network with semantic relationships connecting the nodes. In txtai, they can take advantage of the relationships inherently learned within an embeddings index. This opens exciting possibilities for exploring relationships, such as topics and interconnections in a dataset.
#
# This notebook introduces the semantic graph.

# %% [markdown]
# # Install dependencies
#
# Install `txtai` and all dependencies. We'll install the graph extra for graph functionality, pipeline extra for object detection and similarity extra to load models with the sentence-transformers library.

# %%
# !pip install git+https://github.com/neuml/txtai#egg=txtai[graph,pipeline,similarity] datasets ipyplot
# Out:
# Collecting txtai[graph,pipeline,similarity]
#   Cloning https://github.com/neuml/txtai to /tmp/pip-install-12lemrdy/txtai_419666a06514460eaeba4e2ca245f629
#   Running command git clone --filter=blob:none --quiet https://github.com/neuml/txtai /tmp/pip-install-12lemrdy/txtai_419666a06514460eaeba4e2ca245f629
#   Resolved https://github.com/neuml/txtai to commit 3e8d63be86a0dbc111ce81e6bc99fc1c460029e1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting datasets
#   Using cached datasets-2.6.1-py3-none-any.whl (441 kB)
# Collecting ipyplot
#   Using cached ipyplot-1.1.1-py3-none-any.whl (13 kB)
# Collecting torch>=1.6.0
#   Downloading torch-1.13.0-cp39-cp39-manylinux1_x86_64.whl (890.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.2/890.2 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pyyaml>=5.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (6.0)
# Collecting transformers>=4.22.0
#   Using cached transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Collecting faiss-cpu>=1.7.1.post2
#   Downloading faiss_cpu-1.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 87.8 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.18.4 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (1.21.5)
# Requirement already satisfied: nltk>=3.5 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (3.7)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (4.11.1)
# Collecting onnxmltools>=1.9.1
#   Using cached onnxmltools-1.11.1-py3-none-any.whl (308 kB)
# Collecting onnx>=1.10.1
#   Downloading onnx-1.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 89.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting imagehash>=4.2.1
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Collecting sentencepiece>=0.1.91
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.2 MB/s eta 0:00:00
# Collecting onnxruntime>=1.8.1
#   Downloading onnxruntime-1.13.1-cp39-cp39-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 86.2 MB/s eta 0:00:000m eta 0:00:01
# Requirement already satisfied: pandas>=1.1.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (1.4.2)
# Collecting soundfile>=0.10.3.post1
#   Using cached soundfile-0.11.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pillow>=7.1.2 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (9.0.1)
# Collecting fasttext>=0.9.2
#   Using cached fasttext-0.9.2.tar.gz (68 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm>=0.4.12
#   Downloading timm-0.6.11-py3-none-any.whl (548 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 55.5 MB/s eta 0:00:00
# Collecting tika>=1.24
#   Using cached tika-1.24.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-louvain>=0.16
#   Using cached python-louvain-0.16.tar.gz (204 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.6.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (2.7.1)
# Requirement already satisfied: scikit-learn>=0.23.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from txtai[graph,pipeline,similarity]) (1.0.2)
# Collecting hnswlib>=0.5.0
#   Using cached hnswlib-0.6.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pymagnitude-lite>=0.1.43
#   Using cached pymagnitude_lite-0.1.143-py3-none-any.whl (34 kB)
# Collecting annoy>=1.16.3
#   Using cached annoy-1.17.1.tar.gz (647 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=2.2.0
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.19.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from datasets) (2.27.1)
# Requirement already satisfied: aiohttp in /home/opc/anaconda3/lib/python3.9/site-packages (from datasets) (3.8.1)
# Collecting pyarrow>=6.0.0
#   Downloading pyarrow-10.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 51.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: tqdm>=4.62.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from datasets) (4.64.0)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 37.2 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 26.5 MB/s eta 0:00:00
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from datasets) (2022.2.0)
# Collecting dill<0.3.6
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Using cached huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: packaging in /home/opc/anaconda3/lib/python3.9/site-packages (from datasets) (21.3)
# Collecting shortuuid
#   Using cached shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: IPython in /home/opc/anaconda3/lib/python3.9/site-packages (from ipyplot) (8.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/opc/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.9.3->txtai[graph,pipeline,similarity]) (2.3.1)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from fasttext>=0.9.2->txtai[graph,pipeline,similarity]) (61.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /home/opc/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.6.0)
# Requirement already satisfied: PyWavelets in /home/opc/anaconda3/lib/python3.9/site-packages (from imagehash>=4.2.1->txtai[graph,pipeline,similarity]) (1.3.0)
# Requirement already satisfied: scipy in /home/opc/anaconda3/lib/python3.9/site-packages (from imagehash>=4.2.1->txtai[graph,pipeline,similarity]) (1.7.3)
# Requirement already satisfied: click in /home/opc/anaconda3/lib/python3.9/site-packages (from nltk>=3.5->txtai[graph,pipeline,similarity]) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from nltk>=3.5->txtai[graph,pipeline,similarity]) (2022.3.15)
# Requirement already satisfied: joblib in /home/opc/anaconda3/lib/python3.9/site-packages (from nltk>=3.5->txtai[graph,pipeline,similarity]) (1.1.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /home/opc/anaconda3/lib/python3.9/site-packages (from onnx>=1.10.1->txtai[graph,pipeline,similarity]) (3.19.1)
# Collecting skl2onnx
#   Using cached skl2onnx-1.13-py2.py3-none-any.whl (288 kB)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting flatbuffers
#   Using cached flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Collecting numpy>=1.18.4
#   Using cached numpy-1.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Requirement already satisfied: sympy in /home/opc/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.8.1->txtai[graph,pipeline,similarity]) (1.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/opc/anaconda3/lib/python3.9/site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->txtai[graph,pipeline,similarity]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->txtai[graph,pipeline,similarity]) (2021.3)
# Collecting lz4>=1.0.0
#   Downloading lz4-4.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 86.0 MB/s eta 0:00:00
# Collecting fasteners>=0.14.1
#   Using cached fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/opc/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/opc/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.23.1->txtai[graph,pipeline,similarity]) (2.2.0)
# Collecting torchvision
#   Downloading torchvision-0.14.0-cp39-cp39-manylinux1_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 63.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: cffi>=1.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.3.post1->txtai[graph,pipeline,similarity]) (1.15.0)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 6.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 66.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 81.3 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /home/opc/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->txtai[graph,pipeline,similarity]) (0.37.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 88.4 MB/s eta 0:00:000m eta 0:00:010:01
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (5.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.6.3)
# Requirement already satisfied: backcall in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (2.11.2)
# Requirement already satisfied: stack-data in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: decorator in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: pickleshare in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/opc/anaconda3/lib/python3.9/site-packages (from IPython->ipyplot) (0.18.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /home/opc/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.3.post1->txtai[graph,pipeline,similarity]) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/opc/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->ipyplot) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/opc/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->ipyplot) (0.7.0)
# Requirement already satisfied: wcwidth in /home/opc/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->ipyplot) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/opc/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1.0->txtai[graph,pipeline,similarity]) (1.16.0)
# Collecting numpy>=1.18.4
#   Downloading numpy-1.22.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 78.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting onnxconverter-common>=1.7.0
#   Using cached onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
# Requirement already satisfied: executing in /home/opc/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->ipyplot) (0.8.3)
# Requirement already satisfied: pure-eval in /home/opc/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->ipyplot) (0.2.2)
# Requirement already satisfied: asttokens in /home/opc/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->ipyplot) (2.0.5)
# Requirement already satisfied: mpmath>=0.19 in /home/opc/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.8.1->txtai[graph,pipeline,similarity]) (1.2.1)
# Building wheels for collected packages: annoy, fasttext, hnswlib, python-louvain, sentence-transformers, tika, txtai
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.1-cp39-cp39-linux_x86_64.whl size=69670 sha256=e0923d97b7029a4f53a5094c6ef3b59f67370f2860aeef53d49b69b79617b738
#   Stored in directory: /home/opc/.cache/pip/wheels/5b/7d/31/9a9a4993d085bc85bee21946bce94cd5906ce99730f5467e57
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp39-cp39-linux_x86_64.whl size=301381 sha256=6befa575fc230cedba7fb4c07450ab63bf6098a2056adc985ffa2334737e0879
#   Stored in directory: /home/opc/.cache/pip/wheels/64/57/bc/1741406019061d5664914b070bd3e71f6244648732bc96109e
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.6.2-cp39-cp39-linux_x86_64.whl size=166099 sha256=f0848a5fe39030e6f534c0a85d9ac4de26e4e5af2110593703226c4a803fa577
#   Stored in directory: /home/opc/.cache/pip/wheels/42/ef/fe/bab7e480effd9f1bb90c3dfc354ac1bceb27eb0f7e0877efdc
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9408 sha256=f80b49e11d03a8618524d2eb202bd017017d5b0d33a81dbb734955de652e4ab3
#   Stored in directory: /home/opc/.cache/pip/wheels/4d/7c/b6/79b198e4ec43f915fbdf967953d48b89a18893b12aa9df0ae2
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125940 sha256=d1d101dc4229adfe097e677756adca8e6931da46d01606f74e561b0e9c5a8740
#   Stored in directory: /home/opc/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=7d2ab62c0c58466972111bf073954cc1db158b269700aa569d443845507746bc
#   Stored in directory: /home/opc/.cache/pip/wheels/ec/76/38/0e4b92d8a3a89cbfff5be03a40c02d15b2072b1b08ebf28d6a
#   Building wheel for txtai (pyproject.toml) ... done
#   Created wheel for txtai: filename=txtai-5.2.0-py3-none-any.whl size=150469 sha256=0ffc3d4075e2cd463daaad937a099323706badc6a1330efdee4249275fc865e1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ifwezdbv/wheels/1c/21/76/fe34260886f366a2a7f440e42722b0a60b84cf8e466201b22a
# Successfully built annoy fasttext hnswlib python-louvain sentence-transformers tika txtai
# Installing collected packages: tokenizers, sentencepiece, flatbuffers, faiss-cpu, annoy, xxhash, shortuuid, pybind11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, lz4, humanfriendly, fasteners, dill, tika, soundfile, responses, python-louvain, pymagnitude-lite, pyarrow, onnx, nvidia-cudnn-cu11, multiprocess, huggingface-hub, hnswlib, fasttext, coloredlogs, transformers, torch, onnxruntime, onnxconverter-common, imagehash, txtai, torchvision, skl2onnx, ipyplot, datasets, timm, sentence-transformers, onnxmltools
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.22.4 which is incompatible.
# Successfully installed annoy-1.17.1 coloredlogs-15.0.1 datasets-2.6.1 dill-0.3.5.1 faiss-cpu-1.7.2 fasteners-0.18 fasttext-0.9.2 flatbuffers-22.10.26 hnswlib-0.6.2 huggingface-hub-0.10.1 humanfriendly-10.0 imagehash-4.3.1 ipyplot-1.1.1 lz4-4.0.2 multiprocess-0.70.13 numpy-1.22.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.1 onnxruntime-1.13.1 pyarrow-10.0.0 pybind11-2.10.1 pymagnitude-lite-0.1.143 python-louvain-0.16 responses-0.18.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 shortuuid-1.0.11 skl2onnx-1.13 soundfile-0.11.0 tika-1.24 timm-0.6.11 tokenizers-0.13.2 torch-1.13.0 torchvision-0.14.0 transformers-4.24.0 txtai-5.2.0 xxhash-3.1.0
#
# [notice] A new release of pip available: 22.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /home/opc/anaconda3/lib/python3.9/site-packages (4.64.0)
#
# [notice] A new release of pip available: 22.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install pysbd
# Out:
# Requirement already satisfied: pysbd in /home/opc/anaconda3/lib/python3.9/site-packages (0.3.4)
#
# [notice] A new release of pip available: 22.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer, models

word_embedding_model = models.Transformer('allenai/longformer-base-4096', max_seq_length=4096)
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())

model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Downloading:   0%|          | 0.00/694 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/597M [00:00<?, ?B/s]
# Some weights of the model checkpoint at allenai/longformer-base-4096 were not used when initializing LongformerModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing LongformerModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
model.save("longformer")

# %% [markdown]
# # Graph basics
#
# First we'll build a basic [graph](https://en.wikipedia.org/wiki/Graph_theory) and show how it can be used to explore relationships.
#
# The code below builds a graph of animals and relationships between them. We'll add nodes and relationships along with running a couple analysis functions.

# %% [markdown]
# The visualization shows the layout of the graph. A centrality and path function were also run. Centrality shows the most central or related nodes. In this case, the `wolf` node has the highest score. We also ran a path function to show how the graph is traversed from `dog` to `horse`.

# %% [markdown]
# # Build a Semantic Graph
#
# While txtai graphs can be standalone, with nodes and relationships manually added, the real power comes in indexing an embeddings instance.
#
# The following section builds an embeddings index over the `ag_news` dataset. `ag_news` contains news headlines from the mid 2000s. This configuration sets the familiar vector model and content settings.
#
# Column expressions is a feature starting with txtai 5.0. Column expressions alias expressions allowing SQL statements to use those references as a shorthand for the expression.
#
# Next comes the graph. The configuration sets the maximum number of connections to add per node (15) along with a minimum similarity score (0.1). Topic modeling parameters are also added which we'll cover later.

# %%
import pysbd

from txtai.embeddings import Embeddings
import networkx as nx
from tqdm import tqdm

from txtai.graph import GraphFactory

from datasets import load_dataset
dataset = load_dataset("Hellisotherpeople/DebateSum", split = "train")
seg = pysbd.Segmenter(language="en", clean=False)
#from txtai.scoring import ScoringFactory
#scoring = ScoringFactory.create({"method": "bm25", "terms": True, "content" : True})

#sentence-transformers/all-mpnet-base-v2 
#legal-bert
#longformer


# Create embeddings instance with a semantic graph
embeddings = Embeddings({
  "path": "legal-bert",
  "content": True,
  "functions": [
    {"name": "graph", "function": "graph.attribute"},
  ],
  "expressions": [
      {"name": "topic", "expression": "graph(indexid, 'topic')"},
      {"name": "topicrank", "expression": "graph(indexid, 'topicrank')"}
  ],
  "graph": {
      "limit": 100,
      "minscore": 0.10,
      "topics": {
          "terms": 4,
          "resolution" : 100
      }
  }
})

# Load dataset
#dataset = load_dataset("ag_news", split="train")
#rows = dataset["text"]
# Out:
# 2022-12-06 23:46:10,429 [WARNING] _create_builder_config: Using custom data configuration Hellisotherpeople--DebateSum-d85e26ecd585ba24
# 2022-12-06 23:46:10,432 [WARNING] download_and_prepare: Found cached dataset csv (/home/lain/.cache/huggingface/datasets/Hellisotherpeople___csv/Hellisotherpeople--DebateSum-d85e26ecd585ba24/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)

# %%
dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'Full-Document', 'Citation', 'Extract', 'Abstract', '#CharsDocument', '#CharsAbstract', '#CharsExtract', '#WordsDocument', '#WordsAbstract', '#WordsExtract', 'AbsCompressionRatio', 'ExtCompressionRatio', 'OriginalDebateFileName', 'DebateCamp', 'Tag', 'Year'],
#     num_rows: 240566
# })

# %%
##TODO: Get some kind of retrieve and rerank pipeline working
##TODO: Think of further columns to add as calculations from what are here? Maybe sentiment?

def stream(dataset, field, limit, index_content=False):
  index = 0
  for count, row in tqdm(enumerate(dataset)):
    segmented_sentence = seg.segment(row[field])
    for sentence in segmented_sentence:
        if index_content:
            yield (index, {"text":sentence, "full-document": row["Full-Document"], "length_doc" : row["#WordsDocument"], "extract" : row["Extract"], "length_extract" : row["#WordsExtract"], "Abstract" : row["Abstract"], "length_abstract" : row["#WordsAbstract"], "citation": row["Citation"], "filename" : row["OriginalDebateFileName"], "debatecamp" : row["DebateCamp"], "tag" : row["Tag"], "year" : row["Year"] ,"evidence_id" : count} , None)
        else:
            yield (index, {"text":sentence, "evidence_id" : count} , None)
        index += 1

    if index >= limit:
      print("Hit Limit, now indexing")
      break
        
def stream_no_limit(dataset, field, index_content=False):
  index = 0
  for count, row in tqdm(enumerate(dataset)):
    segmented_sentence = seg.segment(row[field])
    for sentence in segmented_sentence:
        if index_content:
            yield (index, {"text":sentence, "full-document": row["Full-Document"], "length_doc" : row["#WordsDocument"], "extract" : row["Extract"], "length_extract" : row["#WordsExtract"], "Abstract" : row["Abstract"], "length_abstract" : row["#WordsAbstract"], "citation": row["Citation"], "filename" : row["OriginalDebateFileName"], "debatecamp" : row["DebateCamp"], "tag" : row["Tag"], "year" : row["Year"] ,"evidence_id" : count} , None)
        else:
            yield (index, {"text":sentence, "evidence_id" : count} , None)
        index += 1
    
embeddings.index(stream_no_limit(dataset, "Full-Document", True))

#embeddings.index(stream(dataset, "Full-Document", 10000, True))
#embeddings.save("DebateSum_SemanticGraph")
# Out:
# 240566it [3:05:22, 21.63it/s]

# %%
embeddings.index((x, {"text": text["Extract"], "full-document": text["Full-Document"], "length_doc" : text["#WordsDocument"], "extract" : text["Extract"], "length_extract" : text["#WordsExtract"], "Abstract" : text["Abstract"], "length_abstract" : text["#WordsAbstract"], "citation": text["Citation"], "filename" : text["OriginalDebateFileName"], "debatecamp" : text["DebateCamp"], "tag" : text["Tag"], "year" : text["Year"]}, None) for x, text in tqdm(enumerate(dataset)))
# Out:
# 240566it [58:19, 68.74it/s]

# %%
embeddings.save("DebateSum_SemanticGraph_legal-bert_sentence.tar.gz")

# %%
embeddings.load("DebateSum_SemanticGraph_mpnet_extract.tar.gz")

# %%
from tqdm import tqdm
# Index dataset

#embeddings.index((x, {"text": text["Abstract"], "extract" : text["Extract"], "document" : text["Full-Document"], "citation": text["Citation"], "filename" : text["OriginalDebateFileName"]}, None) for x, text in tqdm(enumerate(dataset)))


graph = embeddings.graph

# %% [markdown]
# mpnet abstractive
# 240566 1876918
#
# 7.802091733661449
#
# 1692
#
# mpnet extractive
# 240566 2133792
#
# 8.869881861942252
# 1203
#
# legalbert extractive
#
# 240566 2685362
#
# 11.16268300591106
#
# 2576
#
# legalbert abstractive
#
# 240566 3006572
#
# 12.497909097711231
#
# 5008
#
# Longformer abstractive
#
# 240566 2604166
#
# 10.82516232551566
#
# Longformer Extractive
#
# 240566 2128302
#
# 8.847060681891872
#
# 1592

# %%
print(graph.backend.number_of_nodes(), graph.backend.number_of_edges())
graph.backend.number_of_edges() / float(graph.backend.number_of_nodes())
# Out:
# 240566 2128302
# 8.847060681891872

# %%
len(embeddings.graph.topics)
# Out:
# 1592

# %%
#embeddings.save("test_embeddings") ##Note, need original settings to load embeddings, can't do it in seperate embeddings object

# %%
#embeddings.load("test_embeddings")

# %%
list(graph.topics.keys())
# Out:
# ['from_has_have_more',
#  'has_its_have_from',
#  'from_have_can_more',
#  'has_from_have_which',
#  'have_has_its_china',
#  'from_more_have_than',
#  'have_from_can_has',
#  'states_its_has_have',
#  'which_its_from_has',
#  'court_has_have_from',
#  'has_have_more_its',
#  'its_has_china_states',
#  'which_its_can_from',
#  'have_has_would_from',
#  'which_its_from_we',
#  'we_have_can_from',
#  'have_from_states_has',
#  'his_trump_has_he',
#  'social_which_political_from',
#  'from_political_which_its',
#  'oil_from_has_have',
#  'from_have_which_can',
#  'can_have_more_has',
#  'from_which_can_we',
#  'have_from_we_has',
#  'have_from_has_who',
#  'have_more_we_can',
#  'from_can_have_water',
#  'have_from_more_who',
#  'one_from_can_which',
#  'more_have_from_we',
#  'has_states_its_united',
#  'has_economic_have_from',
#  'have_from_has_government',
#  'which_from_its_what',
#  'have_we_people_from',
#  'has_from_have_been',
#  'have_house_would_has',
#  'from_which_social_has',
#  'states_united_have_has',
#  'has_have_its_political',
#  'from_more_which_have',
#  'we_have_can_people',
#  'state_federal_states_have',
#  'from_year_economy_growth',
#  'which_from_its_only',
#  'have_more_has_than',
#  'military_has_have_its',
#  'from_have_has_world',
#  'have_from_which_social',
#  'which_can_social_from',
#  'has_its_have_would',
#  'china_its_states_united',
#  'have_from_has_law',
#  'from_climate_have_global',
#  'states_more_from_have',
#  'has_have_war_world',
#  'has_its_from_china',
#  'we_have_can_you',
#  'has_from_have_energy',
#  'which_from_political_can',
#  'its_has_states_power',
#  'students_have_school_schools',
#  'we_can_have_our',
#  'energy_from_can_more',
#  'has_have_we_more',
#  'from_have_political_can',
#  'have_from_federal_has',
#  'nuclear_weapons_have_would',
#  'its_from_which_have',
#  'have_trump_has_voters',
#  'has_united_states_china',
#  'we_have_can_which',
#  'china_its_has_south',
#  'court_have_has_its',
#  'have_democrats_republicans_trump',
#  'would_nuclear_have_could',
#  'we_can_have_what',
#  'economic_has_more_have',
#  'we_which_from_have',
#  'may_can_more_have',
#  'its_has_from_world',
#  'from_we_what_can',
#  'have_from_has_he',
#  'from_have_states_economic',
#  'court_federal_has_congress',
#  'has_have_economy_from',
#  'court_has_have_he',
#  'states_has_united_from',
#  'has_its_china_military',
#  'have_from_global_more',
#  'percent_has_more_trump',
#  'which_from_one_its',
#  'have_has_more_would',
#  'from_which_through_social',
#  'trump_has_have_his',
#  'education_school_students_schools',
#  'court_supreme_has_have',
#  'oil_has_its_from',
#  'have_has_countries_from',
#  'house_senate_have_would',
#  'from_more_economic_have',
#  'states_have_united_china',
#  'have_state_federal_has',
#  'engagement_economic_policy_state',
#  'has_have_from_trump',
#  'can_from_has_more',
#  'states_have_more_its',
#  'has_have_said_he',
#  'from_which_political_has',
#  'its_states_world_has',
#  'he_has_his_president',
#  'we_have_our_has',
#  'more_have_from_other',
#  'from_have_than_has',
#  'students_school_have_more',
#  'than_from_more_has',
#  'states_more_have_war',
#  'have_were_from_people',
#  'which_we_what_all',
#  'warming_climate_global_we',
#  'democrats_have_has_more',
#  'house_senate_bill_republicans',
#  'would_states_nuclear_its',
#  'federal_state_states_government',
#  'has_its_states_from',
#  'we_human_our_have',
#  'from_has_have_also',
#  'year_economy_oil_growth',
#  'house_bill_senate_have',
#  'nuclear_its_has_would',
#  'from_has_military_have',
#  'climate_global_warming_have',
#  'he_has_we_have',
#  'we_you_have_about',
#  'can_have_which_more',
#  'has_have_war_its',
#  'from_which_through_we',
#  'climate_change_emissions_global',
#  'have_from_more_school',
#  'have_we_you_what',
#  'which_we_only_what',
#  'court_supreme_trump_decision',
#  'information_has_national_security',
#  'has_have_political_more',
#  'word_meaning_court_should',
#  'world_more_have_from',
#  'from_which_its_through',
#  'have_from_would_more',
#  'has_more_have_world',
#  'from_billion_states_percent',
#  'nuclear_weapons_states_would',
#  'from_were_which_had',
#  'have_can_its_from',
#  'have_from_people_who',
#  'have_people_more_can',
#  'has_from_have_new',
#  'states_war_have_has',
#  'immigration_permanent_states_united',
#  'we_which_can_its',
#  'have_from_has_people',
#  'have_school_education_schools',
#  'has_have_from_congress',
#  'from_which_through_can',
#  'have_education_school_state',
#  'can_have_which_social',
#  'its_has_defense_states',
#  'has_its_more_from',
#  'have_health_education_from',
#  'fish_species_have_from',
#  'has_world_have_economic',
#  'social_which_political_have',
#  'have_would_has_states',
#  'court_law_courts_has',
#  'students_school_have_education',
#  'which_its_political_state',
#  'china_has_states_have',
#  'his_has_trump_president',
#  'has_have_war_would',
#  'nuclear_would_has_war',
#  'trade_states_exports_united',
#  'have_from_species_human',
#  'have_more_from_about',
#  'from_have_his_which',
#  'have_from_has_said',
#  'can_from_have_fish',
#  'have_from_which_political',
#  'countries_has_cooperation_between',
#  'we_our_have_more',
#  'have_we_could_can',
#  'court_have_has_courts',
#  'we_have_global_species',
#  'democrats_republicans_have_party',
#  'have_from_between_economic',
#  'have_between_has_from',
#  'have_from_can_may',
#  'has_year_economy_growth',
#  'from_have_more_workers',
#  'which_from_can_has',
#  'we_which_can_political',
#  'has_venezuela_from_his',
#  'have_has_from_our',
#  'court_supreme_has_his',
#  'has_have_global_economic',
#  'have_workers_more_immigration',
#  'has_have_world_its',
#  'can_more_would_have',
#  'can_systems_have_from',
#  'court_supreme_has_federal',
#  'we_one_what_from',
#  'have_from_more_people',
#  'have_species_from_ecosystems',
#  'its_would_china_nuclear',
#  'states_united_its_from',
#  'have_one_which_can',
#  'have_can_more_education',
#  'rights_have_human_has',
#  'court_have_may_congress',
#  'students_more_education_have',
#  'from_were_has_its',
#  'world_war_has_been',
#  'has_have_china_economic',
#  'from_have_immigration_who',
#  'have_from_has_all',
#  'states_its_more_war',
#  'which_from_what_one',
#  'has_said_house_have',
#  'growth_have_has_from',
#  'have_from_has_were',
#  'have_would_has_we',
#  'have_more_from_evidence',
#  'species_from_have_more',
#  'have_would_more_even',
#  'trump_his_percent_approval',
#  'from_which_through_within',
#  'have_from_terrorist_groups',
#  'have_has_people_more',
#  'congress_law_federal_states',
#  'have_has_we_can',
#  'can_we_one_which',
#  'has_oil_from_more',
#  'which_from_other_one',
#  'used_word_indicate_noun',
#  'united_states_have_from',
#  'would_has_have_nuclear',
#  'energy_from_can_power',
#  'senate_house_bill_has',
#  'from_federal_programs_state',
#  'more_economic_has_our',
#  'have_war_more_would',
#  'we_have_has_do',
#  'would_from_nuclear_could',
#  'political_social_which_we',
#  'we_can_what_all',
#  'have_can_one_we',
#  'have_from_has_trafficking',
#  'its_has_which_have',
#  'billion_year_million_than',
#  'has_china_have_from',
#  'nuclear_would_its_have',
#  'have_has_can_could',
#  'has_from_its_space',
#  'has_war_have_been',
#  'immigration_from_immigrants_have',
#  'which_we_from_all',
#  'have_technology_states_science',
#  'from_more_have_one',
#  'which_has_its_political',
#  'has_oil_from_drilling',
#  'have_more_global_we',
#  'from_were_which_has',
#  'obama_his_has_president',
#  'surveillance_foreign_intelligence_government',
#  'has_relations_states_united',
#  'from_has_have_research',
#  'from_which_social_its',
#  'have_from_has_one',
#  'his_trump_republicans_has',
#  'can_one_which_only',
#  'energy_from_cost_than',
#  'have_we_can_he',
#  'which_from_has_economic',
#  'china_states_military_united',
#  'from_through_have_which',
#  'more_percent_from_has',
#  'china_its_russia_has',
#  'house_senate_act_would',
#  'states_weapons_could_military',
#  'has_its_have_economy',
#  'have_has_federal_more',
#  'has_have_he_trump',
#  'court_federal_law_supreme',
#  'species_have_from_marine',
#  'climate_change_from_world',
#  'economic_economy_growth_has',
#  'can_has_from_all',
#  'our_economy_economic_we',
#  'more_from_energy_have',
#  'would_have_china_from',
#  'have_from_global_has',
#  'has_china_its_united',
#  'from_one_which_has',
#  'water_resources_protection_from',
#  'political_has_which_social',
#  'substantial_which_than_term',
#  'world_have_more_war',
#  'states_united_sea_ocean',
#  'have_we_people_you',
#  'world_states_have_has',
#  'from_gas_has_oil',
#  'china_has_have_world',
#  'has_research_from_states',
#  'nuclear_weapons_has_states',
#  'from_energy_have_than',
#  'has_have_from_space',
#  'has_its_nuclear_between',
#  'foreign_security_defense_department',
#  'democrats_republicans_house_senate',
#  'nato_military_its_security',
#  'international_law_states_has',
#  'which_we_from_what',
#  'states_united_government_federal',
#  'have_has_terrorist_from',
#  'climate_change_more_have',
#  'have_from_which_who',
#  'would_billion_have_from',
#  'have_democrats_voters_trump',
#  'economic_have_more_growth',
#  'from_has_gas_energy',
#  'have_has_can_would',
#  'from_has_have_could',
#  'our_more_security_have',
#  'has_have_its_been',
#  'have_one_can_what',
#  'has_from_have_political',
#  'has_have_said_its',
#  'have_from_visa_workers',
#  'which_from_political_state',
#  'states_from_which_united',
#  'economic_climate_change_have',
#  'economy_has_growth_have',
#  'can_has_have_world',
#  'has_have_from_us',
#  'has_have_would_been',
#  'social_from_its_has',
#  'oil_from_million_per',
#  'which_have_can_should',
#  'have_from_development_new',
#  'can_have_also_from',
#  'from_all_we_have',
#  'world_has_have_our',
#  'more_percent_than_americans',
#  'economy_has_more_have',
#  'its_has_world_china',
#  'from_which_its_power',
#  'security_states_military_united',
#  'which_power_social_political',
#  'law_court_have_courts',
#  'has_from_have_his',
#  'from_may_agency_have',
#  'political_policy_congress_can',
#  'would_world_economic_global',
#  'has_its_china_security',
#  'earth_have_from_global',
#  'from_have_more_between',
#  'have_nuclear_weapons_could',
#  'surveillance_have_government_from',
#  'korea_nuclear_north_its',
#  'climate_change_from_have',
#  'from_has_have_surveillance',
#  'we_would_have_more',
#  'can_have_data_information',
#  'have_from_more_immigration',
#  'have_has_states_we',
#  'has_production_from_growth',
#  'political_economic_has_its',
#  'cooperation_has_china_bilateral',
#  'have_energy_from_can',
#  'have_has_from_nuclear',
#  'have_has_we_world',
#  'more_can_have_new',
#  'water_from_can_gas',
#  'you_can_his_about',
#  'have_has_from_water',
#  'national_federal_ocean_government',
#  'have_federal_water_state',
#  'have_from_death_who',
#  'have_about_we_has',
#  'has_its_more_china',
#  'social_we_political_more',
#  'we_have_re_can',
#  'from_would_budget_funding',
#  'development_energy_research_states',
#  'he_from_which_his',
#  'support_percent_americans_republicans',
#  'we_which_its_have',
#  'have_law_can_from',
#  'economy_growth_has_from',
#  'oil_have_gas_energy',
#  'emissions_energy_from_has',
#  'sea_china_south_has',
#  'social_its_political_have',
#  'oil_gas_has_production',
#  'oil_would_from_prices',
#  'social_political_can_we',
#  'world_its_economic_have',
#  'court_should_determination_resolution',
#  'from_can_cyber_security',
#  'which_political_we_its',
#  'from_which_its_all',
#  'has_have_its_nuclear',
#  'have_from_would_can',
#  'countries_international_development_has',
#  'have_would_weapons_more',
#  'from_more_has_states',
#  'have_has_would_he',
#  'from_its_can_has',
#  'have_about_has_more',
#  'than_more_from_percent',
#  'iran_nuclear_deal_would',
#  'more_can_from_about',
#  'which_from_other_can',
#  'said_have_has_would',
#  'which_social_human_can',
#  'have_from_other_also',
#  'human_from_which_we',
#  'climate_we_change_more',
#  'have_more_has_climate',
#  'have_education_can_students',
#  'who_states_status_united',
#  'nuclear_war_could_world',
#  'have_has_which_can',
#  'nuclear_war_would_could',
#  'have_has_we_countries',
#  'education_have_school_has',
#  'have_who_has_would',
#  'has_government_federal_have',
#  'prices_oil_has_year',
#  'china_would_its_states',
#  'were_have_from_percent',
#  'its_china_russia_power',
#  'have_from_has_social',
#  'has_its_military_war',
#  'substantial_real_from_mean',
#  'species_have_extinction_than',
#  'has_from_its_forces',
#  'states_united_its_security',
#  'human_from_have_global',
#  'have_should_one_has',
#  'have_federal_death_states',
#  'military_its_states_has',
#  'which_from_through_has',
#  'have_from_were_said',
#  'has_policy_have_states',
#  'have_has_more_what',
#  'have_federal_from_programs',
#  'word_have_has_which',
#  'states_from_law_have',
#  'has_china_have_war',
#  'has_have_more_years',
#  'from_have_has_other',
#  'has_its_united_rights',
#  'has_its_economic_have',
#  'its_security_international_cooperation',
#  'trump_immigration_administration_from',
#  'have_can_more_emissions',
#  'have_economic_more_economy',
#  'states_china_its_arctic',
#  'more_have_countries_than',
#  'countries_has_china_from',
#  'have_more_can_who',
#  'which_one_from_have',
#  'more_have_we_economic',
#  'china_its_would_has',
#  'would_from_have_states',
#  'which_its_what_can',
#  'have_political_more_president',
#  'has_than_its_have',
#  'have_can_security_attacks',
#  'which_from_new_its',
#  'congress_from_president_have',
#  'has_have_government_its',
#  'rights_human_one_right',
#  'water_federal_epa_states',
#  'his_president_has_have',
#  'have_we_said_can',
#  'have_from_has_policy',
#  'more_has_economic_can',
#  'have_has_been_world',
#  'from_water_energy_have',
#  'has_from_government_cuba',
#  'climate_change_from_global',
#  'energy_more_can_have',
#  'state_education_federal_states',
#  'from_which_its_state',
#  'from_have_social_state',
#  'political_social_which_can',
#  'which_from_one_only',
#  'has_russia_from_have',
#  'states_has_policy_its',
#  'courts_have_can_congress',
#  'federal_have_has_states',
#  'has_growth_economic_its',
#  'from_one_all_has',
#  'surveillance_government_nsa_has',
#  'have_from_states_state',
#  'we_way_our_people',
#  'political_from_we_its',
#  'cuba_embargo_has_cuban',
#  'have_could_global_war',
#  'has_industry_from_have',
#  'rights_human_all_can',
#  'would_has_have_court',
#  'education_students_economy_our',
#  'can_more_policy_which',
#  'world_global_climate_has',
#  'have_from_we_up',
#  'we_have_has_what',
#  'have_we_has_been',
#  'states_china_countries_united',
#  'human_water_food_life',
#  'more_have_public_has',
#  'china_tpp_its_has',
#  'from_its_we_what',
#  'have_from_about_has',
#  'its_has_economic_china',
#  'have_from_people_which',
#  'cooperation_china_states_countries',
#  'oil_have_has_prices',
#  'has_have_can_all',
#  'more_has_its_states',
#  'china_has_strategic_would',
#  'have_he_been_said',
#  'only_have_which_can',
#  'economic_growth_economy_financial',
#  'social_state_has_from',
#  'would_budget_federal_billion',
#  'house_obama_bill_congress',
#  'social_from_have_more',
#  'his_president_he_political',
#  'we_have_has_all',
#  'have_countries_has_economic',
#  'we_can_from_our',
#  'has_program_department_security',
#  'trump_republican_democrats_has',
#  'security_united_states_economic',
#  'from_more_health_have',
#  'has_its_global_have',
#  'have_could_would_we',
#  'we_have_us_what',
#  'has_its_security_have',
#  'reform_bill_republicans_tax',
#  'trump_has_war_his',
#  'has_global_system_have',
#  'from_energy_marine_global',
#  'military_our_capabilities_has',
#  'has_have_constitutional_states',
#  'have_can_china_has',
#  'its_political_from_social',
#  'from_people_have_can',
#  'from_have_has_what',
#  'have_military_has_said',
#  'percent_has_than_from',
#  'we_have_our_trump',
#  'have_we_more_could',
#  'china_korea_its_north',
#  'have_can_more_power',
#  'more_have_workers_has',
#  'from_have_more_its',
#  'economy_billion_million_more',
#  'have_can_social_from',
#  'increase_has_have_growth',
#  'economic_states_global_countries',
#  'which_from_have_also',
#  'cuba_embargo_has_would',
#  'cooperation_china_have_has',
#  'have_has_from_enforcement',
#  'oil_production_from_has',
#  'have_has_from_security',
#  'has_war_world_nuclear',
#  'saudi_trump_arabia_arms',
#  'climate_change_why_understanding',
#  'climate_energy_change_can',
#  'court_have_has_political',
#  'have_from_fish_has',
#  'have_from_who_than',
#  'have_from_women_has',
#  'have_from_would_nuclear',
#  'have_has_government_would',
#  'government_federal_political_have',
#  'increase_from_have_would',
#  'species_have_can_may',
#  'international_have_security_states',
#  'has_policy_cuba_relations',
#  'have_which_has_economic',
#  'we_have_from_who',
#  'protection_have_resources_which',
#  'democrats_trump_elections_house',
#  'can_we_have_do',
#  'people_have_from_world',
#  'war_violence_has_can',
#  'school_have_students_has',
#  'which_from_his_has',
#  'cooperation_bilateral_china_two',
#  'has_have_theory_from',
#  'from_which_social_about',
#  'has_cuba_state_states',
#  'energy_have_more_has',
#  'from_which_we_social',
#  'global_have_world_can',
#  'can_different_substantial_term',
#  'china_countries_cooperation_have',
#  'house_bill_republicans_would',
#  'act_surveillance_have_house',
#  'would_could_from_have',
#  'policy_its_states_rights',
#  'has_have_social_which',
#  'he_his_obama_has',
#  'have_federal_prison_from',
#  'have_more_conflict_from',
#  'oil_its_gas_has',
#  'its_have_countries_military',
#  'have_which_economic_more',
#  'global_climate_from_emissions',
#  'has_more_states_united',
#  'have_from_more_women',
#  'have_has_world_global',
#  'criminal_law_reform_justice',
#  'would_have_weapons_could',
#  'has_have_from_al',
#  'from_which_have_theory',
#  'climate_warming_global_from',
#  'our_we_more_can',
#  'states_could_more_can',
#  'has_world_economy_economic',
#  'has_united_states_cuba',
#  'from_we_can_more',
#  'states_international_united_law',
#  'china_relations_two_between',
#  'has_environmental_have_from',
#  'economic_political_could_have',
#  'china_has_its_america',
#  'which_can_power_have',
#  'world_has_people_have',
#  'from_have_its_security',
#  'can_social_which_we',
#  'has_states_united_other',
#  'china_nuclear_russia_have',
#  'world_earth_than_one',
#  'act_congress_federal_under',
#  'budget_billion_spending_congress',
#  'congress_president_has_executive',
#  'oil_trump_drilling_federal',
#  'has_said_from_its',
#  'has_china_states_from',
#  'government_court_amendment_have',
#  'have_more_can_its',
#  'which_social_political_through',
#  'were_which_its_from',
#  'which_can_only_from',
#  'economic_states_from_more',
#  'from_have_has_marine',
#  'oil_has_its_china',
#  'federal_state_funding_states',
#  'cooperation_security_states_has',
#  'has_more_war_conflict',
#  'we_all_has_our',
#  'security_national_from_states',
#  'water_can_have_use',
#  'have_workers_has_would',
#  'have_can_all_we',
#  'has_its_political_from',
#  'has_trade_china_its',
#  'has_from_american_national',
#  'has_than_been_more',
#  'exploration_development_ocean_from',
#  'has_have_economy_been',
#  'may_courts_has_which',
#  'court_has_have_government',
#  'have_from_may_has',
#  'has_cuba_embargo_from',
#  'has_from_states_national',
#  'from_has_which_more',
#  'china_cooperation_between_have',
#  'can_have_what_must',
#  'has_energy_from_more',
#  'from_has_drug_have',
#  'have_court_congress_has',
#  'which_what_have_we',
#  'has_world_been_capitalism',
#  'has_world_than_have',
#  'have_one_more_you',
#  'have_has_health_people',
#  'social_from_political_has',
#  'word_resolved_resolution_used',
#  'growth_economic_economy_increase',
#  'court_law_judicial_courts',
#  'more_states_also_can',
#  'production_from_have_has',
#  'billion_state_million_federal',
#  'have_oil_has_been',
#  'has_its_power_military',
#  'have_law_would_may',
#  'nuclear_war_could_even',
#  'has_world_military_its',
#  'have_we_about_he',
#  'its_has_from_economic',
#  'has_trump_have_court',
#  'has_from_states_demand',
#  'have_more_students_from',
#  'tax_would_have_has',
#  'federal_has_education_trump',
#  'has_congress_have_law',
#  'have_from_health_can',
#  'states_power_more_military',
#  'states_has_development_countries',
#  'can_which_have_may',
#  'nuclear_weapons_states_korea',
#  'have_mexico_more_from',
#  'we_world_our_have',
#  'we_about_can_have',
#  'states_federal_government_have',
#  'nuclear_its_military_capabilities',
#  'can_from_political_states',
#  'our_we_people_have',
#  'development_more_can_from',
#  'its_more_state_can',
#  'states_have_has_court',
#  'have_most_more_from',
#  'international_have_its_more',
#  'energy_more_than_wind',
#  'congress_would_house_has',
#  'security_states_activities_programs',
#  'has_have_power_political',
#  'systems_have_space_could',
#  'support_saudi_have_its',
#  'have_from_government_rights',
#  'about_can_have_from',
#  'have_more_from_security',
#  'one_than_more_can',
#  'nuclear_has_china_russia',
#  'policy_cuba_would_states',
#  'more_can_we_about',
#  'nuclear_would_china_could',
#  'political_what_can_we',
#  'oil_prices_have_we',
#  'we_our_united_states',
#  'criminal_law_justice_crime',
#  'have_has_companies_from',
#  'have_can_government_also',
#  'from_has_more_economic',
#  'more_what_have_can',
#  'nuclear_war_would_weapons',
#  'have_more_from_racial',
#  'has_russia_china_war',
#  'rights_civil_have_movement',
#  'has_environmental_have_can',
#  'can_have_water_economic',
#  'more_can_from_new',
#  'has_states_power_united',
#  'have_world_more_we',
#  'would_states_its_united',
#  'from_new_which_have',
#  'which_have_more_may',
#  'china_has_its_power',
#  'has_political_from_can',
#  'one_we_when_can',
#  'indigenous_have_from_peoples',
#  'has_more_its_united',
#  'china_nuclear_military_its',
#  'states_federal_state_law',
#  'has_have_many_been',
#  'growth_economic_economy_global',
#  'its_has_nato_economic',
#  'climate_change_world_trump',
#  'trade_economic_have_other',
#  'would_world_more_have',
#  'have_would_billion_trade',
#  'prices_have_has_production',
#  'nuclear_weapons_has_china',
#  'oil_gas_energy_natural',
#  'states_military_china_have',
#  'trade_economic_development_cooperation',
#  'can_have_from_satellites',
#  'can_from_policy_has',
#  'policy_can_may_have',
#  'has_space_nasa_have',
#  'has_have_nieto_mexico',
#  'would_percent_more_costs',
#  'economic_economy_our_states',
#  'congress_have_support_has',
#  'have_people_we_world',
#  'political_social_have_economic',
#  'have_more_can_all',
#  'cyber_has_security_government',
#  'government_law_federal_state',
#  'social_economic_global_security',
#  'china_has_countries_its',
#  'border_trump_would_administration',
#  'could_its_nuclear_military',
#  'energy_power_more_has',
#  'would_economy_world_all',
#  'have_has_from_since',
#  'have_should_from_would',
#  'more_from_new_has',
#  'oil_gas_offshore_energy',
#  'oil_states_has_countries',
#  'states_have_war_can',
#  'from_have_law_its',
#  'its_from_has_government',
#  'were_from_have_which',
#  'emissions_from_gas_more',
#  'what_have_who_can',
#  'have_from_can_our',
#  'court_has_from_fisa',
#  'have_extinction_has_human',
#  'policy_has_state_political',
#  'has_china_washington_its',
#  'has_its_which_war',
#  'have_can_more_data',
#  'have_states_has_other',
#  'has_have_from_immigration',
#  'states_united_nuclear_china',
#  'trade_have_from_would',
#  'more_have_from_education',
#  'can_more_have_also',
#  'have_has_government_can',
#  'economy_china_global_economic',
#  'states_united_has_were',
#  'have_policy_more_political',
#  'has_economic_have_development',
#  'more_economic_can_than',
#  'states_would_have_can',
#  'has_its_military_new',
#  'its_military_would_have',
#  'which_political_one_other',
#  'china_have_more_has',
#  'from_political_have_its',
#  'has_power_its_have',
#  'have_has_from_mexico',
#  'military_security_national_states',
#  'people_we_have_has',
#  'technology_development_systems_more',
#  'have_from_economic_can',
#  'energy_has_market_development',
#  'have_has_from_technology',
#  'china_taiwan_states_united',
#  'more_from_can_aquaculture',
#  'has_china_military_would',
#  'more_have_than_when',
#  'nuclear_war_have_would',
#  'has_been_trump_one',
#  'trump_congress_republicans_have',
#  'fed_said_would_its',
#  'students_percent_more_school',
#  'environmental_federal_marine_national',
#  'nuclear_would_have_more',
#  'nato_its_alliance_military',
#  'energy_states_from_united',
#  'has_from_can_state',
#  'has_have_trade_its',
#  'food_world_people_global',
#  'border_have_more_from',
#  'nuclear_have_would_states',
#  'have_has_president_he',
#  'would_has_world_from',
#  'have_states_from_all',
#  'new_us_china_mexico',
#  'we_social_have_which',
#  'its_from_new_oil',
#  'trade_united_states_have',
#  'can_state_have_between',
#  'have_government_federal_from',
#  'have_can_we_justice',
#  'its_military_states_united',
#  'policy_can_government_more',
#  'from_gas_production_has',
#  'would_china_have_states',
#  'have_from_more_government',
#  'people_all_power_from',
#  'from_has_against_people',
#  'have_spending_would_government',
#  'oil_china_has_venezuela',
#  'more_than_percent_world',
#  'political_power_new_which',
#  'drug_from_has_trafficking',
#  'cuba_has_embargo_more',
#  'from_which_life_has',
#  'have_which_from_rights',
#  'have_has_international_from',
#  'trump_has_us_would',
#  'from_government_has_surveillance',
#  'human_rights_international_law',
#  'has_rights_human_its',
#  'who_trump_voters_more',
#  'have_government_companies_data',
#  'has_its_china_which',
#  'have_political_has_economic',
#  'has_have_year_said',
#  'has_we_than_more',
#  'have_more_would_use',
#  'have_economic_from_than',
#  'have_more_china_would',
#  'have_than_death_would',
#  'have_more_all_who',
#  'substantial_means_has_than',
#  'have_between_about_should',
#  'were_which_would_government',
#  'oil_prices_from_more',
#  'which_political_from_more',
#  'states_united_its_should',
#  'have_national_more_we',
#  'war_has_china_nuclear',
#  'we_political_which_all',
#  'from_its_had_one',
#  'have_said_who_we',
#  'more_even_people_than',
#  'more_can_government_has',
#  'from_which_can_what',
#  'have_also_which_who',
#  'could_has_would_from',
#  'congress_authority_federal_has',
#  'ai_human_could_humans',
#  'would_have_states_use',
#  'water_federal_from_has',
#  'time_congress_would_have',
#  'have_from_about_public',
#  'we_have_people_only',
#  'one_more_states_border',
#  'have_privacy_information_government',
#  'from_between_has_all',
#  'earth_space_could_would',
#  'its_which_have_all',
#  'which_have_all_has',
#  'power_states_war_conflict',
#  'president_mexico_nieto_party',
#  'research_have_ocean_new',
#  'which_its_education_political',
#  'have_can_moral_when',
#  'states_has_system_world',
#  'could_from_have_security',
#  'can_research_more_have',
#  'political_more_have_public',
#  'have_has_federal_our',
#  'economic_from_which_trade',
#  'has_congress_have_president',
#  'from_state_more_federal',
#  'has_most_than_percent',
#  'we_can_settler_indigenous',
#  'would_its_china_even',
#  'more_have_from_also',
#  'more_may_might_we',
#  'can_human_ai_systems',
#  'we_people_about_being',
#  'has_from_violence_have',
#  'more_than_from_political',
#  'more_can_have_resources',
#  'economic_development_from_remittances',
#  'have_law_enforcement_from',
#  'has_united_states_billion',
#  'economic_global_would_could',
#  'economic_order_security_international',
#  'relations_have_cooperation_washington',
#  'can_from_have_new',
#  'war_resources_countries_more',
#  'social_can_individual_have',
#  'energy_emissions_from_percent',
#  'nuclear_could_would_its',
#  'has_relations_china_its',
#  'more_has_china_from',
#  'economic_have_more_can',
#  'from_political_can_more',
#  'its_from_oil_world',
#  'immigration_have_has_more',
#  'which_its_we_what',
#  'what_from_more_we',
#  'power_political_has_world',
#  'we_can_have_only',
#  'has_chinese_china_track',
#  'nuclear_weapons_states_more',
#  'has_would_cuba_have',
#  'more_states_world_has',
#  'have_enforcement_law_more',
#  'china_chinese_have_other',
#  'has_its_than_from',
#  'from_federal_have_law',
#  'its_has_international_have',
#  'we_our_need_can',
#  'trade_have_china_trump',
#  'which_between_from_can',
#  'from_which_its_between',
#  'have_one_more_can',
#  'have_can_people_has',
#  'have_has_government_been',
#  'have_new_over_government',
#  'we_us_has_world',
#  'security_provide_defense_military',
#  'have_would_from_any',
#  'from_rare_energy_high',
#  'which_have_has_global',
#  ...]

# %%
import pprint
pprint.pprint(embeddings.search(f"select id, text, evidence_id, score, topic from txtai where similar('China is going to hurt the USA') and topic like '%usa%' "))
# Out:
# []

# %%
import pprint
pprint.pprint(embeddings.search(f"select id, text, evidence_id, score, topic from txtai where similar('The role of the state in hurting the people')"))
# Out:
# [{'evidence_id': None,
#   'id': '6757',
#   'score': 0.9833215475082397,
#   'text': 'the ruling family has pulled the country to the condition where '
#           'cries of oppressed people are ignored.',
#   'topic': None},
#  {'evidence_id': None,
#   'id': '22889',
#   'score': 0.9824581742286682,
#   'text': 'Nothing in the domain of the state can be against the state',
#   'topic': None},
#  {'evidence_id': None,
#   'id': '203698',
#   'score': 0.9821363091468811,
#   'text': 'we need to see the big picture of the role that immigrants play in '
#           'the new global capitalism system',
#   'topic': 'world_has_new_war'}]

# %%
pprint.pprint(embeddings.search(f"select * from txtai where similar('China is going to hurt the USA') and citation like '%Hague%'"))
# Out:
# []

# %%
pprint.pprint(embeddings.search(f"select id, text, evidence_id, score, topic, tag from txtai where similar('China is going to hurt the USA') and tag like '%Affirmative%'" ))
# Out:
# [{'evidence_id': None,
#   'id': '106321',
#   'score': 0.9788461327552795,
#   'tag': 'Affirmatives',
#   'text': 'Kim’s main argument is that China would not accept the grand '
#           'bargain',
#   'topic': None},
#  {'evidence_id': None,
#   'id': '27706',
#   'score': 0.9782600402832031,
#   'tag': 'Affirmatives',
#   'text': '  relying on the export growth, the economy recovery would go very '
#           'slowly.',
#   'topic': None},
#  {'evidence_id': None,
#   'id': '146847',
#   'score': 0.978130042552948,
#   'tag': 'Affirmatives',
#   'text': 'President Mike Pence? The question is way ahead of where we are',
#   'topic': 'we_you_have_about'}]

# %%
list(nx.all_simple_paths(graph.backend, 10, 20, cutoff = 4))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 list(nx.all_simple_paths(graph.backend, 10, 20, cutoff = 4))
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/algorithms/simple_paths.py:266, in _all_simple_paths_graph(G, source, targets, cutoff)
#     264 visited[child] = None
#     265 if targets - set(visited.keys()):  # expand stack until find all targets
# --> 266     stack.append(iter(G[child]))
#     267 else:
#     268     visited.popitem()  # maybe other ways to child
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/classes/graph.py:476, in Graph.__getitem__(self, n)
#     452 def __getitem__(self, n):
#     453     """Returns a dict of neighbors of node n.  Use: 'G[n]'.
#     454
#     455     Parameters
#    (...)
#     474     AtlasView({1: {}})
#     475     """
# --> 476     return self.adj[n]
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/classes/graph.py:355, in Graph.adj(self)
#     338 @property
#     339 def adj(self):
#     340     """Graph adjacency object holding the neighbors of each node.
#     341
#     342     This object is a read-only dict-like structure with node keys
#    (...)
#     353     For directed graphs, `G.adj` holds outgoing (successor) info.
#     354     """
# --> 355     return AdjacencyView(self._adj)
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/classes/coreviews.py:44, in AtlasView.__init__(self, d)
#      41 def __setstate__(self, state):
#      42     self._atlas = state["_atlas"]
# ---> 44 def __init__(self, d):
#      45     self._atlas = d
#      47 def __len__(self):
#
# KeyboardInterrupt:

# %%
list(nx.all_shortest_paths(graph.backend, 10, 60))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 list(nx.all_shortest_paths(graph.backend, 10, 60))
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/generic.py:493, in all_shortest_paths(G, source, target, weight, method)
#     491 method = "unweighted" if weight is None else method
#     492 if method == "unweighted":
# --> 493     pred = nx.predecessor(G, source)
#     494 elif method == "dijkstra":
#     495     pred, dist = nx.dijkstra_predecessor_and_distance(G, source, weight=weight)
#
# File ~/anaconda3/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/unweighted.py:509, in predecessor(G, source, target, cutoff, return_seen)
#     507 for w in G[v]:
#     508     if w not in seen:
# --> 509         pred[w] = [v]
#     510         seen[w] = level
#     511         nextlevel.append(w)
#
# KeyboardInterrupt:

# %%
def david_distance(source, target, attrs):
    distance = max(1.0 - attrs["weight"], 0.0)
    return distance if distance >= 0.15 else 1.00

def david_showpath(source, target, the_graph):
    return nx.shortest_path(the_graph, source, target, david_distance)

# %% [markdown]
# The embeddings index is now created. Let's explore!

# %% [markdown]
# # Graph analysis
#
# Indexing an embeddings instance into a graph adds the ability to do network analysis. For example, the centrality of the graph can be analyzed to find the most common nodes. Alternatively, pagerank could also be run to rank the importance of nodes within the dataset.
#
# The section below runs graph centrality and shows the associated topic for the most central nodes. Not surprisingly, many of the topics are top topics.

# %% [markdown]
# # Walk the graph
#
# Given that graphs are nodes and relationships, we can traverse the nodes using those relationships. The graph can be used to show how any two nodes are connected.

# %%
from IPython.display import HTML
import string

def highlight(index, result):
  output = f"{index}. "
  spans = [(token, score, "#fff59d" if score > 0.01 else None) for token, score in result["tokens"]]

  for token, _, color in spans:
    output += f"<span style='background-color: {color}'>{token}</span> " if color else f"{token} "

  return output

def showpath(source, target, strip_punctuation = True, the_graph=graph.backend):
  path = david_showpath(source, target, the_graph)
  print(path)
  path = [graph.attribute(p, "text") for p in path]
  list_of_evidence_ids = []
  for text in path:
    if strip_punctuation:
        text = text.translate(str.maketrans("","", string.punctuation))
    list_of_evidence_ids.append(embeddings.search(f"select evidence_id from txtai where similar('{text}') limit 1")[0]['evidence_id'])
  print(list_of_evidence_ids)

  sections = []
  for x, p in enumerate(path):
      if x == 0:
          # Print start node
          
          sections.append(f"{x + 1}. {p}")
          sections.append(dataset["Abstract"][list_of_evidence_ids[x]])
          sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Full-Document"][list_of_evidence_ids[x]])

      if x < len(path) - 1:
          # Explain and highlight next path element
          results = embeddings.explain(p, [path[x + 1]], limit=1)[0]
          sections.append(highlight(x + 2, results))
          sections.append(dataset["Abstract"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Full-Document"][list_of_evidence_ids[x+1]])

  return HTML("<br/><br/>".join(sections))

def showpath_any(list_of_arguments, strip_punctuation = True, the_graph=graph.backend):
  list_of_paths = []
  for x, y in zip(list_of_arguments, list_of_arguments[1:]):
    a_path = david_showpath(x, y, the_graph)
    list_of_paths.extend(a_path)
  #print(list_of_paths)
  path = [graph.attribute(p, "text") for p in list_of_paths]
  list_of_evidence_ids = []
  for text in path:
    if strip_punctuation:
        text = text.translate(str.maketrans("","", string.punctuation))
    list_of_evidence_ids.append(int(embeddings.search(f"select id from txtai where similar('{text}') limit 1")[0]['id']))
  print(list_of_evidence_ids)

  sections = []
  for x, p in enumerate(path):
      if x == 0:
          # Print start node
          
          sections.append(f"{x + 1}. {p}")
          #sections.append(dataset["Abstract"][list_of_evidence_ids[x]])
          #sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          #sections.append(dataset["Full-Document"][list_of_evidence_ids[x]])

      if x < len(path) - 1:
          # Explain and highlight next path element
          results = embeddings.explain(p, [path[x + 1]], limit=1)[0]
          sections.append(highlight(x + 2, results))
          #sections.append(dataset["Abstract"][list_of_evidence_ids[x+1]])
          #sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          #sections.append(dataset["Full-Document"][list_of_evidence_ids[x+1]])

  return HTML("<br/><br/>".join(sections))

def showpath_list(list_of_path, strip_punctuation = True):
  path = list_of_path
  path = [graph.attribute(p, "text") for p in path]
  list_of_evidence_ids = []
  for text in path:
        if strip_punctuation:
            text = text.translate(str.maketrans("","", string.punctuation))
        list_of_evidence_ids.append(embeddings.search(f"select evidence_id from txtai where similar('{text}') limit 1")[0]['evidence_id'])
  print(list_of_evidence_ids)
  sections = []
  for x, p in enumerate(path):
      if x == 0:
          # Print start node
          
          sections.append(f"{x + 1}. {p}")
          sections.append(dataset["Abstract"][list_of_evidence_ids[x]])
          sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Full-Document"][list_of_evidence_ids[x]])


      if x < len(path) - 1:
          # Explain and highlight next path element
          results = embeddings.explain(p, [path[x + 1]], limit=1)[0]
          sections.append(highlight(x + 2, results))
          sections.append(dataset["Abstract"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Citation"][list_of_evidence_ids[x+1]])
          sections.append(dataset["Full-Document"][list_of_evidence_ids[x+1]])


  return HTML("<br/><br/>".join(sections))

# %%
selected_nodes = [n for n,v in graph.backend.nodes(data=True) if "z" in v['text']] ##also works for topic
selected_nodes
H = graph.backend.subgraph(selected_nodes)
list(H.nodes(data=True))
# Out:
# [(0,
#   {'text': 'A) The Affirmatives construction of a “Nation-Space” manifests in distinction to a colonized Other- locking the colonial Other in a violent cycle. ',
#    'topic': 'alternative_other_from_only',
#    'topicrank': 11}),
#  (1,
#   {'text': 'Use of the term modernization is a blanket to cover colonization '}),
#  (2,
#   {'text': 'The projection of power portrayed of the US gave them an entitled sense of superiority. The American ideas of “modernization” are all really outgrowths of what we believed to be progress.'}),
#  (131072,
#   {'text': 'Their performative locus is a re-elaboration and consolidation of anti-black practices that is unable to challenge militarization and achieve emancipation/agency for black bodies.',
#    'topic': 'anti_violence_through_coalitions',
#    'topicrank': 14}),
#  (131077,
#   {'text': 'Suppression of Indigenous cultures causes dehumanization of natives – prioritize ongoing cultural violence '}),
#  (131079,
#   {'text': 'Providing an equal education to native Americans is critical to equality – util based impact calculus always profits the majority – rather, impact calculus must prioritize a multicultural consciousness that takes into account the historical and institutional roots of oppression and inherently values minorities and diversity’s place ',
#    'topic': 'every_impact_we_federalism',
#    'topicrank': 8}),
#  (8,
#   {'text': 'Epistemological decolonization is key to liberating those imprisoned by coloniality. '}),
#  (131082,
#   {'text': 'Prioritize Violence against Native Americans –anything else falls back into the current exclusionary narrative because they are historically always pushed aside in policy making decisions ',
#    'topic': 'have_us_immigrants_violence',
#    'topicrank': 9}),
#  (13,
#   {'text': 'Western European globalization is the root cause for environmental exploitation – Western identity sees nature as a frontier to be tamed, whereas the natives were one with nature',
#    'topic': 'our_we_nature_environmental',
#    'topicrank': 27}),
#  (15,
#   {'text': 'Colonization leads to racism. ',
#    'topic': 'racism_policy_violence_racial',
#    'topicrank': 23}),
#  (131087,
#   {'text': 'Culturally Responsive Education is necessary to deconstruct colonialism – it’s a fundamental departure from normalized education practices and important for the preservation of Native American Cultures ',
#    'topic': 'education_native_american_trump',
#    'topicrank': 5}),
#  (18,
#   {'text': 'Colonization of the “Other” leads to an Increasingly Violent Struggle of Life and Death'}),
#  (19,
#   {'text': 'Colonialization Leads to Absolute Otherization and Racial Terror'}),
#  (20,
#   {'text': 'Genocide and Civil War is an inevitable product of postcolonial thinking—it banalizes political violence against the colonized',
#    'topic': 'genocide_violence_war_native',
#    'topicrank': 4}),
#  (24,
#   {'text': 'Even though nation states are the most organized political sites in the world, some nation states are clearly positioned differently, which is an outgrowth of the coloniality and imperiality formerly imposed on the post colonial countries. Reject the aff-it embodies the colonial mindset.',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 52}),
#  (27,
#   {'text': 'In the colonial situation a desire of the Colony to destroy the colonized perpetuates a system of violence-only resisting the desire to become colonizer can the violence be overthrown through a symbolic upheaval. ',
#    'topic': 'only_through_can_which',
#    'topicrank': 2}),
#  (28,
#   {'text': 'Decolonization creates a free flow of subjectivity where race, sex, and gender dynamics can be dismantled from the war frame constituting the colonial situation. ',
#    'topic': 'gender_from_which_can',
#    'topicrank': 0}),
#  (29,
#   {'text': 'Decolonizing knowledge and being is essential in bringing down coloniality. '}),
#  (30,
#   {'text': 'Epistemic de-colonization collapses and delinks the political with coloniality ',
#    'topic': 'political_inevitable_delegitimizes_coloniality',
#    'topicrank': 0}),
#  (31,
#   {'text': 'Mimcry breaks out of the traditional notion of colonization. '}),
#  (33,
#   {'text': 'The alternative is to reject the aff – epistemological decolonization is necessary to clear the way for intercultural communication. Only then, can we liberate those who are imprisoned by coloniality. ',
#    'topic': 'only_our_which_we',
#    'topicrank': 6}),
#  (131106,
#   {'text': 'Universalizing settler-colonialism is bad – it does not determine future possibility. '}),
#  (35,
#   {'text': 'The criticism of capitalism is rooted in westernized, Eurocentric view of the world that colonized in the first place. ',
#    'topic': 'we_capitalism_western_human',
#    'topicrank': 10}),
#  (131108,
#   {'text': 'Tying all of settler colonialism to land claims is bad – it essentializes Native identity and re-creates the logic of a unified nation-state. ',
#    'topic': 'state_key_supremacy_ir',
#    'topicrank': 18}),
#  (38,
#   {'text': 'The ethnicity paradigmof the permutation obscurely homogenizes colonial history of exploitation and raciailized difference '}),
#  (131110,
#   {'text': 'The aff turns vampirism – a critique of structural injustice contextualizes vulnerability and emphasizes material suffering while avoiding sentimentality.'}),
#  (131114,
#   {'text': 'Infusing the aff methodology and interrogation into legal solutions ruptures the intelligibility of settler colonialism and creates meaningful progress and reinterpretation of the liberal rights they criticize --- 1ac politicizes dominant state-corporate relations that relegate indigenous populations which avoids cooption by the dominant legal order '}),
#  (45,
#   {'text': 'Postcolonial Thought mimics colonial thought it criticizes and only uses the colonial Other as a justification for its existence. ',
#    'topic': 'colonial_decolonization_through_indigenous',
#    'topicrank': 14}),
#  (131117,
#   {'text': 'School choice fails to address needs of communities and glazes over cultural struggles etc- '}),
#  (55,
#   {'text': 'Failure to achieve the desired result in democracy is not a reason to reject democracy perm can be the unrealized. ',
#    'topic': 'political_can_democracy_only',
#    'topicrank': 2}),
#  (131128,
#   {'text': 'Charter schools are controlled, organized, funded, and managed by the states',
#    'topic': 'can_states_government_data',
#    'topicrank': 7}),
#  (62,
#   {'text': 'The United States federal government should substantially increase its debt relief efforts toward Venezuela.',
#    'topic': 'should_united_states_government',
#    'topicrank': 36}),
#  (131135,
#   {'text': 'States should ordain and establish reparations as educational funding for the disenfranchisement of black people, sets a precedent for other racialized policy reparations'}),
#  (64,
#   {'text': 'Venezuelan debt is the critical issue-foreign exchange is key',
#    'topic': 'key_issue_state_most',
#    'topicrank': 21}),
#  (66,
#   {'text': 'Post-Chavez US-Venezuela ties vital to prevent Iran proliferation ',
#    'topic': 'us_relations_post_chavez',
#    'topicrank': 3}),
#  (68,
#   {'text': 'Chavez’s death makes now key',
#    'topic': 'chavez_key_regulations_death',
#    'topicrank': 0}),
#  (69,
#   {'text': 'Economic engagement with Venezuela bolsters US credibility-it spills over',
#    'topic': 'us_china_taiwan_credibility',
#    'topicrank': 7}),
#  (71,
#   {'text': 'Petro Caribe collapse coming now-Venezuelan debt is the reason-it spills over',
#    'topic': 'us_now_key_influence',
#    'topicrank': 13}),
#  (72,
#   {'text': 'Oil is key to Venezuelan stability-debt relief is key',
#    'topic': 'key_oil_stability_us',
#    'topicrank': 1}),
#  (73,
#   {'text': 'Venezuelan oil is key to global oil stability',
#    'topic': 'stability_key_economic_us',
#    'topicrank': 106}),
#  (131143,
#   {'text': 'Utilizing ESSA’s whole school whole student approach is key to solvency for funding aimed at students in poverty, ELLs, and students with special needs'}),
#  (77,
#   {'text': 'That causes Brazilian nuclear re-arm',
#    'topic': 'nuclear_war_causes_us',
#    'topicrank': 19}),
#  (83,
#   {'text': 'U.S. should cancel debt that disproportionately punishes the citizens for the faults of regimes taking out loans to serve western interests',
#    'topic': 'courts_have_state_interests',
#    'topicrank': 9}),
#  (84,
#   {'text': 'Cancellation of Venezuela’s debt is a key step to breaking down the global neoliberal system',
#    'topic': 'economy_neoliberal_debt_venezuela',
#    'topicrank': 0}),
#  (85,
#   {'text': 'SAP’S force governments to cut back on programs to help its citizens and force it to conform to western standards of economic prosperities- furthering the poverty inside the indebted countries ',
#    'topic': 'cause_economy_us_economic',
#    'topicrank': 12}),
#  (86,
#   {'text': 'Previous SAP’s in Venezuela are the cause of the governmental problems that have played out throughout venezuela’s history'}),
#  (90,
#   {'text': 'PVDSA is unsustainable—Venezuela cant keep up',
#    'topic': 'unsustainable_growth_lack_economic',
#    'topicrank': 34}),
#  (91,
#   {'text': 'Lower debt allows Venezuela to stabilize oil prices ',
#    'topic': 'economy_prices_oil_high',
#    'topicrank': 60}),
#  (131164,
#   {'text': 'Our alternative is to endorse an Afro-pessimist ideology – it allows us to navigate our lives through civil society more effectively through analyzing the oppressive structures imbedded within the past and the present'}),
#  (131165,
#   {'text': 'Our analysis of racialized education goes beyond just an analysis and is a prior question to any solvency mechanism',
#    'topic': 'question_prior_aff_vote',
#    'topicrank': 8}),
#  (95,
#   {'text': 'Empirics prove PVDSA k2 Venezuelan stability',
#    'topic': 'empirics_prove_impact_fails',
#    'topicrank': 46}),
#  (96,
#   {'text': 'Venezuelan debt is dragging OPEC down ',
#    'topic': 'down_china_key_cracking',
#    'topicrank': 17}),
#  (131168,
#   {'text': 'School is a liminal space where black youth are dehumanized '}),
#  (131176,
#   {'text': 'Citizenship is an obstacle, not a conduit, of black liberation, their attempt to desegregate schools is a subtle attempt at assimilating and destroying black subjectivity',
#    'topic': 'schools_racial_segregation_communities',
#    'topicrank': 22}),
#  (131179,
#   {'text': 'Desegregation is a nice word for assimilation – they try and mold the black body into the “perfect black citizen” that acts white, seems white, and feels white',
#    'topic': 'black_blackness_white_can',
#    'topicrank': 10}),
#  (131182,
#   {'text': 'Privatization, standardized testing, and charter schools are all examples of reform that have put black bodies at a structural disadvantage within educational spaces',
#    'topic': 'school_schools_students_education',
#    'topicrank': 591}),
#  (131186,
#   {'text': 'They posit an equal, democratic society as the end goal of their project – this fails to recognize that democracy itself necessitates anti-black violence '}),
#  (117,
#   {'text': 'NAFTA minimized the effect of exchange rate fluctuations – external demand',
#    'topic': 'empirics_nafta_trade_economic',
#    'topicrank': 10}),
#  (131189,
#   {'text': 'Their attempt to solve climate change through innovation ignores the racialization of space and mobility that has made rapid climate change possible',
#    'topic': 'climate_change_inevitable_impact',
#    'topicrank': 13}),
#  (131190,
#   {'text': 'Freire fails to adequately theorize black positionality and denies black existence',
#    'topic': 'plan_border_circumvented_fails',
#    'topicrank': 8}),
#  (131191,
#   {'text': 'Their attempt to analogize the conditions of the black body and Native Americans is flawed – violence inflicted upon natives operates within the humanist language that necessarily excludes blackness'}),
#  (131195,
#   {'text': 'Black political literacy is uniquely key to racial progress---grassroots political activism drove successful education movements like Brown v Board---unaffiliated movements merely fizzled out',
#    'topic': 'discourse_activism_black_policy',
#    'topicrank': 4}),
#  (131203,
#   {'text': 'Anti-blackness isn’t totalizing – learning can act as a site for black marronage and futigivity instead of black suffering',
#    'topic': 'black_blackness_anti_education',
#    'topicrank': 1}),
#  (131208,
#   {'text': 'Confining black liberation to political rejection delegitimizes progressive potential--- keeps the current political stationary ',
#    'topic': 'political_inevitable_delegitimizes_coloniality',
#    'topicrank': 2}),
#  (131214,
#   {'text': 'They misread Patterson – social death isn’t totalizing',
#    'topic': 'isn_doesn_key_capital',
#    'topicrank': 21}),
#  (131243,
#   {'text': 'The plan upsets the delicate balance between centralization and decentralization that upholds disciplined devolution. '}),
#  (131244,
#   {'text': 'Federal wins on education generate constituencies for further federalization '}),
#  (189,
#   {'text': 'Expropriating the term “American” is offensive---using one term to describe a diverse and complex nation inevitably dehumanizes the indigenous populations'}),
#  (190,
#   {'text': 'Their description of Latin America denies cultural difference and enforces generalizations which are essentially racism in disguise---not only is it historically inaccurate, but it also denies political independence by pinning the country with their European and American imperialist heritage',
#    'topic': 'which_racial_order_white',
#    'topicrank': 16}),
#  (191,
#   {'text': 'The term “Latin America” is an overarching claim that serves to marginalize and dehumanize minorities---this strips them of their cultural identity and is a social primer for exclusion'}),
#  (131262,
#   {'text': 'Uniform, unflexible federal standards fail to create positive educational outcomes – takes influence away from local leaders geared towards student improvement and creates a one-size-fits-all approach. ',
#    'topic': 'triangulate_attempts_fail_from',
#    'topicrank': 3}),
#  (215,
#   {'text': 'The plan doesn’t trigger that much new oil---Cuba’s reserves are half the size of ANWR',
#    'topic': 'can_solve_doesn_isn',
#    'topicrank': 64}),
#  (131289,
#   {'text': 'Formula grants subsidize the status quo – competitive grants allow for innovation to improve education ',
#    'topic': 'stem_education_key_students',
#    'topicrank': 51}),
#  (233,
#   {'text': 'THREAT CONSTRUCTION – the fear of transition violence is what the totality of our argument is criticizing – their focus is an attempt to justify continued imperialist violence – the totality of the link and impact debate are responsive to this argument ',
#    'topic': 'our_debate_argument_should',
#    'topicrank': 0}),
#  (252,
#   {'text': 'Legalization is an Uphill fight - unpopular',
#    'topic': 'unpopular_plan_congress_public',
#    'topicrank': 170}),
#  (265,
#   {'text': 'Investing in Venezuelan oil drains money - Castro’s nationalization and recent trends',
#    'topic': 'oil_causes_collapse_economy',
#    'topicrank': 25}),
#  (269,
#   {'text': 'The affirmative’s geopolitical imaginary is characterized by a wholly enclosed land space of bounded nation-states. This only serves the interests of status quo power hierarchies through the construction of an inside to be secured against a dangerous outside, excepted from the law Such an order can only be maintained thought he constant policing of the inside and warfare externally.',
#    'topic': 'only_through_can_which',
#    'topicrank': 7}),
#  (270,
#   {'text': 'And, the construction of the US-Mexico border stabilizes American identity around the racist projection of lawlessness and barbarity onto the Mexican other in need of domination. ',
#    'topic': 'us_control_border_american',
#    'topicrank': 0}),
#  (271,
#   {'text': 'This construction of civilization around state borders is a colonial artifact. It undergirds the justification for the affirmative’s intervention into Mexico to stabilize, develop and extract resources from the barbaric other. ',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 28}),
#  (274,
#   {'text': 'Taking Cuba of the terror list only consolidates a world order founded on the colonization of space instantiated in the world map of bounded nation-states, reproducing colonial knowledge through the language of the 1AC. This short-circuits the border thinking that allows a break from the colonial structure of modernity.',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 55}),
#  (275,
#   {'text': 'Also, you should be skeptical of their engagement with Cuba – expanding American geopolitical influence in the region only serves to further the goals of US regional domination and the securitization of borders.',
#    'topic': 'china_us_western_american',
#    'topicrank': 4}),
#  (279,
#   {'text': 'Next, International law legitimizes colonial cartographies and historical borders which perpetuate the logic of colonial domination ',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 40}),
#  (285,
#   {'text': 'The revolutions that create new states gives way to an authority that legitimizes law and justifies the violence of the law'}),
#  (287,
#   {'text': '{**In CUBA Teror 1NC**} The development discourse of the aff are a prime example of the borders created in our minds that propagate hegemonic politics and are the root cause of transnational neoliberal globalization',
#    'topic': 'neoliberal_global_form_which',
#    'topicrank': 25}),
#  (289,
#   {'text': 'Separating the foreign and the domestic forms an inside/outside dichotomy that obscures the process of globalization',
#    'topic': 'dichotomy_public_private_alternative',
#    'topicrank': 45}),
#  (290,
#   {'text': 'Globalization ushers in an unequal access to wealth, resulting in notions of deterritorialization. Innerconnectivity brings problems with governance and securitization to the forefront. '}),
#  (131363,
#   {'text': 'Terror has been weaponized by the US government and media as a method for maintaining their hegemony, cultural and otherwise.',
#    'topic': 'war_terror_has_violence',
#    'topicrank': 11}),
#  (296,
#   {'text': 'Human rights discourse is rooted in Western predistenation, assuming the necessity of an imperial mission to civilize the inferior, undeveloped.'}),
#  (299,
#   {'text': 'The politics of separation and spatial exclusion in the name of “safety” and protection from “hazards” causes ecological wellbeing to become a second thought. The interconnected nature of the world means we must deconstruct the image of borders as a tool for demarcation',
#    'topic': 'border_borders_between_which',
#    'topicrank': 51}),
#  (300,
#   {'text': 'Securing the environment otherizes states that cannot cope with unsustainable development causing violence leading to their impacts- also elevating environmental destruction destroys personal agency towards the problem killing any chance of solvency ',
#    'topic': 'nuclear_war_environment_environmental',
#    'topicrank': 4}),
#  (303,
#   {'text': 'Competitiveness rhetoric is the newest manifestation of border violence – cities become organized around regional wealth accumulation which creates new forms of spatial division',
#    'topic': 'causes_racial_which_inevitably',
#    'topicrank': 4}),
#  (307,
#   {'text': 'International law draws the borders, and thus, the identities of the population of states. This collectivized categorization creates stigmatization and alienation of the "Other".'}),
#  (308,
#   {'text': 'International law’s authority ends at the borders of the nation-state. The reinforcement of international law upholds the modern nation-state and allows for the creation of the artificial citizen',
#    'topic': 'state_sovereignty_sovereign_violence',
#    'topicrank': 48}),
#  (311,
#   {'text': 'State spaces and borders bring about the violent conceptualization of neoliberal policies',
#    'topic': 'indigenous_borders_identities_power',
#    'topicrank': 11}),
#  (313,
#   {'text': 'The neoliberal agenda crowds our any non-market solutions and imposes the will of globalization on populations',
#    'topic': 'global_globalization_power_china',
#    'topicrank': 14}),
#  (131393,
#   {'text': 'Lack of support measures makes it so that many special education services for military families are heavily underutilized because the families cant afford the programs',
#    'topic': 'school_schools_students_education',
#    'topicrank': 314}),
#  (324,
#   {'text': 'Organizing at the level of the state leaves the global capital processin place leaving in place the global division of labor',
#    'topic': 'state_from_any_power',
#    'topicrank': 24}),
#  (325,
#   {'text': 'Representations of disasters create an spectator/victim dichotomy that results in the traumatized victims being subjugated to biopolitical control for their own protection'}),
#  (328,
#   {'text': '{**In Cuba Terror and Policy 1NC**}You should be skeptical of their engagement with Cuba – expanding American geopolitical influence in the region only serves to further the goals of US hegemony and the securitization of borders.',
#    'topic': 'china_us_western_american',
#    'topicrank': 8}),
#  (332,
#   {'text': 'Homogenizing islands saps island identities and enables domination by great powers',
#    'topic': 'indigenous_borders_identities_power',
#    'topicrank': 8}),
#  (334,
#   {'text': '{**In the Mexico Oil 1NC**} The construction of the US-Mexico border stabilizes American identity around the racist projection of lawlessness and barbarity onto the Mexican other in need of domination.',
#    'topic': 'us_control_border_american',
#    'topicrank': 1}),
#  (335,
#   {'text': 'The process of policing immigration along the US-Mexico border reinforces otherization and alienation of migrants.',
#    'topic': 'border_us_mexico_between',
#    'topicrank': 10}),
#  (337,
#   {'text': 'The US- Mexico border is a one sided, racist system based on a collaboration of securitization and globalization- globalization necessitates securitization while creating and reinforcing social inequalities ',
#    'topic': 'social_global_violence_migration',
#    'topicrank': 8}),
#  (338,
#   {'text': 'In an attempt to resolve the security/economy contradiction of the US-Mexico border, the United States has expanded the border by localization inwardly and preemption outwardly. ',
#    'topic': 'border_us_mexico_between',
#    'topicrank': 17}),
#  (339,
#   {'text': 'Discourse based on the dichotomy of chaos and order along the border allow the region to be controlled and securitize migrants as a threat to be eliminated.',
#    'topic': 'border_violence_borders_security',
#    'topicrank': 18}),
#  (342,
#   {'text': 'The collapse of economic barriers is followed by an influx of permanent securitization.',
#    'topic': 'economic_collapse_through_reform',
#    'topicrank': 6}),
#  (344,
#   {'text': 'The creation of the North American Free Trade Agreement turned Mexico into yet another casualty of American expansionism. This can be compared to the fascist economic policies of Nazi Germany in WW2 '}),
#  (345,
#   {'text': 'NAFTA turned Mexico into a base to increase American hegemony in the region. This turned Latin America into the U.S.’s “new order” that does nothing but further the spread of globalization and imperialist policies',
#    'topic': 'us_global_state_american',
#    'topicrank': 21}),
#  (348,
#   {'text': 'Crossing the border is an ontological experience. War on Terror discourse turns “friendly” borders into “leaky” borders, and the securitization of borders categorize individuals as inadmissible, detainee, or deportable. ',
#    'topic': 'surveillance_from_war_state',
#    'topicrank': 13}),
#  (349,
#   {'text': 'The system of transportation necessitated by trade and globalization creates a violent networked border',
#    'topic': 'global_globalization_power_china',
#    'topicrank': 12}),
#  (350,
#   {'text': 'Using ID politics for social movements recreates sovereign power since the borders of the state created those identities- destabilizing the system comes first',
#    'topic': 'identity_politics_state_power',
#    'topicrank': 0}),
#  (354,
#   {'text': 'Analyzing the way states re-inscribe borders is fundamental to broader understandings of their political structures ',
#    'topic': 'state_political_alternative_only',
#    'topicrank': 7}),
#  (357,
#   {'text': 'We must reject the homogenization of identity by which the state justifies violence through the domestication of alterity. An encounter with the Other is a recognition of their difference and exteriority ',
#    'topic': 'violence_forms_state_all',
#    'topicrank': 5}),
#  (365,
#   {'text': 'The alternative is denizenry—abandoning political citizenship renders borders useless',
#    'topic': 'citizenship_state_from_alternative',
#    'topicrank': 0}),
#  (369,
#   {'text': 'The purpose of the “other” is only to affirm the identity of the oppressor. The creation of state identity is only possible through antagonizing the “other”',
#    'topic': 'state_oppression_other_violence',
#    'topicrank': 5}),
#  (372,
#   {'text': 'Cognitive science proves that categorization via the creation of borders is the root of us-them distinctions ',
#    'topic': 'from_borders_based_starting',
#    'topicrank': 2}),
#  (373,
#   {'text': 'Borders are the root cause of us-them dichotomies that cause violence and securitization',
#    'topic': 'border_violence_borders_security',
#    'topicrank': 3}),
#  (374,
#   {'text': 'State borders fueled the designation of terrorists and a militarized response',
#    'topic': 'war_violence_militarized_state',
#    'topicrank': 1}),
#  (379,
#   {'text': 'Borders create a mutual xenophobic otherization of those across the border- this causes zones of structural violence that devalue lives.'}),
#  (380,
#   {'text': 'The re-entrenching of economic and social inequality is symptomatic of the 1AC’s globalization of Latin America. Latin American economies become dependent on the hegemon eliminating economic sovereignty while social exclusion and the separation from higher and lower classes creates a larger divide. ',
#    'topic': 'poverty_trade_solves_inequality',
#    'topicrank': 33}),
#  (385,
#   {'text': 'Securitized borders result in extraordinary rendition and spaces of exception – those outside of the US State border are rendered inhuman',
#    'topic': 'border_us_mexico_between',
#    'topicrank': 28}),
#  (390,
#   {'text': 'A framework for debate totalizes discussion and other forms of politics- turns education and locks in current border dialogue',
#    'topic': 'debate_policy_necessary_framework',
#    'topicrank': 2}),
#  (392,
#   {'text': 'Focus on discourse and representations is key in the context of our criticism – threat construction and the securitization of national identities legitimize violent intervention in the name of United States hegemony – critical analysis is necessary.',
#    'topic': 'discourse_aff_our_us',
#    'topicrank': 5}),
#  (400,
#   {'text': 'The permutation cannot solve; economic interactions are entirely insulated from politicization and the material effects of the plan – questions of territory and societal perceptions permeate economic calculations in the context of Venezuela. ',
#    'topic': 'its_how_from_must',
#    'topicrank': 8}),
#  (131473,
#   {'text': 'State vouchers fail—Arizona proves no accountability means wasted funds',
#    'topic': 'key_fail_plan_money',
#    'topicrank': 3}),
#  (406,
#   {'text': 'These exclusionary borders help reinforce this epistemology inherent in the us/them dichotomy that leads to the otherization of anyone that is on the “outside”',
#    'topic': 'border_borders_between_which',
#    'topicrank': 40}),
#  (408,
#   {'text': 'Geopolitical binaries are not physical; rather, they serve as psychological structuring mechanisms – the alternate must problematize conventional categorization to open new spaces for classification. '}),
#  (131483,
#   {'text': 'The plan normalizes Trump’s agenda by making him appear pragmatic — that collapses democratic resistance ',
#    'topic': 'trump_his_any_us',
#    'topicrank': 23}),
#  (131489,
#   {'text': 'Trump bolsters the neoliberal regime and continues to secure and embolden otherization '}),
#  (419,
#   {'text': 'Borderlands are utilized as "transition zones" for the acclimatization of one culture into another. Rather than a strict dividing line, borders represent regions of negotiation and a mixture of different identities.',
#    'topic': 'border_borders_between_which',
#    'topicrank': 45}),
#  (425,
#   {'text': 'Construction of borders involve citizens and give people autonomy '}),
#  (131515,
#   {'text': 'Emergency thinking over-prioritizes timeframe – obscures collective responsibility and prevents imagining a better future.'}),
#  (131535,
#   {'text': 'Segregation and suburbanization destroyed schools',
#    'topic': 'school_schools_students_education',
#    'topicrank': 132}),
#  (131536,
#   {'text': 'Suburbanization caused massive amounts of warming and obscures the history of white flight – the aff is key to understand emissions '}),
#  (131537,
#   {'text': 'The Supreme Court must affirm the use of dignity to open a space that combats segregation and its ability to degrade, dishonor, isolate, and ostracize.'}),
#  (467,
#   {'text': 'Brazilian Sugar Ethanol does not cause deforestation',
#    'topic': 'deforestation_cause_warming_extinction',
#    'topicrank': 25}),
#  (131544,
#   {'text': 'Rethinking spatial justice requires rejecting utilitarianism. Their moral system relies on abstract calculation – affirming an ethics of place is the only way to re-connect transportation, the built environment, and marginalized communities. '}),
#  (131549,
#   {'text': '6.Precedent Solvency Deficit- Milliken v Bradley makes segregation untouchable and prevents desegregation policies from working-overturn is key- that’s Hertz 14, Bracey 5, and Orfield 10',
#    'topic': 'desegregation_key_schools_school',
#    'topicrank': 38}),
#  (131557,
#   {'text': 'Legalizing online gambling drains the economy and wrecks society'}),
#  (131558,
#   {'text': 'State courts are ineffective in minimizing educational inequality – empirics prove (links to court clog)'}),
#  (490,
#   {'text': 'Chinese economic relations with Venezuela are becoming promising.'}),
#  (131562,
#   {'text': '4.Precedent Solvency Deficit- Milliken v Bradley makes segregation untouchable and prevents desegregation policies from working-Supreme Court overturn is key- that’s Hertz 14, Bracey 5, and Orfield 10',
#    'topic': 'court_supreme_decisions_proves',
#    'topicrank': 76}),
#  (494,
#   {'text': 'Economic Politics are zero sum',
#    'topic': 'zero_sum_now_china',
#    'topicrank': 5}),
#  (495,
#   {'text': 'Any interruptions with developing ties between China and Mexico will destabilize the Chinese economy.',
#    'topic': 'us_china_economic_from',
#    'topicrank': 16}),
#  (496,
#   {'text': 'China is dependent on Mexico for its supply of oil. Other counties’ investments will destabilize China’s economy. ',
#    'topic': 'economy_russia_oil_its',
#    'topicrank': 2}),
#  (131570,
#   {'text': '8. Actualizing potential is a fundamental human characteristic---without it, there is no material world. And, actualizing potential is key to community—all connected through potential. Prefer our evidence from a scientist '}),
#  (131573,
#   {'text': 'Their K is totalizing—their gestural politics towards im-potentiality don’t resolve their impacts, it’s try-or-die for reformism. '}),
#  (131574,
#   {'text': 'Schools are inevitable—Non-institutional study and institutionalized schooling are not only compatible, but the only option'}),
#  (131575,
#   {'text': 'Critical pedagogy within schools can reveal the system’s flaws without deinstitutionalization. ',
#    'topic': 'school_schools_students_education',
#    'topicrank': 381}),
#  (131579,
#   {'text': 'Sovereignty don’t imply the Nazis—the plan is a justified use of sovereign power to prevent catastrophe. '}),
#  (512,
#   {'text': 'Text: The United States federal government should enter into prior binding consultation with the Federative Republic of Brazil [over the plan]',
#    'topic': 'should_united_states_government',
#    'topicrank': 119}),
#  (131586,
#   {'text': 'The role of the ballot is to maximize the lives saved—util gives equality to all beings which preserves dignity and short circuits “value to life” claims. ',
#    'topic': 'life_human_rights_value',
#    'topicrank': 31}),
#  (131588,
#   {'text': 'The impact is inevitable – the “institutionalized values” they criticize are produced by everyday social processes and the alt can’t overcome',
#    'topic': 'can_its_utilitarianism_inevitable',
#    'topicrank': 6}),
#  (131592,
#   {'text': 'Work is inevitable and the alternative trades off with labor organization – cements economic inequality and turns their impact',
#    'topic': 'turns_economic_wages_growth',
#    'topicrank': 4}),
#  (131607,
#   {'text': 'Establishing a right to education is in the direction of the alt – challenges privatization and shift towards school choice',
#    'topic': 'education_direction_reform_right',
#    'topicrank': 1}),
#  (553,
#   {'text': 'Absolute zero risk of Mexican collapse---everything’s super-resilient ',
#    'topic': 'collapse_self_now_correcting',
#    'topicrank': 30}),
#  (131635,
#   {'text': 'The impact is the annihilation of sexual difference – this social organization of masculine over feminine justifies perpetual physical-psychological war',
#    'topic': 'feminine_masculine_women_masculinity',
#    'topicrank': 29}),
#  (566,
#   {'text': 'US-Mexican drug cooperation fails and has opposition from the citizens ',
#    'topic': 'us_relations_china_cooperation',
#    'topicrank': 94}),
#  (131640,
#   {'text': 'The claim that everyone is always already a cyborg is a dangerous form of cultural essentialism that universalizes the western subject and subverts any transformative potential of the 1ac. ',
#    'topic': 'only_which_western_cultural',
#    'topicrank': 1}),
#  (131646,
#   {'text': 'Appropriation DA: the alt recognizies a place of enunciation for the feminine that cannot be reconciled by the perm',
#    'topic': 'feminine_masculine_women_masculinity',
#    'topicrank': 82}),
#  (131656,
#   {'text': 'Recognizing the right to education won’t solve inequality',
#    'topic': 'can_solve_won_without',
#    'topicrank': 3}),
#  (131674,
#   {'text': 'The affirmative is a product of the bill of sale, this allows for the mass genocide of the indigenous culture, and the exploitation and violence upon the black body. Their avoidance of a directly addressing the legal system that only serves as a camouflage of Western modernity (failing to realize that this bill of sale is only repetition of history that perpetrates the supremacist state, and no decision of transportation is therefore legitimate '}),
#  (131675,
#   {'text': 'Their plan is the politics of the prison loaf. Just like people incarcerated in our domestic prisons are provided just enough nutrition not to starve to death, the affirmative deploys human rights and politics at the level of biological health as opposed to social justice.\xa0 This makes the carceral technologies of confinement, capture and dehumanizing social alienation all the more efficient because it conceptually fortifies them from criticisms of bodily harm- ',
#    'topic': 'only_debate_from_world',
#    'topicrank': 19}),
#  (131682,
#   {'text': 'The affirmative’s reach to extend the control of the United States across the globe institutionalizes the fungibility of black bodies into the mold of global politics '}),
#  (613,
#   {'text': 'Exporting LNG to another country requires a long and costly authorization process – uncertainty deters investment ',
#    'topic': 'would_lng_legitimacy_decrease',
#    'topicrank': 10}),
#  (634,
#   {'text': 'Legalizing marijuana solves their drug violence internal link-a continued strategy of prohibition inevitably fails',
#    'topic': 'violence_state_law_domestic',
#    'topicrank': 13}),
#  (635,
#   {'text': 'Current criminalization policies have failed-only legalization can solve the drug war',
#    'topic': 'only_way_can_solve',
#    'topicrank': 0}),
#  (636,
#   {'text': 'US legalization is key to a broader spillover in the region that solves crime',
#    'topic': 'key_crime_solving_economy',
#    'topicrank': 8}),
#  (131720,
#   {'text': 'Privatization is accessible – competition drives downs costs while maintaining quality'}),
#  (655,
#   {'text': 'Monopolies like Gazprom are the manifestation of Putin’s authoritarianism – a “Russian awakening” will happen with US involvement ',
#    'topic': 'us_authoritarian_china_regime',
#    'topicrank': 26}),
#  (131739,
#   {'text': 'Privatizing vaccines through vouchers offers a national immunization plan – competition and economic incentives sponsor innovation '}),
#  (131743,
#   {'text': 'Privatized education is key to the economy – prefer comparative evidence',
#    'topic': 'economy_key_us_oil',
#    'topicrank': 88}),
#  (131751,
#   {'text': 'Congress can rule under the Citizenship Clause',
#    'topic': 'president_congress_executive_has',
#    'topicrank': 40}),
#  (131768,
#   {'text': 'Trump has revitalized federalism — state control of education policy is key. ',
#    'topic': 'federal_state_states_courts',
#    'topicrank': 31}),
#  (131771,
#   {'text': 'Trump has revitalized federalism by letting states take control of education policy. Momentum for the shift in balance of power is essential to cement the long-standing federalist principle — that’s Roberts.',
#    'topic': 'federalism_states_policy_brink',
#    'topicrank': 1}),
#  (704,
#   {'text': 'First, Alt causes- Brazilian paralysis',
#    'topic': 'defense_missile_alt_crash',
#    'topicrank': 6}),
#  (706,
#   {'text': 'And, Amazon resilient – we have best studies and data',
#    'topic': 'our_data_best_evidence',
#    'topicrank': 4}),
#  (131779,
#   {'text': 'Progressive federalism allows states to assert “states’ rights” in bucking Trump’s agenda on a broad range of issues including executive overreach, environmental policies, immigration and marijuana legalization — that’s Chemerinsky.'}),
#  (131782,
#   {'text': 'Federalism is more effective at protecting minority rights and limiting Trump overreach on marijuana legalization and immigration.',
#    'topic': 'immigrants_immigration_discretion_prosecutorial',
#    'topicrank': 13}),
#  (713,
#   {'text': 'First, Ag production high now – mechanization ',
#    'topic': 'solves_mechanization_aff_labor',
#    'topicrank': 20}),
#  (131787,
#   {'text': 'Fair-weather federalism is inevitable due to political polarization — liberals should still embrace the tool.',
#    'topic': 'race_inevitable_space_prevents',
#    'topicrank': 7}),
#  (131796,
#   {'text': 'Trump threatens to undermines the effectiveness of racial-justice based marijuana legalization — State resistance would solve.'}),
#  (131800,
#   {'text': 'It’s necessary - status quo forced choice between centralized and decentralized climate policy collapses effective policy - federalism is key',
#    'topic': 'political_change_key_breaking',
#    'topicrank': 8}),
#  (729,
#   {'text': 'Alternative causalities to relations collapse--rising tensions over the perceived militarization of the Mexican border is a thorn in the side of relations ',
#    'topic': 'has_other_over_collapse',
#    'topicrank': 0}),
#  (747,
#   {'text': 'More evidence – Ability to weather Global Recession and Eurozone meltdown',
#    'topic': 'nuclear_cause_more_meltdown',
#    'topicrank': 1}),
#  (131825,
#   {'text': 'No internal link — the federal government is compartmentalized. Education policies don’t distract State and Defense from conducting foreign policy. ',
#    'topic': 'federal_government_states_power',
#    'topicrank': 89}),
#  (768,
#   {'text': 'Airport entry and self-radicalization are comparatively more likely to allow terrorism',
#    'topic': 'attacks_cyber_likely_attack',
#    'topicrank': 28}),
#  (131844,
#   {'text': 'Standardized testing is good – allows more access',
#    'topic': 'solves_more_better_creates',
#    'topicrank': 29}),
#  (784,
#   {'text': 'Immigration has no environmental impact and slows global population growth – also they justify neo-Nazism'}),
#  (799,
#   {'text': 'Text: The United States Government should force implementation of holistic grazing throughout the United States ',
#    'topic': 'states_united_should_federal',
#    'topicrank': 268}),
#  (808,
#   {'text': 'The aff can be utilized as a vehicle of resistance to neoliberalism – perm do both'}),
#  (813,
#   {'text': 'Borders exemplify the great divide drawn between citizenship and non-citizenship- La Migra harshly enforces laws in the name of “border security”, depicting the immigrant body as a threat that must be kept out ',
#    'topic': 'border_violence_borders_security',
#    'topicrank': 1}),
#  (817,
#   {'text': 'There’s no escape-current attempts at revolution have failed and lead to a re-subjugation of the indigenous population-only a geography-based alternative can de-politicize the underlying ethnic cleavages',
#    'topic': 'state_indigenous_settler_war',
#    'topicrank': 14}),
#  (822,
#   {'text': 'A Leap of Speculation-Insecure Americans unwarrantedly assume that the Latin American other is a dangerous terrorist threat, defining American hegemonic securitization in an attempt to protect themselves from non-existent threats',
#    'topic': 'hegemony_threat_threats_us',
#    'topicrank': 6}),
#  (823,
#   {'text': 'The TPP is an example of US attempts to dominate others through trade and international organizations – it would undermine global governance and destroy human rights',
#    'topic': 'rights_international_human_global',
#    'topicrank': 0}),
#  (825,
#   {'text': 'The Bolivarian shift in Venezuela is an example of how we can move away from neoliberalism ',
#    'topic': 'we_neoliberalism_capitalism_can',
#    'topicrank': 0}),
#  (826, {'text': 'Trying to move Venezuela away from Chavismo is bad - '}),
#  (131899,
#   {'text': 'Regulation has zero predictable definition – you should prefer reasonability '}),
#  (131907,
#   {'text': 'Regulate means to organize and refine results in the educational process – you should prefer specific definitions in the context of federal involvement in primary and secondary education '}),
#  (836,
#   {'text': 'Imagining a better alternative for Latin America allows for a new collective identity for marginalized populations that can break down the oppressive structures of neoliberalism'}),
#  (840,
#   {'text': 'Neoliberalism is sustainable-dematerialization means that resource wars and environmental collapse aren’t inevitable',
#    'topic': 'inevitable_isn_neoliberalism_us',
#    'topicrank': 2}),
#  (845,
#   {'text': 'The alternative is no better for the environment – Venezuela is proof',
#    'topic': 'alternative_better_worse_more',
#    'topicrank': 7}),
#  (131926,
#   {'text': 'Won’t escalate conflict – don’t want to risk destabilizing the regime. ',
#    'topic': 'doesn_china_us_want',
#    'topicrank': 76}),
#  (131929,
#   {'text': 'SEL does not build character or promote citizenship – and its studies have no real scientific foundation.'}),
#  (888,
#   {'text': 'Engagement is not zero-sum – the US & China have different interests. ',
#    'topic': 'us_china_engagement_nuclear',
#    'topicrank': 1}),
#  (890,
#   {'text': 'China and United States seeks to cooperate with each other in Latin America and Cuba—not a zero sum game. ',
#    'topic': 'china_us_both_relations',
#    'topicrank': 38}),
#  (131965,
#   {'text': 'b. Violation: Court rulings are distinct – it’s a form of educational legalization. '}),
#  (900,
#   {'text': 'Prioritizing ontology and epistemology over specific policy formulations paralyzes problem solving measures ensuring short-term annihilation',
#    'topic': 'ontological_ontology_blackness_epistemology',
#    'topicrank': 23}),
#  (131975,
#   {'text': 'The aff is aesthetic education that hides the true negative value of education- this constructs the queer as that which threaten the aesthetic because it would expose the negative- children are taught what they ought to be, not what they are, enabling a stronger form of social control- education and queerness are negatively linked- queerness is the counterpedagogy that dissolves the harmonizing framework that unifies the symbolic order'}),
#  (131981,
#   {'text': 'Be skeptical of their truth claims- their use of rationality is a form of heteronormative policing that seeks to enforce normative binaries (male/female, homo/hetero)- neoliberalism forms what is considered rational in order to maximize production and profit',
#    'topic': 'neoliberalism_inevitable_alternative_can',
#    'topicrank': 97}),
#  (132001,
#   {'text': 'We affirm sinthomosexuality, a merger of Lacan’s sinthome, where the knot holding the symbolic, imaginary, and real together fails, and the body of the queer within heternormativity, to recognize the needs of the Queer and challenge the Human',
#    'topic': 'we_can_our_only',
#    'topicrank': 98}),
#  (931,
#   {'text': 'Biopower is a description of our era—it is neither inherently good, nor bad. Our specific context is more important than their sweeping generalization. ',
#    'topic': 'we_our_must_than',
#    'topicrank': 5}),
#  (132007,
#   {'text': 'Their impact is framed through heteronormativity which will always view queered bodies as less important and normalize violence against them- this psychological priming will always prioritize their impacts because queer genocide will appear to be a non-UQ impact',
#    'topic': 'queer_secessionism_bodies_quebec',
#    'topicrank': 9}),
#  (132018,
#   {'text': 'Foucault has a naturalized understanding of sex and gender- vote for the additional nuance of the K'}),
#  (132020,
#   {'text': 'Edelman has it wrong- we shouldn’t reject the future, but reimagine it- they paper over violence to children in marginalized positions',
#    'topic': 'can_we_won_them',
#    'topicrank': 32}),
#  (132021,
#   {'text': 'Edelman’s utopian argument essentializes the white male queer- this papers over oppression of other queer folx- turns the K',
#    'topic': 'women_exploitation_western_turns',
#    'topicrank': 11}),
#  (132026,
#   {'text': 'Their totalizing critique cedes the political to the right- uniting on our similarities is the best way to create effective coalitions against queer oppression',
#    'topic': 'political_from_makes_totalitarianism',
#    'topicrank': 20}),
#  (132028,
#   {'text': 'Counterplan: The United States Federal Government should incentivize states to [do the plan].',
#    'topic': 'states_united_should_federal',
#    'topicrank': 36}),
#  (132031,
#   {'text': 'Counterplan: The United States Federal Government should incentivize states to [do the plan] through competitive grants modeled after the Investing in Innovation Fund (I3).',
#    'topic': 'states_federal_should_government',
#    'topicrank': 27}),
#  (132038,
#   {'text': 'Rather than spurring reform, federal incentives and competitions distract policymakers from real education issues and instead incentivize jargon-filled empty promises in an attempt to garner funding',
#    'topic': 'policy_alternative_federal_chinese',
#    'topicrank': 3}),
#  (990,
#   {'text': 'Restoring ties with Venezuela will require significant time and effort by Kerry'}),
#  (132070,
#   {'text': 'Yes the federal reserve hiked rates with low inflation but that’s on outlook that it will stabilize by the end of the year --- Aff takes it past that',
#    'topic': 'growth_inflation_economic_rates',
#    'topicrank': 8}),
#  (132072,
#   {'text': 'Perkins reauthorization costs billions',
#    'topic': 'now_us_mexico_costs',
#    'topicrank': 13}),
#  (132076,
#   {'text': 'Over $100 billion required to equalize funding',
#    'topic': 'billion_million_cost_costs',
#    'topicrank': 82}),
#  (1019,
#   {'text': 'Can’t force compliance – trade liberalization creates a ceiling.',
#    'topic': 'can_solve_won_without',
#    'topicrank': 26}),
#  (1020,
#   {'text': 'Turn – singling out Mexico politicizes CITES – collapses treaty credibility.'}),
#  (1030,
#   {'text': 'All canonical Western thought contains de-colonial effects—a combination of all philosophies is necessary for decolonizing the twenty-first century',
#    'topic': 'colonial_decolonization_through_indigenous',
#    'topicrank': 34}),
#  (132103,
#   {'text': 'Privatization is good for multiple reasons --- Canada proves it works',
#    'topic': 'key_now_proves_theory',
#    'topicrank': 16}),
#  (1032,
#   {'text': 'Perm fills the blind-spots and solves their link --can\'t simply generalize all modernism and "male rationality"- alt degrades into insular and fragmented politics\nBest and Kellner 01 ',
# ...
#  (3960,
#   {'text': 'No China war—globalization locks in interdependence',
#    'topic': 'interdependence_war_economic_checks',
#    'topicrank': 30}),
#  (135044,
#   {'text': 'The 1AC is glorified Project Mayhem—its self-aggrandizing and makes us feel like good revolutionaries, but only ends in everybody being worse off—the alternative is free market existentialism which can maintain stability while cultivating a sustainable ethic of responsibility ',
#    'topic': 'neoliberal_only_which_can',
#    'topicrank': 1}),
#  (135047,
#   {'text': 'Their evidence criticizes consumer capitalism – transitioning to sustainability requires precision, not outright rejection.'}),
#  (135066,
#   {'text': 'Capitalism is amazing – solves inequality with a laundry list of benefits.'}),
#  (4002,
#   {'text': 'OFAC doesn’t solve perception—too bureaucratic and politicized. ',
#    'topic': 'doesn_can_solve_too',
#    'topicrank': 1}),
#  (135074,
#   {'text': 'Capitalism is key to avoid human extinction by colonizing Mars.',
#    'topic': 'extinction_can_only_prevent',
#    'topicrank': 15}),
#  (135078,
#   {'text': 'Mars colonization is really fun and also would solve human extinction.',
#    'topic': 'action_change_solve_motivate',
#    'topicrank': 19}),
#  (4008,
#   {'text': 'OFAC is heavily scrutinized by Congress – specifically true for travel licenses',
#    'topic': 'nsa_congressional_effective_congress',
#    'topicrank': 5}),
#  (4013,
#   {'text': '1. Oil companies aren’t going to pull out of Venezuela – solutions are being developed now towards debt relief',
#    'topic': 'aren_isn_have_doesn',
#    'topicrank': 23}),
#  (4014,
#   {'text': '2. Their Metzker evidence says foreign investment is key to revitalizing the oil industry – the plan does nothing to solve this',
#    'topic': 'key_together_work_states',
#    'topicrank': 10}),
#  (4020,
#   {'text': '4. Brazil won’t adopt nuclear weapons – and Argentina checks their impact',
#    'topic': 'won_cause_escalate_extinction',
#    'topicrank': 142}),
#  (135095,
#   {'text': 'Socialism Bad – Venezuela Proves',
#    'topic': 'obama_appeasing_reasons_proves',
#    'topicrank': 8}),
#  (135097, {'text': 'Instead of colonizing Mars, we should save Earth.'}),
#  (4027,
#   {'text': '3. Solvency takeout – their Griffin evidence indicates that relations will never improve as long as the US criticizes Venezuela for the drug trade, violation of human rights, and cooperation with Iran – these are all things the US are doing even now – the plan does nothing to solve this',
#    'topic': 'us_rights_human_have',
#    'topicrank': 14}),
#  (4028,
#   {'text': '5. There’s no logical coherency in their internal link to solving for the impacts outlined in the 1AC – just improving relations with Venezuela can’t solve for diplomatic relations with other countries – you can’t solve for water scarcity and warming just with Venezuela',
#    'topic': 'doesn_solve_impacts_impact',
#    'topicrank': 8}),
#  (4030,
#   {'text': '1NC #2 – Venezuela is not obtaining influence as Iran is which means that iran will inevitably find another ally to negotiate with – this is the basic theory of geopolitics – that’s our Lansberg ’13 evidence',
#    'topic': 'war_us_means_israel',
#    'topicrank': 23}),
#  (135102,
#   {'text': 'Black Girls are more likely than white girls to be perceived of as older than their actual age. This process of “adultification” leads the criminalization of black girls to become normalized because they are not given the possibility of being a child.',
#    'topic': 'women_because_black_who',
#    'topicrank': 9}),
#  (4034,
#   {'text': 'Turn – US hegemony creates backlash and forces Venezuela and Iran to ally with one another and form deterrence policies',
#    'topic': 'hegemony_us_undermines_causes',
#    'topicrank': 17}),
#  (135107,
#   {'text': 'Sixty percent of black girls will be victims of sexual assault by the age of 18. Instead of receiving help, these girls are often criminalized and stigmatized ',
#    'topic': 'women_because_black_who',
#    'topicrank': 26}),
#  (4036,
#   {'text': 'Congress will hate the plan – they prefer hard policy towards Venezuela',
#    'topic': 'congress_trump_congressional_plan',
#    'topicrank': 52}),
#  (4037,
#   {'text': 'Democratic and Republican opposition to Venezuela',
#    'topic': 'democratic_democracy_peace_transition',
#    'topicrank': 55}),
#  (135109,
#   {'text': ' “I got into prostitution because the guy that raped me, he forced me on the track. Basically, I didn’t go willingly at first, but ever since he did that to me, my whole life just changed, and that was at twelve years old. Ever since then, my life’s been off- track,”. Criminalized victims of sexual assault are tricked into thinking they’re choosing prostitution, when in reality, they’re being exploited. Conversations need to begin here to help these girls.'}),
#  (4039,
#   {'text': 'Any debt relief to Venezuela echoes the neoliberal policies of the U.S. in the past – causes social stratification and foreign dependence'}),
#  (4040,
#   {'text': 'Security driven economic engagement with Latin America authorizes international violence while criminalizing dissent – the 1AC exhibits a discourse of security that provides the rationale for global domination.',
#    'topic': 'rights_international_human_global',
#    'topicrank': 7}),
#  (4041,
#   {'text': 'Security politics authorizes limitless global destruction.',
#    'topic': 'war_conflict_power_global',
#    'topicrank': 36}),
#  (135112,
#   {'text': 'Why is it that inner-city girls must struggle so hard in order to survive? The question of survival among Black girls has always been whether they are seen, and if so, how they are seen. Are they "background noise" in a larger view of urban life that prioritizes men and boys? Are they disruptive forces in the exploitation of Black communities? Are they loyal "ride-or-die chicks" who sacrifice their own safety and well-being in the name of love? Are they willing participants in their own oppression? Are they making a way out of no way at all? Are they good girls? Are they bad girls?1'}),
#  (135114,
#   {'text': 'This leads to the criminalization of black girls and women, a social phenomena that is proliferated from stereotypes of black women stemming from chattel slavery to the pushout of black girls within academic spaces, creating a cycle of antiblack violence. ',
#    'topic': 'violence_women_them_rights',
#    'topicrank': 9}),
#  (135108,
#   {'text': 'Education is never neutral for black girls. Schools put more effort into removing these girls than actually helping them. Girls like Diamond show that education systems reek of unfair and racialized injustices. Schools should help black girls overcome money struggles that often lead them into a life of sex trafficking. Introducing girls who have unstable living conditions to the benefits of the McKinney-Vento Act can be a life changing step in the direction of self-betterment. ',
#    'topic': 'black_key_white_anti',
#    'topicrank': 16}),
#  (135110,
#   {'text': 'The media’s hyper-sexualization of young black girls is dangerous – it makes us think black girls are disposable yet useable. This was shown in the life of Danisha. She was exploited by sex traffickers, and then thrown away by the system into a juvenile detention facility. Danisha was 11, not 21.',
#    'topic': 'black_people_violence_only',
#    'topicrank': 46}),
#  (135116,
#   {'text': 'The intersection of antiblackness and sexism is a prerequisite to understanding structural, colonialist, and capitalist violence towards women of color writ large. A disavowal of such racist institutionalization could mitigate this phenomena, which is net better for people affected by it. Only our analysis can address these contingencies of violence.',
#    'topic': 'violence_which_women_only',
#    'topicrank': 0}),
#  (4047,
#   {'text': 'The quest for competitiveness makes it impossible to address the root causes of war and environmental destruction – forging alternative modes of social organization is key. ',
#    'topic': 'only_alternative_way_can',
#    'topicrank': 56}),
#  (4048,
#   {'text': 'Discourse of democracy authorizes global violence in its name – criticizing democracy is a prerequisite to meaningful analysis.',
#    'topic': 'violence_discourse_our_war',
#    'topicrank': 9}),
#  (135119,
#   {'text': 'Notions of respectability politics discreetly socialize misogynoir as a rule for evaluating Black girls and Women',
#    'topic': 'knowledge_production_black_key',
#    'topicrank': 14}),
#  (135120,
#   {'text': 'Narratives are key to challenge normative modes of scholarship that exclude marginalized voices in the academy',
#    'topic': 'narratives_key_contextual_precision',
#    'topicrank': 4}),
#  (135125,
#   {'text': 'What about the Link is criticizing the mechanism of the Affirmative solvency?',
#    'topic': 'what_card_do_how',
#    'topicrank': 31}),
#  (135126,
#   {'text': 'Wilderson’s call to imagine the end of the world is a form of universalizes the experiences of individual black people by forcing them to embrace the negativity surrounding their own ontological position ',
#    'topic': 'which_black_between_from',
#    'topicrank': 24}),
#  (135127,
#   {'text': 'Wilderson fails to address sexualized violence that black girls and face',
#    'topic': 'violence_effective_impact_structural',
#    'topicrank': 15}),
#  (4056,
#   {'text': 'Discourse of human security lays the terrain for western military interventions across the globe, authorizing force in the maintenance of bare life.',
#    'topic': 'state_us_security_arms',
#    'topicrank': 18}),
#  (135129,
#   {'text': 'The black body is sexually fetishized by the white body in so that only obscenities satisfy the desires of whiteness – psychoanalysis doesn’t account for this negrophilia.'}),
#  (4058,
#   {'text': 'Discourse of “human security” authorizes biopolitical techniques of population management through the targeting and eradication of unpredictability by sovereign intervention.',
#    'topic': 'global_economic_biopolitical_key',
#    'topicrank': 12}),
#  (4060,
#   {'text': 'Anti-proliferation discourse conforms to patterns of thought that legitimize the wholesale degradation and marginalization of other peoples while authorizing Western dominance.',
#    'topic': 'makes_violence_state_discourse',
#    'topicrank': 4}),
#  (4062,
#   {'text': 'Soft power is a thin veil to mask the militarization of the globe and the cultural coercion of other people'}),
#  (4064,
#   {'text': 'Economic globalization and free trade are deployed as a ruse to authorize military intervention and global violence.'}),
#  (4065,
#   {'text': 'Framing trade with Latin America as a security priority authorizes military aggression in the name of ‘integration’.'}),
#  (4066,
#   {'text': 'Framing climate change in terms of security legitimizes preemptive military doctrines to ‘contain’ anticipated threats while foreclosing attention to the institutional drivers of environmental degradation – rejecting the militarization of warming is a prerequisite to forging effective political responses to ecological destruction.',
#    'topic': 'nuclear_environmental_while_climate',
#    'topicrank': 0}),
#  (135138,
#   {'text': 'Portraying Black girls as Jezebels is a scapegoat for their sexual exploitation ',
#    'topic': 'black_people_violence_only',
#    'topicrank': 43}),
#  (135139,
#   {'text': 'Intersectionality homogenizes the experiences of black girls and women'}),
#  (4070,
#   {'text': 'Their focus on nuclear war authorizes structural violence.',
#    'topic': 'nuclear_war_causes_us',
#    'topicrank': 37}),
#  (4078,
#   {'text': 'Security does not promote emancipation – it authorizes violence and forecloses meaningful political contestation. ',
#    'topic': 'our_violence_do_understanding',
#    'topicrank': 3}),
#  (4088,
#   {'text': 'Criticizing security is a privilege of the secure – the alternative offers no mechanism for reducing global suffering.',
#    'topic': 'only_alternative_way_can',
#    'topicrank': 51}),
#  (4097,
#   {'text': 'Venezuela would reject the aff’s perception of engagement from the U.S.'}),
#  (135172,
#   {'text': 'Education is recognized as a way to extend the future of America – challenging this form of educational futurism in a radical negation of the status quo critical to break normative boundaries',
#    'topic': 'life_social_education_only',
#    'topicrank': 11}),
#  (135178,
#   {'text': 'Queer times require even queerer modalities of analysis — Intersectionality’s focus the varying permutations of the violence of the subject ignores the heart of the problem: the subject itself. By beginning with the terrorist as the subject of analysis the negative is that temporal interruption of the queer – only by problematizing the very basis of liberal humanism can we actually create the self beyond being – the only tenable theory of subjectivity is becoming ',
#    'topic': 'which_black_analysis_violence',
#    'topicrank': 2}),
#  (135180,
#   {'text': 'Curricular practices are tied to biopolitics of neoliberalism that denies the possibility of democratic future – promotes a carceral state that marginalizes students in the education system',
#    'topic': 'neoliberal_ideology_neoliberalism_political',
#    'topicrank': 49}),
#  (4113,
#   {'text': 'Activism turns debate into an echo chamber---that polarizes and radicalizes even the purest conclusions---our framework is key to tempering provisional conclusions ',
#    'topic': 'our_violence_debate_da',
#    'topicrank': 7}),
#  (135185,
#   {'text': 'Their critical praxis is mobilized violently in the postcolony – bids for inclusion within this space is only made possible through the targeted elimination of the colonial subject ',
#    'topic': 'war_only_through_has',
#    'topicrank': 1}),
#  (4126,
#   {'text': '(--) The ozone layer is depleting fast—the shifting of the Southern Hemisphere jet stream proves this is true:'}),
#  (4127,
#   {'text': '(--) International law key to solve ozone depletion:',
#    'topic': 'oil_warming_prices_key',
#    'topicrank': 52}),
#  (4128, {'text': '(--) Ozone depletion threatens human survival:'}),
#  (135204,
#   {'text': 'The kritiks characterization of the law is outdated and ignorant---legal reforms can protect subjects from state coercion'}),
#  (135206,
#   {'text': 'Ethical obligations are tautological—the only coherent rubric is to maximize number of lives saved',
#    'topic': 'only_ethics_ethical_all',
#    'topicrank': 6}),
#  (135208,
#   {'text': 'Prioritize existence because value is subjective and could improve in the future ',
#    'topic': 'otec_from_because_value',
#    'topicrank': 0}),
#  (135209,
#   {'text': 'Prioritize human existence---we’re the only species that can protect the entire biosphere from inevitable asteroid strikes---their impacts are long term while the lives killed in short term matter'}),
#  (135210,
#   {'text': 'There is an ontological difference between the gratuitous violence of racial slavery and the dehumanization present in international intervention – the attempt to draw a connection between black bodies and global subaltern positions invests in a violent chain of equivalence ',
#    'topic': 'violence_war_only_which',
#    'topicrank': 49}),
#  (135217,
#   {'text': 'Neoliberal privatization is a never-ending black hole that seeks to subsume everything- their rhetoric of race struggles in educational contexts inevitably get hijacked by capitalists to further the commodification of education- by reading this 1AC, they have already succeeded. ',
#    'topic': 'we_politics_us_rhetoric',
#    'topicrank': 14}),
#  (135261,
#   {'text': 'Lack of political action doesn’t authorize violation of PQD',
#    'topic': 'doesn_cause_war_economic',
#    'topicrank': 306}),
#  (4198,
#   {'text': '(--) There are severe water shortages—extend our Daily Mail evidence—vast freshwater reserves equivalent in size to the Dead Sea have been lost in the Middle East in the last decade—you should prefer our evidence, it cites a NASA study that also says there will be shortages for decades to come. Our Nagel evidence says this threatens human survival.',
#    'topic': 'evidence_from_extend_our',
#    'topicrank': 2}),
#  ...]

# %%
selected_nodes = [n for n,v in graph.backend.nodes(data=True) if n%2 == 0] ##also works for topic
selected_nodes
J = graph.backend.subgraph(selected_nodes)
list(J.nodes(data=True))
# Out:
# [(0,
#   {'text': 'A) The Affirmatives construction of a “Nation-Space” manifests in distinction to a colonized Other- locking the colonial Other in a violent cycle. ',
#    'topic': 'alternative_other_from_only',
#    'topicrank': 11}),
#  (2,
#   {'text': 'The projection of power portrayed of the US gave them an entitled sense of superiority. The American ideas of “modernization” are all really outgrowths of what we believed to be progress.'}),
#  (4,
#   {'text': 'The assumed cultural norms of economic engagement entrenches a universal market aesthetic reenacting a pattern of domination inherent in colonial thought. '}),
#  (6,
#   {'text': 'Economic Engagement “towards” other countries is an act violent social mimesis, re-speaking the colonial position. ',
#    'topic': 'political_alternative_social_struggle',
#    'topicrank': 8}),
#  (8,
#   {'text': 'Epistemological decolonization is key to liberating those imprisoned by coloniality. '}),
#  (10,
#   {'text': 'Colonialism is the foothold for biopower and racism – European thought is predicated off the assumption of a white exceptionalism ',
#    'topic': 'slavery_capitalism_racism_violence',
#    'topicrank': 14}),
#  (12,
#   {'text': 'Lack of understanding leads to objectification and rejection of the “Other” from a society that is familiar to the “Subject”',
#    'topic': 'only_other_from_rights',
#    'topicrank': 6}),
#  (14,
#   {'text': 'Our perception of language destroys the human spirit of all deemed another',
#    'topic': 'neoliberalism_our_deschooling_discourse',
#    'topicrank': 9}),
#  (16,
#   {'text': 'As long as colonialism exists there can be nothing but violence, corruption and barbarism',
#    'topic': 'slavery_capitalism_racism_violence',
#    'topicrank': 11}),
#  (18,
#   {'text': 'Colonization of the “Other” leads to an Increasingly Violent Struggle of Life and Death'}),
#  (20,
#   {'text': 'Genocide and Civil War is an inevitable product of postcolonial thinking—it banalizes political violence against the colonized',
#    'topic': 'genocide_violence_war_native',
#    'topicrank': 4}),
#  (22,
#   {'text': 'Only radical change of social norms strays away from ideology',
#    'topic': 'from_ideology_radical_change',
#    'topicrank': 0}),
#  (24,
#   {'text': 'Even though nation states are the most organized political sites in the world, some nation states are clearly positioned differently, which is an outgrowth of the coloniality and imperiality formerly imposed on the post colonial countries. Reject the aff-it embodies the colonial mindset.',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 52}),
#  (26,
#   {'text': 'Postcolonial translation of modern discourse shapes our understanding of the world '}),
#  (28,
#   {'text': 'Decolonization creates a free flow of subjectivity where race, sex, and gender dynamics can be dismantled from the war frame constituting the colonial situation. ',
#    'topic': 'gender_from_which_can',
#    'topicrank': 0}),
#  (30,
#   {'text': 'Epistemic de-colonization collapses and delinks the political with coloniality ',
#    'topic': 'political_inevitable_delegitimizes_coloniality',
#    'topicrank': 0}),
#  (32,
#   {'text': 'Mimicry may be used as a tool to oppress the postcolonial subject, or a method to explode the postcolonial power matrix. ',
#    'topic': 'too_otec_postcolonial_studies',
#    'topicrank': 4}),
#  (34,
#   {'text': 'Through the power of discourse we must break through the ontological constriction of national borders, only then will we be free',
#    'topic': 'only_power_through_which',
#    'topicrank': 0}),
#  (36,
#   {'text': 'The subaltern’s voice and the intellectual’s knowledge can coexist ',
#    'topic': 'can_knowledge_card_only',
#    'topicrank': 0}),
#  (38,
#   {'text': 'The ethnicity paradigmof the permutation obscurely homogenizes colonial history of exploitation and raciailized difference '}),
#  (40,
#   {'text': 'Use of postcolonialism leads to a misrepresentation of the “other”'}),
#  (42,
#   {'text': 'Postcolonial assumes a “post” state of oppression that ignores ongoing violence ',
#    'topic': 'violence_ignores_affirmative_plan',
#    'topicrank': 2}),
#  (44, {'text': 'Postcolonialism is a self serving field '}),
#  (46,
#   {'text': 'Postcolonialism becomes a critic’s language game to avoid any confrontation with the Other.'}),
#  (48,
#   {'text': 'Western states violence necessary evil for democracy',
#    'topic': 'democracy_violence_peace_democratic',
#    'topicrank': 5}),
#  (50,
#   {'text': 'Governments are established because the people want them-in return, the government bring political stability back to the people.',
#    'topic': 'us_political_military_them',
#    'topicrank': 2}),
#  (52,
#   {'text': 'Meditations on the hybrid and liminal space of postcolonialism lead to a mystification of the oppressed. '}),
#  (54,
#   {'text': 'The histories of the oppressive are not meant to be separate entities used to create dichotomous positions of power or inferiority ',
#    'topic': 'politics_between_power_domination',
#    'topicrank': 5}),
#  (56,
#   {'text': 'Politics and the government are necessary for the existence of a stable society simply because the government’s purpose is to maintain order in society.',
#    'topic': 'key_indigenous_necessary_political',
#    'topicrank': 13}),
#  (58,
#   {'text': 'The state is not over determined in dealing with the subaltern, a history remains open for future acts of justice. ',
#    'topic': 'state_its_accountable_ethical',
#    'topicrank': 5}),
#  (60,
#   {'text': 'Their conceptions of freedom fail to grasp the modalities of domination, reinforcing the structures that create unfreedom in the first place.',
#    'topic': 'politics_between_power_domination',
#    'topicrank': 6}),
#  (62,
#   {'text': 'The United States federal government should substantially increase its debt relief efforts toward Venezuela.',
#    'topic': 'should_united_states_government',
#    'topicrank': 36}),
#  (64,
#   {'text': 'Venezuelan debt is the critical issue-foreign exchange is key',
#    'topic': 'key_issue_state_most',
#    'topicrank': 21}),
#  (66,
#   {'text': 'Post-Chavez US-Venezuela ties vital to prevent Iran proliferation ',
#    'topic': 'us_relations_post_chavez',
#    'topicrank': 3}),
#  (68,
#   {'text': 'Chavez’s death makes now key',
#    'topic': 'chavez_key_regulations_death',
#    'topicrank': 0}),
#  (70,
#   {'text': 'US Diplomacy solves warming and proliferation',
#    'topic': 'nuclear_solves_proliferation_global',
#    'topicrank': 3}),
#  (72,
#   {'text': 'Oil is key to Venezuelan stability-debt relief is key',
#    'topic': 'key_oil_stability_us',
#    'topicrank': 1}),
#  (74,
#   {'text': 'Scenario 1: Oil Shocks',
#    'topic': 'scenario_advantage_two_one',
#    'topicrank': 96}),
#  (76,
#   {'text': 'Cuban instability collapse causes Latin American instability and terror attacks',
#    'topic': 'instability_causes_us_latin',
#    'topicrank': 3}),
#  (78, {'text': 'Causes South American arms race'}),
#  (80,
#   {'text': 'Legal restrictions don’t matter',
#    'topic': 'don_solve_reality_reps',
#    'topicrank': 57}),
#  (82,
#   {'text': 'Latin America is key piece for the symbolism of American power',
#    'topic': 'capitalism_latin_america_modern',
#    'topicrank': 0}),
#  (84,
#   {'text': 'Cancellation of Venezuela’s debt is a key step to breaking down the global neoliberal system',
#    'topic': 'economy_neoliberal_debt_venezuela',
#    'topicrank': 0}),
#  (86,
#   {'text': 'Previous SAP’s in Venezuela are the cause of the governmental problems that have played out throughout venezuela’s history'}),
#  (88, {'text': 'US controls the IMF'}),
#  (90,
#   {'text': 'PVDSA is unsustainable—Venezuela cant keep up',
#    'topic': 'unsustainable_growth_lack_economic',
#    'topicrank': 34}),
#  (92,
#   {'text': 'Accumulated debt is devastating the PVDSA—causing oil companies to pull out '}),
#  (94, {'text': 'PVDSA’s debt is external and foreign '}),
#  (96,
#   {'text': 'Venezuelan debt is dragging OPEC down ',
#    'topic': 'down_china_key_cracking',
#    'topicrank': 17}),
#  (98,
#   {'text': 'US is key—largest and most sophisticated',
#    'topic': 'us_world_largest_most',
#    'topicrank': 0}),
#  (100,
#   {'text': 'Perm do both-shields the net benefit ',
#    'topic': 'do_perm_both_plan',
#    'topicrank': 57}),
#  (102,
#   {'text': 'Bureaucracy DA—IMF policies must go through an approval of several different agencies/countries—which means there is a t/f differential ',
#    'topic': 'surveillance_through_fisc_cp',
#    'topicrank': 6}),
#  (104,
#   {'text': 'The Chamber of Commerce likes the plan',
#    'topic': 'solves_plan_aff_case',
#    'topicrank': 62}),
#  (106,
#   {'text': 'Economic engagement includes developmental assistance, debt relief, and opening markets—prefer our evidence-its from the state department and is in the context of Latin America',
#    'topic': 'foreign_policy_from_agency',
#    'topicrank': 11}),
#  (108,
#   {'text': 'Prevents China-Taiwan conflict and Chinese heg',
#    'topic': 'china_us_taiwan_conflict',
#    'topicrank': 3}),
#  (110,
#   {'text': 'Manufacturing solves bioterror – supply chain speed',
#    'topic': 'solves_risk_counterplan_solve',
#    'topicrank': 19}),
#  (112,
#   {'text': 'Continued growth is key to manufacturing',
#    'topic': 'growth_key_economic_reform',
#    'topicrank': 148}),
#  (114,
#   {'text': 'Key to US aerospace and defense manufacturing',
#    'topic': 'aerospace_key_industry_us',
#    'topicrank': 3}),
#  (116,
#   {'text': 'Prefer Neg evidence – the aff’s aggregated data doesn’t assume individual commodities',
#    'topic': 'doesn_assume_aff_neg',
#    'topicrank': 1}),
#  (118,
#   {'text': 'Volatility has indirect negative impacts on trade',
#    'topic': 'economy_has_effect_impact',
#    'topicrank': 43}),
#  (120,
#   {'text': 'Mexican growth is key to regional leadership and trade',
#    'topic': 'growth_key_economic_reform',
#    'topicrank': 185}),
#  (122,
#   {'text': 'Interdependence doesn’t solve war ',
#    'topic': 'doesn_solve_war_trade',
#    'topicrank': 11}),
#  (124,
#   {'text': 'The president needs more power to keep congress from delegating to non-reputable agencies',
#    'topic': 'courts_congress_can_executive',
#    'topicrank': 51}),
#  (126,
#   {'text': 'Latin American democracy solves the environment',
#    'topic': 'environment_solves_destroys_economy',
#    'topicrank': 32}),
#  (128,
#   {'text': 'Key to stop global prolif',
#    'topic': 'prolif_causes_key_tsunamis',
#    'topicrank': 2}),
#  (130,
#   {'text': 'Drug violence kills Democracy – obviates popular support',
#    'topic': 'us_support_fear_military',
#    'topicrank': 9}),
#  (132,
#   {'text': 'Decline doesn’t hurt democracy – backlash against incumbents'}),
#  (134,
#   {'text': 'Mexican collapse kills the US economy – statistics, agriculture, manufacturing',
#    'topic': 'key_economy_security_us',
#    'topicrank': 9}),
#  (136,
#   {'text': 'Empirics Prove the internal link– Mexican collapse results in critical healthcare cuts',
#    'topic': 'empirics_prove_war_key',
#    'topicrank': 234}),
#  (138,
#   {'text': 'Economic Growth Increases Disease – Statistics Prove',
#    'topic': 'growth_economic_now_economy',
#    'topicrank': 56}),
#  (140,
#   {'text': 'Instability leads to WMD terrorism – DTO border smuggling',
#    'topic': 'instability_causes_us_latin',
#    'topicrank': 31}),
#  (142,
#   {'text': 'Mexican collapse casues terrorism – opens up a base of future operations'}),
#  (144, {'text': 'Mexican collapse causes U.S. isolationism'}),
#  (146,
#   {'text': 'Mexican Collapse Gives Iran leverage in nuclear talks',
#    'topic': 'nuclear_war_relations_us',
#    'topicrank': 46}),
#  (148,
#   {'text': 'American influence key to prevent Chinese influence – that gives power to anti-American leaders and gives China leverage in the Taiwan and North Korea issues',
#    'topic': 'china_us_japan_chinese',
#    'topicrank': 24}),
#  (150, {'text': 'Economic downturn and stability guts Mexican oil exports'}),
#  (152,
#   {'text': 'Chinese economic instability results in an internal war that causes lash-out',
#    'topic': 'instability_causes_war_protests',
#    'topicrank': 1}),
#  (154,
#   {'text': 'Warming causes extinction of every species',
#    'topic': 'species_key_ecosystems_invasive',
#    'topicrank': 140}),
#  (156,
#   {'text': 'Banking Industry solves warming – Green marketing and green brand image',
#    'topic': 'solves_warming_japan_solve',
#    'topicrank': 65}),
#  (158,
#   {'text': 'Banking solves the environment – bank lending criteria, environmental management strategies, and environmental financial products'}),
#  (160, {'text': 'Exchange Rate fluctuations Decrease Mexican Corn imports'}),
#  (162,
#   {'text': 'Discussion of specific policies in Latin America is the only way to achieve political autonomy',
#    'topic': 'way_only_solve_best',
#    'topicrank': 148}),
#  (164,
#   {'text': 'Moral obligation to bridge the gap between theoretical and pragmatic approaches---scholars must engage in the policy debate ',
#    'topic': 'debate_policy_necessary_framework',
#    'topicrank': 8}),
#  (166,
#   {'text': 'Only researching specific mechanisms will result in policies geared towards the interest of Latin Americans',
#    'topic': 'from_policies_effective_specifically',
#    'topicrank': 9}),
#  (168,
#   {'text': 'State action is good---fiat allows us to imagine the possibility of any one of the plethora of possible ethical policies '}),
#  (170,
#   {'text': 'Aff is not a prior question---Latin American countries want pragmatic politics---the aff fails without a solution to years of neglect',
#    'topic': 'aff_plan_solves_causes',
#    'topicrank': 13}),
#  (172,
#   {'text': 'The affirmatives rejection fails—it makes political action impossible—a pragmatic attack against neoliberalism solves best',
#    'topic': 'neoliberal_political_neoliberalism_us',
#    'topicrank': 2}),
#  (174,
#   {'text': 'Pragmatic action is key in the context of Mexico',
#    'topic': 'context_right_specifically_education',
#    'topicrank': 21}),
#  (176,
#   {'text': 'Status quo solves---the era of neglect their authors describe is coming to a close'}),
#  (178,
#   {'text': 'Economic engagement is well received---Latin America has a favorable view of America only when we are engaging',
#    'topic': 'we_our_key_way',
#    'topicrank': 39}),
#  (180,
#   {'text': 'Their interrogation ignores historical trends which disproves their argument',
#    'topic': 'disproves_ignores_theory_false',
#    'topicrank': 3}),
#  (182, {'text': 'Impacts are inevitable---no shift from neolib'}),
#  (184,
#   {'text': 'Immigration reform is an alt cause---failure to pass a policy has bred resentment---the aff makes it worse',
#    'topic': 'solves_plan_we_aff',
#    'topicrank': 30}),
#  (186,
#   {'text': 'The 1AC ironically neglects the non-human world---that ensures replicating human-centrism and reifying anthropocentric dominance ',
#    'topic': 'human_anthropocentric_only_world',
#    'topicrank': 0}),
#  (188,
#   {'text': 'Anthro comes first---prior question to understanding politics'}),
#  (190,
#   {'text': 'Their description of Latin America denies cultural difference and enforces generalizations which are essentially racism in disguise---not only is it historically inaccurate, but it also denies political independence by pinning the country with their European and American imperialist heritage',
#    'topic': 'which_racial_order_white',
#    'topicrank': 16}),
#  (192,
#   {'text': 'The aff kills free trade and hegemony---their author',
#    'topic': 'hegemony_key_us_power',
#    'topicrank': 369}),
#  (194,
#   {'text': 'Ethical policies and selfish policies are indistinguishable'}),
#  (196,
#   {'text': 'Methodologies are always imperfect---endorsing multiple epistemological frameworks is effective compensation',
#    'topic': 'too_history_methodologies_frameworks',
#    'topicrank': 0}),
#  (198, {'text': 'It’s accurate---this is the Latin American point of view'}),
#  (200,
#   {'text': 'The term “Latin America” originated in French intellectual circles in order to map the region---it’s historically accurate',
#    'topic': 'evidence_accurate_us_about',
#    'topicrank': 7}),
#  (202,
#   {'text': 'The term is politically correct and unproblematic---there’s no alternative or a root cause'}),
#  (204,
#   {'text': 'Cuba is a key model for global health care – key to disease prevention ',
#    'topic': 'key_education_us_health',
#    'topicrank': 6}),
#  (206,
#   {'text': 'Cuban health care good now – trends and focus on preventative care ',
#    'topic': 'health_care_key_disease',
#    'topicrank': 12}),
#  (208,
#   {'text': 'Cuban health care strong – lots of positive trends ',
#    'topic': 'health_care_cuban_patient',
#    'topicrank': 3}),
#  (210,
#   {'text': 'Easing the embargo Brain drain which collapses Cuba’s public health care system ',
#    'topic': 'embargo_lifting_cuba_economy',
#    'topicrank': 52}),
#  (212,
#   {'text': 'Policies can’t increase soft power, and impacts are limited by security concerns.',
#    'topic': 'don_can_fail_state',
#    'topicrank': 8}),
#  (214,
#   {'text': 'Plan doesn’t affect US oil markets significantly',
#    'topic': 'doesn_cause_war_economic',
#    'topicrank': 273}),
#  (216,
#   {'text': 'Every new offshore drilling operation threatens critical species in the ocean environment',
#    'topic': 'ecosystems_ocean_marine_resilient',
#    'topicrank': 30}),
#  (218,
#   {'text': 'US soft power is key to US power projection globally.',
#    'topic': 'key_us_globally_power',
#    'topicrank': 0}),
#  (220,
#   {'text': 'US leadership is unsustainable and mass suffering, militarism and conflict'}),
#  (222,
#   {'text': 'HEGEMONY DOESN’T SOLVE CONFLICT – extend Mearsheimer – Iran, North Korea and Middle East conflict all prove the US is declining as a global problem solver ',
#    'topic': 'us_won_china_east',
#    'topicrank': 9}),
#  (224,
#   {'text': 'Global perception declining support ',
#    'topic': 'now_decreasing_us_global',
#    'topicrank': 7}),
#  (226,
#   {'text': 'Rising economic powers decline ',
#    'topic': 'economic_causes_decline_war',
#    'topicrank': 98}),
#  (228,
#   {'text': 'US HEGEMONY IMPERIALISM – extend Boggs – justifications for US predominance are based in a Fukyaman notion of the end of history – this ideology posits the US as the city on the hill and the rest of the world open for colonial exploitation ',
#    'topic': 'us_state_colonial_our',
#    'topicrank': 3}),
#  (230,
#   {'text': 'MILITARISM – extend Boggs – US leadership necessitates global militarism - any increase in predominance only greases the wheels of militarism and decreases popular resistance to war ',
#    'topic': 'us_military_cooperation_prevents',
#    'topicrank': 24}),
#  (232,
#   {'text': 'B) MILITARISM – Extend Sanders ev – continued reliance on militaristic foreign policies guarantees extinction via destruction of the environment – this outweighs any alternative cause to environmental destruction – even if they win they deter conflict the build up to war accesses our impact ',
#    'topic': 'nuclear_war_environment_environmental',
#    'topicrank': 1}),
#  (234,
#   {'text': 'No transition wars- rising states will integrate into international institutions- no incentives for aggression'}),
#  (236,
#   {'text': 'These studies specifically apply to the US ',
#    'topic': 'us_china_war_south',
#    'topicrank': 49}),
#  (238,
#   {'text': 'Prefer history and social science ',
#    'topic': 'science_social_debate_knowledge',
#    'topicrank': 0}),
#  (240,
#   {'text': 'The United States federal government should lift the travel ban on Cuba ',
#    'topic': 'should_united_states_government',
#    'topicrank': 12}),
#  (242,
#   {'text': 'Lifting travel restrictions solves the case ',
#    'topic': 'solves_plan_aff_case',
#    'topicrank': 8}),
#  (244,
#   {'text': 'Easing embargo popular and political opposition ',
#    'topic': 'political_opposition_embargo_causes',
#    'topicrank': 1}),
#  (246,
#   {'text': '2. Doesn’t Solve – ',
#    'topic': 'doesn_solve_war_trade',
#    'topicrank': 52}),
#  (248,
#   {'text': 'Federal Government” doesn’t mean “all three branches” – any one body acts as it',
#    'topic': 'doesn_aff_don_even',
#    'topicrank': 20}),
#  (250,
#   {'text': 'Piena has momentum now to push oil reform ',
#    'topic': 'now_still_has_have',
#    'topicrank': 0}),
#  (252,
#   {'text': 'Legalization is an Uphill fight - unpopular',
#    'topic': 'unpopular_plan_congress_public',
#    'topicrank': 170}),
#  (254,
#   {'text': 'Mexican renewables leads to US modeling',
#    'topic': 'us_mexico_key_trade',
#    'topicrank': 31}),
#  (256, {'text': 'Global demand for renewables decreasing '}),
#  (258,
#   {'text': 'Reform key to competitiveness – private sector investment and access to US gas',
#    'topic': 'key_economy_growth_innovation',
#    'topicrank': 156}),
#  (260,
#   {'text': 'Economic reform happening now',
#    'topic': 'now_us_china_war',
#    'topicrank': 93}),
#  (262,
#   {'text': 'Obama plans to aid Nieto in drug policy',
#    'topic': 'obama_now_policy_prison',
#    'topicrank': 2}),
#  (264,
#   {'text': 'Nieto won’t get the 2/3 vote in Congress',
#    'topic': 'won_pass_republicans_trump',
#    'topicrank': 135}),
#  (266,
#   {'text': 'AND- USAID is the main agency for economic policy',
#    'topic': 'state_power_security_agency',
#    'topicrank': 5}),
#  (268,
#   {'text': 'Food insecurity causes failed states- that causes extinction',
#    'topic': 'extinction_causes_war_risks',
#    'topicrank': 35}),
#  (270,
#   {'text': 'And, the construction of the US-Mexico border stabilizes American identity around the racist projection of lawlessness and barbarity onto the Mexican other in need of domination. ',
#    'topic': 'us_control_border_american',
#    'topicrank': 0}),
#  (272,
#   {'text': 'Next, bounding nation-states through the enclosure of borders is the control of territory through violence. This production of the space of the state obfuscates always on-going non-state violence and legitimates wars and genocides in the name of state-making.',
#    'topic': 'violence_war_state_only',
#    'topicrank': 4}),
#  (274,
#   {'text': 'Taking Cuba of the terror list only consolidates a world order founded on the colonization of space instantiated in the world map of bounded nation-states, reproducing colonial knowledge through the language of the 1AC. This short-circuits the border thinking that allows a break from the colonial structure of modernity.',
#    'topic': 'colonial_state_colonialism_settler',
#    'topicrank': 55}),
#  (276,
#   {'text': 'And, we must break from the idea of separate islands, but use an Archipelagic perspective of islands to expose imperialism – viewing islands as isolated is the link',
#    'topic': 'we_our_must_than',
#    'topicrank': 9}),
#  (278,
#   {'text': 'First development is just a replacement for the white man’s burden because it reinforces the colinal relationship through the state and neoliberlaims. '}),
#  (280,
#   {'text': 'The process of state driven neoliberal practice uses inclusionary ontological enframing to reducing human existence to particular modalities of potential contribution to the market—this idea constitutes ontological violence and the reduction of the infinite possibility of being- ontologically positioned to serve the interests of profit-making',
#    'topic': 'neoliberal_capitalism_market_control',
#    'topicrank': 20}),
#  (282,
#   {'text': 'And, this reinforcement of the nation-state and soverignetny perpetuate the colonial relationship between the west and Latin America. No amount of internal reform can change the oppression of Mexican labor by global markets.'}),
#  (284,
#   {'text': 'The root of the creation of law that governs a nature is violence therefore law itself is violence in order to prevent violence ',
#    'topic': 'violence_which_war_all',
#    'topicrank': 12}),
#  (286,
#   {'text': 'The nation-state and democracy are the product of colonial interaction of Latin America with the west.',
#    'topic': 'imperialism_rooted_capitalism_colonial',
#    'topicrank': 6}),
#  (288,
#   {'text': '{In Mexico OIL 1NC**}The West masks insidious imperialism as attempts at developing the non-west'}),
#  (290,
#   {'text': 'Globalization ushers in an unequal access to wealth, resulting in notions of deterritorialization. Innerconnectivity brings problems with governance and securitization to the forefront. '}),
#  (292,
#   {'text': 'The human rights story of of the state as a savage only when “bad” culture disallows “good” culture fails to understand that the state is a empty vessel and it is societal norms that fill it.',
#    'topic': 'only_we_violence_you',
#    'topicrank': 21}),
#  (294,
#   {'text': 'Human rights reinforce racism due to the narrative of the redeemers redeeming themselves by protecting the inferior people. This view causes the movement to fail as the people who need help are alienated.',
#    'topic': 'only_schools_who_can',
#    'topicrank': 8}),
#  (296,
#   {'text': 'Human rights discourse is rooted in Western predistenation, assuming the necessity of an imperial mission to civilize the inferior, undeveloped.'}),
#  (298,
#   {'text': 'The AFFIRMATIVE too easily deploys representations of dangerous geographies – the space of disaster is taken up as the space of nature, which, when taken to its logical limit, is the epicenter of modern violence ',
#    'topic': 'from_which_our_space',
#    'topicrank': 3}),
#  (300,
#   {'text': 'Securing the environment otherizes states that cannot cope with unsustainable development causing violence leading to their impacts- also elevating environmental destruction destroys personal agency towards the problem killing any chance of solvency ',
#    'topic': 'nuclear_war_environment_environmental',
#    'topicrank': 4}),
#  (302,
#   {'text': 'The affirmative completes the scalar transformation of the state from welfare provider into regional guardian.',
#    'topic': 'state_from_any_power',
#    'topicrank': 9}),
#  (304,
#   {'text': 'Their concern for Latin American relations is disingenuous – the affirmative uses political stability as a tool to mask economic interests in the region that further American intervention and imperialism.'}),
#  (306,
#   {'text': 'NGO HUMANITARIANISM is an too easily slips into prescripted regimes of control. Be skeptical of the affirmatives claims ',
#    'topic': 'politics_claims_re_affirmative',
#    'topicrank': 5}),
#  (308,
#   {'text': 'International law’s authority ends at the borders of the nation-state. The reinforcement of international law upholds the modern nation-state and allows for the creation of the artificial citizen',
#    'topic': 'state_sovereignty_sovereign_violence',
#    'topicrank': 48}),
#  (310,
#   {'text': 'The idea of the border is not a historic concept – rather, boundaries are a result of European influence in the global sphere. They are completely artificial constructions that are not necessarily effective. This is exemplified by borders such as the Somali-Ethiopia border, where millions of Somalis live in Ethiopia despite a boundary',
#    'topic': 'border_borders_between_which',
#    'topicrank': 17}),
#  (312,
#   {'text': 'Neoliberal governmentality forcibly creates conditions for the mono-ontological politics transnationally-the space of domination is no longer confined to the sovereign state-but extends to the locus of power created by neoliberal rationalism',
#    'topic': 'neoliberal_capitalism_market_control',
#    'topicrank': 31}),
#  (314,
#   {'text': 'Borders are artificial products of the expanding neoliberal order ',
#    'topic': 'neoliberalism_neoliberal_inequality_education',
#    'topicrank': 55}),
#  (316,
#   {'text': 'Advancements in surveillance technology create threats based on historically conceived “Others”',
#    'topic': 'surveillance_through_violence_bodies',
#    'topicrank': 23}),
#  (318,
#   {'text': 'Transnational movements prohibit the movement of migrant bodies across borders. Rather than increasing the fluidity of identity across borders, transnationalism exacerbates the difference between exclusion and inclusion.'}),
#  (320,
#   {'text': 'Transnationalism backfires – Retrenches nationalism.',
#    'topic': 'political_backfires_security_violence',
#    'topicrank': 4}),
#  (322,
#   {'text': 'Transnational movements such as the Coalition for Justice in the Maquiladoras spurs transterrioriatial degradation leading to inequalities for workers, division of labor, and weakened society '}),
#  (324,
#   {'text': 'Organizing at the level of the state leaves the global capital processin place leaving in place the global division of labor',
#    'topic': 'state_from_any_power',
#    'topicrank': 24}),
#  (326,
#   {'text': 'Disaster assistance mimics the process of war - from rhetorical conception to policy implementation ',
#    'topic': 'rhetoric_apocalyptic_rhetorical_environmental',
#    'topicrank': 43}),
#  (328,
#   {'text': '{**In Cuba Terror and Policy 1NC**}You should be skeptical of their engagement with Cuba – expanding American geopolitical influence in the region only serves to further the goals of US hegemony and the securitization of borders.',
#    'topic': 'china_us_western_american',
#    'topicrank': 8}),
#  (330,
#   {'text': 'US policy towards Cuba such as humanitarian aid is rooted in American geopolitical ideologies which serve post-colonial US hegemonic interests',
#    'topic': 'china_us_western_american',
#    'topicrank': 0}),
#  (332,
#   {'text': 'Homogenizing islands saps island identities and enables domination by great powers',
#    'topic': 'indigenous_borders_identities_power',
#    'topicrank': 8}),
#  (334,
#   {'text': '{**In the Mexico Oil 1NC**} The construction of the US-Mexico border stabilizes American identity around the racist projection of lawlessness and barbarity onto the Mexican other in need of domination.',
#    'topic': 'us_control_border_american',
#    'topicrank': 1}),
#  (336,
#   {'text': 'The only justification for the plan is fear. Even though the most vulnerable site for entry into a nation would be airports, we are still fixated on the idea of crossing through walls, swimming, and walking. Most who perform border crossings are NOT security threats',
#    'topic': 'immigrants_state_from_only',
#    'topicrank': 52}),
#  (338,
#   {'text': 'In an attempt to resolve the security/economy contradiction of the US-Mexico border, the United States has expanded the border by localization inwardly and preemption outwardly. ',
#    'topic': 'border_us_mexico_between',
#    'topicrank': 17}),
#  (340,
#   {'text': 'Economic integration is an extension of imperialism – NAFTA proves',
#    'topic': 'imperialism_us_order_from',
#    'topicrank': 12}),
#  (342,
#   {'text': 'The collapse of economic barriers is followed by an influx of permanent securitization.',
#    'topic': 'economic_collapse_through_reform',
#    'topicrank': 6}),
#  (344,
#   {'text': 'The creation of the North American Free Trade Agreement turned Mexico into yet another casualty of American expansionism. This can be compared to the fascist economic policies of Nazi Germany in WW2 '}),
#  (346,
#   {'text': 'NAFTA represents the latest attempt by the US to tear down the border and spread neoliberalism',
#    'topic': 'imperialism_us_order_from',
#    'topicrank': 17}),
#  (348,
#   {'text': 'Crossing the border is an ontological experience. War on Terror discourse turns “friendly” borders into “leaky” borders, and the securitization of borders categorize individuals as inadmissible, detainee, or deportable. ',
#    'topic': 'surveillance_from_war_state',
#    'topicrank': 13}),
#  (350,
#   {'text': 'Using ID politics for social movements recreates sovereign power since the borders of the state created those identities- destabilizing the system comes first',
#    'topic': 'identity_politics_state_power',
#    'topicrank': 0}),
#  (352,
#   {'text': 'Place and boundaries have a connection to our view of everyday life. Assessing its influence allows us to question capitalism, modernity, and Eurocentric thought. ',
#    'topic': 'world_our_we_must',
#    'topicrank': 69}),
#  (354,
#   {'text': 'Analyzing the way states re-inscribe borders is fundamental to broader understandings of their political structures ',
#    'topic': 'state_political_alternative_only',
#    'topicrank': 7}),
#  (356,
#   {'text': 'Cartography hides and displaces bloodshed and violence and creates a “historical amnesia” with which the state masks violence. Only by encountering the Other outside of our dominant spatial construction can we disrupt violent cartographies and unmask historical violence.',
#    'topic': 'global_through_only_violence',
#    'topicrank': 2}),
#  (358,
#   {'text': 'Vote negative to assume a politics that renders the biopolitical machine inoperative—the cessation of line-drawing under the sovereign body and assuming the situation of bare life reframes the ethical-political thought and inscribes a politics more open to potentialities',
#    'topic': 'being_more_creates_link',
#    'topicrank': 9}),
#  (360,
#   {'text': 'The alternative is to render ourselves immobile in the face of the biopolitical border- borders and border security cannot operate without the continuous flow of goods and people '}),
#  (362,
#   {'text': 'Our Alternative is to work within the framework of critical ethnographic. This effectively disrupts dominate power structures by locating the discourses silenced by state practice',
#    'topic': 'alternative_only_structures_1ac',
#    'topicrank': 4}),
#  (364,
#   {'text': 'An anthropological study of borders reveals the root of state-based relationships',
#    'topic': 'colonial_state_colonialism_indigenous',
#    'topicrank': 7}),
#  (366,
#   {'text': 'Archipelagraphy exposes the colonial history of the Carribbean',
#    'topic': 'colonial_decolonization_through_indigenous',
#    'topicrank': 17}),
#  (368,
#   {'text': 'Archipelagy breaks down dichotomies that construct islands as vulnerable – this notion informs all of US/Cuba relations',
#    'topic': 'state_market_creates_us',
#    'topicrank': 6}),
#  (370,
#   {'text': 'Leaders use national interest as a justification for the creation good/evil dichotomies with the other '}),
#  (372,
#   {'text': 'Cognitive science proves that categorization via the creation of borders is the root of us-them distinctions ',
#    'topic': 'from_borders_based_starting',
#    'topicrank': 2}),
#  (374,
#   {'text': 'State borders fueled the designation of terrorists and a militarized response',
#    'topic': 'war_violence_militarized_state',
#    'topicrank': 1}),
#  (376,
#   {'text': 'The war on terror is the latest example of the expansion of sovereign power ',
#    'topic': 'war_terror_has_violence',
#    'topicrank': 41}),
#  (378,
#   {'text': 'Spatial differences and borders are the root cause of all violence—they create spheres of power and domination ',
#    'topic': 'violence_domination_power_hegemony',
#    'topicrank': 3}),
#  (380,
#   {'text': 'The re-entrenching of economic and social inequality is symptomatic of the 1AC’s globalization of Latin America. Latin American economies become dependent on the hegemon eliminating economic sovereignty while social exclusion and the separation from higher and lower classes creates a larger divide. ',
#    'topic': 'poverty_trade_solves_inequality',
#    'topicrank': 33}),
#  (382,
#   {'text': 'Sovereignty is the ultimate biopolitical control of the state ',
#    'topic': 'state_power_security_agency',
#    'topicrank': 12}),
#  (384,
#   {'text': 'Constructing border to establish space is the root cause of the social borders across lines of race, gender, nature, and nations—root cause of exclusion '}),
#  (386,
#   {'text': 'Borders produce a world system that can be exploited for wealth though gunboat diplomacy and neoliberal regimesof trade',
#    'topic': 'world_countries_neoliberal_can',
#    'topicrank': 0}),
#  (388,
#   {'text': 'Language and knowledge production must be investigated first – western approaches misrepresent hiearchal systems of domination ',
#    'topic': 'knowledge_production_black_key',
#    'topicrank': 6}),
#  (390,
#   {'text': 'A framework for debate totalizes discussion and other forms of politics- turns education and locks in current border dialogue',
#    'topic': 'debate_policy_necessary_framework',
#    'topicrank': 2}),
#  (392,
#   {'text': 'Focus on discourse and representations is key in the context of our criticism – threat construction and the securitization of national identities legitimize violent intervention in the name of United States hegemony – critical analysis is necessary.',
#    'topic': 'discourse_aff_our_us',
#    'topicrank': 5}),
#  (394,
#   {'text': 'Complete Negativity is key- only through imagining political praxis can we create change ',
#    'topic': 'can_legal_social_key',
#    'topicrank': 2}),
#  (396,
#   {'text': 'Perm fails – it’s impossible to reconcile bordered and anti-border thinking, and starting from a Western viewpoint dooms the perm and causes cooption',
#    'topic': 'border_fails_perm_borders',
#    'topicrank': 0}),
#  (398,
#   {'text': 'Bringing in other movements fails conflicting ideologies destroys change- Instead a starting point of profane act of “whatever being” can change politics',
#    'topic': 'state_power_federal_can',
#    'topicrank': 17}),
#  (400,
#   {'text': 'The permutation cannot solve; economic interactions are entirely insulated from politicization and the material effects of the plan – questions of territory and societal perceptions permeate economic calculations in the context of Venezuela. ',
#    'topic': 'its_how_from_must',
#    'topicrank': 8}),
#  (402,
#   {'text': 'Their indicts and truth claims are sheltered in the framework of sovereign power- a radical break from the status quo is only seen as utopian due to their epistemic lock in.',
#    'topic': 'need_can_only_from',
#    'topicrank': 4}),
#  (404,
#   {'text': 'The demand for specificity is a western way of knowing used to derail decolonial movements'}),
#  (406,
#   {'text': 'These exclusionary borders help reinforce this epistemology inherent in the us/them dichotomy that leads to the otherization of anyone that is on the “outside”',
#    'topic': 'border_borders_between_which',
#    'topicrank': 40}),
#  (408,
#   {'text': 'Geopolitical binaries are not physical; rather, they serve as psychological structuring mechanisms – the alternate must problematize conventional categorization to open new spaces for classification. '}),
#  (410, {'text': 'Boundaries and borders are human made and not natural'}),
#  (412,
#   {'text': 'Interdependence isn’t enough to stop war and takes years to develop',
#    'topic': 'enough_aren_develop_takes',
#    'topicrank': 0}),
#  (414,
#   {'text': 'Realism is a naïve understanding of the world ',
#    'topic': 'world_our_human_humans',
#    'topicrank': 17}),
#  (416,
#   {'text': 'The attempt at internal order through a well-defined sovereign makes war inevitable—enemies who cannot be made stable must be eliminated',
#    'topic': 'war_inevitable_makes_through',
#    'topicrank': 0}),
#  (418,
#   {'text': 'Deconstruction cannot be confined to one method or the movement will fail'}),
#  (420,
#   {'text': 'The alt makes gender invisible - only the perm solves',
#    'topic': 'solves_perm_only_fails',
#    'topicrank': 4}),
#  (422,
#   {'text': 'Borders are key to social solidarity that solves poverty, equality, and are key to macroeconomic regulation',
#    'topic': 'solves_key_poverty_security',
#    'topicrank': 0}),
#  (424,
#   {'text': 'Modern borders are engines of connectivity that allow for engagement with the other ',
#    'topic': 'can_key_workers_allow',
#    'topicrank': 3}),
#  (426,
#   {'text': 'Even if Borders split up the world artificially they are key to preserving our ontological connection to the world and pre-requisite for political agency ',
#    'topic': 'key_indigenous_necessary_political',
#    'topicrank': 5}),
#  (428,
#   {'text': 'Borders are problematic because the liberal universalism pre-supposes them to be.'}),
#  (430,
#   {'text': 'Even if remittances have declined in recent times, the overall decline is negligible and reflective of the U.S.’s economy – if anything, it proves that a dramatic change will trigger the impact',
#    'topic': 'economy_now_growth_key',
#    'topicrank': 101}),
#  (432,
#   {'text': 'TN-2 visas allow immigrants to come to the U.S. indefinitely and bring their families',
#    'topic': 'immigrants_immigration_legal_status',
#    'topicrank': 191}),
#  (434,
#   {'text': 'Mexican economy benefits more from external remittances',
#    'topic': 'more_needs_from_countries',
#    'topicrank': 4}),
#  (436, {'text': 'Mexican remittances continue to fall'}),
#  (438,
#   {'text': 'Mexican Immigrants sending less money back home from US',
#    'topic': 'us_don_students_want',
#    'topicrank': 31}),
#  (440,
#   {'text': 'Immigration from Mexico is declining now',
#    'topic': 'us_from_immigration_countries',
#    'topicrank': 79}),
#  (442,
#   {'text': 'Failure to prevent immigration-driven population growth precludes sustainable existence in the US ',
#    'topic': 'immigration_us_immigrants_from',
#    'topicrank': 9}),
#  (444,
#   {'text': 'Extra immigration takes away jobs from Americans',
#    'topic': 'immigration_legal_permanent_illegal',
#    'topicrank': 71}),
#  (446,
#   {'text': 'The plan adds to increasing the unskilled workers surplus',
#    'topic': 'plan_benefits_lack_wages',
#    'topicrank': 9}),
#  (448,
#   {'text': 'Increasing low skilled immigration contributes American unemployment',
#    'topic': 'skilled_wages_workers_high',
#    'topicrank': 82}),
#  (450,
#   {'text': 'Mass immigration hurts the environment',
#    'topic': 'environment_solves_destroys_economy',
#    'topicrank': 84}),
#  (452,
#   {'text': 'Immigrants create too large of a population increase\u2028',
#    'topic': 'too_many_much_long',
#    'topicrank': 203}),
#  (454,
#   {'text': 'Senate bill proves Mexico doesn’t like border security',
#    'topic': 'doesn_solve_war_trade',
#    'topicrank': 430}),
#  (456,
#   {'text': 'Plan won’t solve the agriculture industry',
#    'topic': 'can_solve_aff_plan',
#    'topicrank': 4}),
#  (458,
#   {'text': 'Artic conflict escalates to global nuclear war- only cooperation with Canada can prevent war',
#    'topic': 'war_escalates_nuclear_escalate',
#    'topicrank': 101}),
#  (460,
#   {'text': 'Gradual reforms fail and continue political repression',
#    'topic': 'reforms_economic_reform_now',
#    'topicrank': 71}),
#  (462,
#   {'text': 'Cuba is already receiving an influx of food supplies from other countries',
#    'topic': 'china_oil_investing_cuba',
#    'topicrank': 39}),
#  (464,
#   {'text': 'Strong Latin American Relations is key to stop escalation in the region and solve international security and democracy',
#    'topic': 'key_global_stability_international',
#    'topicrank': 43}),
#  (466,
#   {'text': 'The alt is key to other radical reforms ',
#    'topic': 'key_reform_reforms_political',
#    'topicrank': 5}),
#  (468,
#   {'text': 'Corn ethanol does not increase food prices',
#    'topic': 'ethanol_corn_sugarcane_sugar',
#    'topicrank': 49}),
#  (470,
#   {'text': 'Solvency Turn- Changing U.S. export policy results in increase of food prices. '}),
#  (472,
#   {'text': 'NASA scientists conclude there’s no catastrophic warming and CO2 is good for ecosystems',
#    'topic': 'warming_anthropogenic_real_consensus',
#    'topicrank': 150}),
#  (474,
#   {'text': 'Global warming is key to a prosperous human race; history empirically proves',
#    'topic': 'global_key_climate_warming',
#    'topicrank': 0}),
#  (476,
#   {'text': 'Farming is 18% of greenhouse emissions',
#    'topic': 'emissions_co2_biofuels_increases',
#    'topicrank': 78}),
#  (478,
#   {'text': 'Great White Fleet is popular',
#    'topic': 'popular_plan_popularity_now',
#    'topicrank': 16}),
#  (480,
#   {'text': 'Solvency takeout for the advantage, the engines only work on biofuel 50% of the time',
#    'topic': 'interoperability_fill_time_only',
#    'topicrank': 0}),
#  (482,
#   {'text': 'Turn: Biofuels leads to exploited workers, leads to food insecurity and has poor power density-tons of warrants',
#    'topic': 'biofuels_energy_can_algae',
#    'topicrank': 14}),
#  (484,
#   {'text': 'Turn: Oil dependence key to maintaining ties with critical partners in the Middle East.',
#    'topic': 'key_us_oil_sales',
#    'topicrank': 3}),
#  (486, {'text': 'The Great Green Fleet is already in effect'}),
#  (488,
#   {'text': 'Text: The Department of the Navy should in invest in algae ethanol',
#    'topic': 'should_united_states_government',
#    'topicrank': 509}),
#  (490,
#   {'text': 'Chinese economic relations with Venezuela are becoming promising.'}),
#  (492,
#   {'text': 'China solves better than the US in Latin America…',
#    'topic': 'us_china_than_east',
#    'topicrank': 2}),
#  (494,
#   {'text': 'Economic Politics are zero sum',
#    'topic': 'zero_sum_now_china',
#    'topicrank': 5}),
#  (496,
#   {'text': 'China is dependent on Mexico for its supply of oil. Other counties’ investments will destabilize China’s economy. ',
#    'topic': 'economy_russia_oil_its',
#    'topicrank': 2}),
#  (498,
#   {'text': 'Challenging Russia encourages threatens global stability',
#    'topic': 'stability_key_economic_us',
#    'topicrank': 194}),
#  (500,
#   {'text': 'China is interested in using Latin America to expand its economy ',
#    'topic': 'america_latin_its_expanding',
#    'topicrank': 7}),
#  (502,
#   {'text': 'China and Cuba have a strong agricultural relationship involving technology transfer',
#    'topic': 'china_us_key_relationship',
#    'topicrank': 12}),
#  (504, {'text': 'China’s sugar demand is projected to skyrocket'}),
#  (506,
#   {'text': 'Current Cuban sugar industry ventures do not consider the United States',
#    'topic': 'states_united_should_federal',
#    'topicrank': 591}),
#  (508,
#   {'text': 'Sino-Cuban economic relations are resilient. US involvement is by no means necessary. ',
#    'topic': 'russia_us_nato_ukraine',
#    'topicrank': 34}),
#  (510,
#   {'text': 'China can’t make ethanol economically competitive',
#    'topic': 'won_china_us_can',
#    'topicrank': 198}),
#  (512,
#   {'text': 'Text: The United States federal government should enter into prior binding consultation with the Federative Republic of Brazil [over the plan]',
#    'topic': 'should_united_states_government',
#    'topicrank': 119}),
#  (514,
#   {'text': 'Iranian proliferation spills over and leads to Middle Eastern proliferation',
#    'topic': 'nuclear_proliferation_war_causes',
#    'topicrank': 200}),
#  (516,
#   {'text': 'Their only internal link is that taxing PEMEX gives the government resources to fight the drug war---squo solves that ',
#    'topic': 'china_us_plan_war',
#    'topicrank': 8}),
#  (518,
#   {'text': 'No Mexican economic collapse or failed state, cartel violence is getting better but it’s inevitable because of U.S. drug demand ',
#    'topic': 'risk_plan_collapse_key',
#    'topicrank': 16}),
#  (520,
#   {'text': 'Total stalemate on controlling the drug trade makes it inevitable ',
#    'topic': 'inevitable_makes_crisis_creates',
#    'topicrank': 14}),
#  (522,
#   {'text': 'Nieto’s current reform package solves the entire advantage-allows foreign investment',
#    'topic': 'solves_solve_perm_best',
#    'topicrank': 42}),
#  (524,
#   {'text': 'Overt U.S. push for joint ventures derails PEMEX reform-turns the aff',
#    'topic': 'now_turns_must_more',
#    'topicrank': 3}),
#  (526,
#   {'text': 'PEMEX is doing deep water drilling joint ventures now',
#    'topic': 'drilling_offshore_ocs_oil',
#    'topicrank': 89}),
#  (528,
#   {'text': 'Recent discovery of 10 billion barrels of oil means Mexican politicians won’t reform'}),
#  (530,
#   {'text': 'New shallow off-shore production and increased on-shore production solves PEMEX production',
#    'topic': 'increased_solves_production_investment',
#    'topicrank': 0}),
#  (532,
#   {'text': 'Reforms will pass in the squo-Nieto and PRI promises prove',
#    'topic': 'solves_reforms_squo_now',
#    'topicrank': 7}),
#  (534,
#   {'text': 'PRI will get PEMEX reforms passed soon-they’re the key party for passage'}),
#  (536,
#   {'text': 'Even if the PRI isn’t enough- the PAN still supports Nieto’s reforms',
#    'topic': 'plan_obama_reforms_isn',
#    'topicrank': 0}),
#  (538,
#   {'text': 'Mexican President Nieto is pushing Constitutional reforms that would open up the state’s monopoly on oil production to private and foreign investment---the Mexican Congress has to approve it, and it’ll pass now because of support within Nieto’s party, the PRI---that’s Upstream. ',
#    'topic': 'now_state_key_aff',
#    'topicrank': 6}),
#  (540,
#   {'text': 'Lack of reforms won’t collapse PEMEX-gas fills in',
#    'topic': 'don_won_cause_oil',
#    'topicrank': 46}),
#  (542,
#   {'text': 'PEMEX isn’t key to the economy and no collapse-Homex checks',
#    'topic': 'doesn_solve_isn_key',
#    'topicrank': 5}),
#  (544,
#   {'text': 'Irreversible trends guarantee continued Mexican economic growth ',
#    'topic': 'growth_economic_now_economy',
#    'topicrank': 62}),
#  (546,
# ...
#  (1784,
#   {'text': 'Venezuela is key – China protects its power with energy, agriculture, and telecommunications engagement. ',
#    'topic': 'key_economy_security_us',
#    'topicrank': 56}),
#  (1786,
#   {'text': 'China specifically depends on Venezuela for oil. ',
#    'topic': 'oil_dependence_us_saudi',
#    'topicrank': 76}),
#  (1788,
#   {'text': 'China needs Latin American oil – the plan prevents their development. ',
#    'topic': 'oil_drilling_ocean_has',
#    'topicrank': 59}),
#  (1790,
#   {'text': 'China perceives any action as competitive because of distrust and suspicion. ',
#    'topic': 'fear_political_desire_distrust',
#    'topicrank': 7}),
#  (1792,
#   {'text': 'Chinese growth prevents global economic collapse & war over Taiwan.',
#    'topic': 'economic_causes_decline_war',
#    'topicrank': 120}),
#  (1794,
#   {'text': 'Chinese economic growth and competitiveness is key to prevent global economic collapse and nuclear conflict',
#    'topic': 'key_global_stability_international',
#    'topicrank': 53}),
#  (1796,
#   {'text': 'China engagement in Latin America key to growth & CCP legitimacy. ',
#    'topic': 'key_chinese_leadership_tech',
#    'topicrank': 40}),
#  (1798,
#   {'text': 'b. Perceived influence key to regime stability – US involvement threatens it. ',
#    'topic': 'key_oil_stability_us',
#    'topicrank': 0}),
#  (1800,
#   {'text': 'b. Chinese soft power is an existential impact – it controls every scenario for extinction ',
#    'topic': 'extinction_outweighs_existential_impact',
#    'topicrank': 2}),
#  (1802,
#   {'text': 'Chinese soft power is key to Asian stability',
#    'topic': 'stability_key_economic_us',
#    'topicrank': 107}),
#  (1804,
#   {'text': 'Energy insecurity sparks Asian war ',
#    'topic': 'food_insecurity_causes_shortages',
#    'topicrank': 93}),
#  (1806, {'text': 'Energy insecurity in Asia causes great power wars. '}),
#  (1808,
#   {'text': 'Even if growth has slowed, it just provides us a brink. ',
#    'topic': 'now_has_can_us',
#    'topicrank': 4}),
#  (1810,
#   {'text': 'China engagement only effects economic growth – it doesn’t link to your security or political influence impacts. ',
#    'topic': 'doesn_surveillance_isn_because',
#    'topicrank': 19}),
#  (1812,
#   {'text': 'No China threat to Mexico – alt causes',
#    'topic': 'war_us_causes_china',
#    'topicrank': 38}),
#  (1814,
#   {'text': 'US influence is still unchallenged – culture, proximity, and economic relations. ',
#    'topic': 'us_surveillance_relations_violence',
#    'topicrank': 2}),
#  (1816,
#   {'text': 'US & China competing for influence now. ',
#    'topic': 'us_can_relations_key',
#    'topicrank': 8}),
#  (1818,
#   {'text': 'China’s economy is down. ',
#    'topic': 'economy_now_china_us',
#    'topicrank': 11}),
#  (1820,
#   {'text': 'China’s economy is structurally ruined – too many alt causes to growth. ',
#    'topic': 'economy_china_economic_world',
#    'topicrank': 13}),
#  (1822,
#   {'text': 'CCP is resilient and instability impacts are empirically denied. ',
#    'topic': 'empirically_proven_denied_fails',
#    'topicrank': 61}),
#  (1824,
#   {'text': 'China is outcompeting U.S.-Mexican trade in the status quo – future disruption is only going to increase ',
#    'topic': 'trade_relations_us_china',
#    'topicrank': 3}),
#  (1826,
#   {'text': 'Serious corruption fueled by lack of police reform undermines Pemex',
#    'topic': 'police_reform_undermines_reforms',
#    'topicrank': 1}),
#  (1828,
#   {'text': 'Solving corruption key to reform Pemex',
#    'topic': 'key_prevent_economic_global',
#    'topicrank': 57}),
#  (1830,
#   {'text': 'Policymakers in the US are becoming more open to climate change now – poor diplomacy has meant that international climate change policies have failed to be enacted',
#    'topic': 'legislation_bills_more_act',
#    'topicrank': 9}),
#  (1832,
#   {'text': 'Gradually lifting the embargo prevents rapid Cuban democratic shift',
#    'topic': 'embargo_lifting_us_cuba',
#    'topicrank': 96}),
#  (1834,
#   {'text': 'Only an immediate end to the entire embargo solves credibility ',
#    'topic': 'embargo_lifting_us_cuba',
#    'topicrank': 153}),
#  (1836,
#   {'text': 'Party leaders would backlash',
#    'topic': 'backlash_causes_congressional_political',
#    'topicrank': 74}),
#  (1838, {'text': 'Large opposition to further easing of restrictions'}),
#  (1840,
#   {'text': 'Cuban democracy assistance programs are corrupt and opaque – Congress has been very critical of them',
#    'topic': 'congress_plan_cuban_democracy',
#    'topicrank': 0}),
#  (1842,
#   {'text': 'Engaging Cuba on their energy development sparks huge backlash',
#    'topic': 'backlash_causes_congressional_political',
#    'topicrank': 146}),
#  (1844,
#   {'text': 'Congress HATES any cooperation with Cuba over oil drilling – several bills have been brought to sanction companies that even try',
#    'topic': 'law_congress_have_international',
#    'topicrank': 1}),
#  (1846,
#   {'text': 'Cuban foreign aid costs capital',
#    'topic': 'now_high_us_capital',
#    'topicrank': 48}),
#  (1848,
#   {'text': 'Poe is key to getting other Republicans to sign onto immigration reform',
#    'topic': 'republicans_support_democrats_oppose',
#    'topicrank': 130}),
#  (1850,
#   {'text': 'Closing Guantanamo Bay requires a massive input of political capital',
#    'topic': 'guantanamo_bay_us_closing',
#    'topicrank': 5}),
#  (1852,
#   {'text': 'Guantanamo Bay has too much support to be shut down',
#    'topic': 'guantanamo_bay_us_closing',
#    'topicrank': 36}),
#  (1854,
#   {'text': 'Cuba policy changes require tons of political capital and trade off with the rest of Obama’s agenda',
#    'topic': 'obama_cuba_capital_political',
#    'topicrank': 2}),
#  (1856,
#   {'text': 'Environmental concerns are a neg link warrant---Congress is scared of U.S. companies being exposed to liability, and they think the best way to prevent a spill is to stop drilling in the first place'}),
#  (1858,
#   {'text': 'The plan requires Congress---it’s unlike drilling in other areas---proximity to Florida '}),
#  (1860,
#   {'text': 'Rubio wants Cuba on the state sponsor list',
#    'topic': 'cuba_list_terror_china',
#    'topicrank': 5}),
#  (1862,
#   {'text': 'Plan is massively unpopular- costs capital',
#    'topic': 'unpopular_plan_congress_public',
#    'topicrank': 77}),
#  (1864,
#   {'text': 'Economic engagement with Mexico is politically divisive despite supporters'}),
#  (1866, {'text': 'Border security is the House’s primary concern'}),
#  (1868,
#   {'text': 'Aid to Mexico is put on hold due to human rights violations – won’t get approved in committees'}),
#  (1870, {'text': 'Specifically in Latin America it costs capital'}),
#  (1872,
#   {'text': 'Re-negotiating cannabis laws requires political capital',
#    'topic': 'requires_drugs_would_we',
#    'topicrank': 7}),
#  (1874, {'text': 'Human rights and unions lobbies hate the plan'}),
#  (1876,
#   {'text': 'The plan sparks backlash over the process of ratification, and requires Presidential involvement ',
#    'topic': 'plan_congressional_key_trump',
#    'topicrank': 24}),
#  (1878,
#   {'text': 'The plan requires Obama’s involvement in pushing implementing legislation ',
#    'topic': 'obama_executive_congress_can',
#    'topicrank': 38}),
#  (1880,
#   {'text': 'Clean energy investment costs capital',
#    'topic': 'now_high_us_capital',
#    'topicrank': 49}),
#  (1882,
#   {'text': 'Congress hates Venezuela – Snowden scandal.',
#    'topic': 'congress_trump_congressional_plan',
#    'topicrank': 84}),
#  (1884,
#   {'text': 'Political polarization over Venezuela is increasing despite Chavez’s death',
#    'topic': 'chavez_venezuela_death_us',
#    'topicrank': 3}),
#  (1886,
#   {'text': 'Republicans don’t like the plan – they see Venezuela as a security threat.',
#    'topic': 'don_about_voters_care',
#    'topicrank': 71}),
#  (1888,
#   {'text': 'House Republicans support current efforts to push Venezuela out of oil markets – the plan reverses this trend.',
#    'topic': 'republicans_support_democrats_oppose',
#    'topicrank': 71}),
#  (1890,
#   {'text': 'The plan attracts backlash from both Democrats and Republicans – Congress empirically pushes for isolation of Venezuelan oil, not engagement. ',
#    'topic': 'republicans_democrats_plan_immigration',
#    'topicrank': 3}),
#  (1892,
#   {'text': 'Strong opposition to Venezuelan trade – Congress demands embargo',
#    'topic': 'us_relations_economic_embargo',
#    'topicrank': 9}),
#  (1894,
#   {'text': 'Congress is reducing foreign aid to Latin America now – any increase will be a political fight',
#    'topic': 'congress_aid_us_funding',
#    'topicrank': 7}),
#  (1896,
#   {'text': 'The plan costs capital and is a flip flop',
#    'topic': 'plan_now_gop_trump',
#    'topicrank': 24}),
#  (1898,
#   {'text': 'Issue linkage costs capital- NAFTA proves',
#    'topic': 'nafta_us_key_mexican',
#    'topicrank': 64}),
#  (1900,
#   {'text': 'No farm labor shortage – all the aff’s reports are subjective – prefer concrete data',
#    'topic': 'flawed_data_studies_evidence',
#    'topicrank': 105}),
#  (1902,
#   {'text': 'US ag not key – UK food production solves',
#    'topic': 'proves_solves_key_cp',
#    'topicrank': 9}),
#  (1904, {'text': 'Food price impacts exaggerated – experts agree'}),
#  (1906,
#   {'text': 'Food price spikes inevitable – speculation and droughts outweigh production',
#    'topic': 'food_insecurity_causes_shortages',
#    'topicrank': 103}),
#  (1908,
#   {'text': 'US alone can’t resolve – multilateral institutions solve best',
#    'topic': 'can_solve_aff_plan',
#    'topicrank': 205}),
#  (1910,
#   {'text': 'American aid fails to resolve food shortages – the entire process is dominated by self-interest'}),
#  (1912,
#   {'text': 'UK ag industry solves best for environment – proactive initiatives to respond to climate change',
#    'topic': 'climate_change_key_global',
#    'topicrank': 119}),
#  (1914,
#   {'text': 'Any change in food prices causes millions to die; food price death is inevitable',
#    'topic': 'impact_causes_millions_than',
#    'topicrank': 1}),
#  (1916,
#   {'text': 'Alt cause to Ag price spike – Laundry list',
#    'topic': 'laundry_list_economy_bad',
#    'topicrank': 61}),
#  (1918,
#   {'text': 'Climate Change creates high food prices',
#    'topic': 'climate_change_causes_key',
#    'topicrank': 149}),
#  (1920,
#   {'text': 'Alt cause – ONLY speculation and ethanol can explain food price spikes – best economic models',
#    'topic': 'prices_oil_price_spikes',
#    'topicrank': 27}),
#  (1922,
#   {'text': 'Increased international production and crop shift checks high prices – empirics prove',
#    'topic': 'empirics_prove_war_key',
#    'topicrank': 221}),
#  (1924,
#   {'text': 'Brazilian model for development can benefit global ag – efficiency and sustainability',
#    'topic': 'key_energy_development_us',
#    'topicrank': 7}),
#  (1926,
#   {'text': 'Alt Cause: US Soybean decline a result of weather patterns',
#    'topic': 'causes_alt_cause_disease',
#    'topicrank': 12}),
#  (1928,
#   {'text': 'Status Quo Solves Deforestation- Brazil implementing new model of sustainable development',
#    'topic': 'deforestation_cause_warming_extinction',
#    'topicrank': 79}),
#  (1930,
#   {'text': 'Alt Cause to Deforestation- Infrastructure development. ',
#    'topic': 'deforestation_cause_warming_extinction',
#    'topicrank': 20}),
#  (1932,
#   {'text': 'Strong US agricultural system hurts US relations with other countries',
#    'topic': 'us_other_key_china',
#    'topicrank': 12}),
#  (1934,
#   {'text': 'Food Shortages lead to extinction within the century',
#    'topic': 'food_china_insecurity_extinction',
#    'topicrank': 3}),
#  (1936,
#   {'text': 'Aff can’t solve border security – the border patrol sucks',
#    'topic': 'can_solve_aff_immigration',
#    'topicrank': 1}),
#  (1938,
#   {'text': 'Aff can’t solve counterterrorism – internal DHS inefficiencies and redundancy tank solvency',
#    'topic': 'solve_doesn_solves_can',
#    'topicrank': 0}),
#  (1940,
#   {'text': 'Squo solves US-Mexico border terrorism',
#    'topic': 'solves_squo_us_solve',
#    'topicrank': 5}),
#  (1942,
#   {'text': 'Border reform key – ensures security and a starting point for legislation',
#    'topic': 'key_ensure_security_has',
#    'topicrank': 3}),
#  (1944, {'text': 'Unilateral actions towards the border historically fail'}),
#  (1946,
#   {'text': 'Terrorists won’t target the border – your authors are hype',
#    'topic': 'can_terrorists_nuclear_won',
#    'topicrank': 10}),
#  (1948,
#   {'text': 'Low risk of their impact-terrorists would not use the border for entry',
#    'topic': 'informants_students_terrorists_them',
#    'topicrank': 24}),
#  (1950,
#   {'text': 'Multiple hurdles to nuclear terrorism and no impact- their author'}),
#  (1952,
#   {'text': 'Despite policy changes, drug cooperation strong and improving'}),
#  (1954,
#   {'text': 'Drug wars will always fail – squo internal Mexican reforms solve',
#    'topic': 'solves_squo_us_solve',
#    'topicrank': 21}),
#  (1956,
#   {'text': 'Guest worker programs empirically increase illegal immigration',
#    'topic': 'empirically_proven_denied_fails',
#    'topicrank': 240}),
#  (1958,
#   {'text': 'Mexico and US relations high – economically integrated ',
#    'topic': 'us_mexico_key_trade',
#    'topicrank': 21}),
#  (1960,
#   {'text': 'US-Mexican relations are resilient – Interdependent networks',
#    'topic': 'relations_us_now_key',
#    'topicrank': 125}),
#  (1962,
#   {'text': 'US-Mexico relations high-commerce and culture ensure collaboration',
#    'topic': 'relations_us_now_key',
#    'topicrank': 165}),
#  (1964,
#   {'text': 'Relations between US and Mexico high now – security issues take precedent ',
#    'topic': 'relations_us_now_key',
#    'topicrank': 73}),
#  (1966,
#   {'text': 'Continued drug war is unpopular with the public and takes funds away from education (possible impact turn to drug war, or a plan unpopular with public for ptx)',
#    'topic': 'unpopular_plan_congress_public',
#    'topicrank': 18}),
#  (1968,
#   {'text': 'Alt cause- securitized framing of Mexico subsumes relations',
#    'topic': 'relations_solves_federalism_uncooperative',
#    'topicrank': 13}),
#  (1970,
#   {'text': 'Relations low now- security communications issues are an alt cause',
#    'topic': 'relations_high_resilient_now',
#    'topicrank': 14}),
#  (1972,
#   {'text': 'Cooperation has never been stronger – dynamic issues force cooperation'}),
#  (1974,
#   {'text': 'Relations turn—cooperation can only be achieved through heightening security—migration makes it unattainable due to 9/11 paranoia',
#    'topic': 'relations_engagement_us_china',
#    'topicrank': 9}),
#  (1976,
#   {'text': 'Alt causes to relations – immigration, drugs, and embargo',
#    'topic': 'alt_causes_cause_multiple',
#    'topicrank': 240}),
#  (1978,
#   {'text': 'No Latin American democracy – war on drugs props up dictators',
#    'topic': 'american_latin_war_us',
#    'topicrank': 0}),
#  (1980,
#   {'text': 'Alt causes to Latin American instability – Socioeconomic factors and taxation of the external sector cause LA political instability',
#    'topic': 'instability_economic_leads_causes',
#    'topicrank': 6}),
#  (1982, {'text': 'Democratic expansion causes prolif '}),
#  (1984,
#   {'text': 'Economic Instability contributes to LA political instability',
#    'topic': 'economic_instability_causes_crisis',
#    'topicrank': 16}),
#  (1986,
#   {'text': 'No Latin American prolif – regional safeguards and lack of tech',
#    'topic': 'lack_solvency_fails_funding',
#    'topicrank': 97}),
#  (1988,
#   {'text': 'No Venezuelan prolif – laundry list',
#    'topic': 'laundry_list_economy_bad',
#    'topicrank': 29}),
#  (1990,
#   {'text': 'No nuke terror in Latin America – regional institutions detect'}),
#  (1992,
#   {'text': 'Iran is rapidly expanding influence in Venezuela – desire for a bomb and terrorist influence means a massive security threat',
#    'topic': 'nuclear_threat_now_likely',
#    'topicrank': 14}),
#  (1994,
#   {'text': 'Iran will use Latin America as a jumping-off point for attacks against the U.S.',
#    'topic': 'nuclear_war_iran_us',
#    'topicrank': 35}),
#  (1996,
#   {'text': 'Drug trafficking inevitable- US turns a blind eye ',
#    'topic': 'inevitable_key_us_aff',
#    'topicrank': 1}),
#  (1998,
#   {'text': 'Drug policies fail – only increase violence and social instability',
#    'topic': 'violence_women_against_structural',
#    'topicrank': 80}),
#  ...]

# %%
starting_argument = int(question("No Latin American prolif – regional safeguards and lack of tech", "", "", 100)[0]["id"])
ending_argument = int(question("Iran will use Latin America as a jumping-off point for attacks against the U.S.", "", "", 100)[0]["id"])
showpath_any([starting_argument, ending_argument], the_graph=J)
# Out:
# [21417, 14876, 18168, 194590, 9888, 8650, 70257, 13141]
# 1. Latin American globalization is key to investor confidence and productivity<br/><br/>2. Success in the region is key to overall foreign policy— <br/><br/>3. USAID <span style='background-color: #fff59d'>is</span> <span style='background-color: #fff59d'>key</span> <span style='background-color: #fff59d'>to</span> food <span style='background-color: #fff59d'>aid</span> <br/><br/>4. <span style='background-color: #fff59d'>arms</span> trade <span style='background-color: #fff59d'>is</span> <span style='background-color: #fff59d'>key</span> to North <span style='background-color: #fff59d'>American</span> cooperation <br/><br/>5. Cuba increasing <span style='background-color: #fff59d'>trade</span> <span style='background-color: #fff59d'>ties</span> with Brazil <br/><br/>6. <span style='background-color: #fff59d'>Cuba</span> <span style='background-color: #fff59d'>wants</span> relations with the US – <span style='background-color: #fff59d'>embargo</span> <span style='background-color: #fff59d'>blocks</span> it <br/><br/>7. TPA <span style='background-color: #fff59d'>gets</span> <span style='background-color: #fff59d'>other</span> <span style='background-color: #fff59d'>countries</span> <span style='background-color: #fff59d'>on</span> <span style='background-color: #fff59d'>board</span> <br/><br/>8. Iran influence destabilizes <span style='background-color: #fff59d'>Latin</span> <span style='background-color: #fff59d'>America—turns</span> the <span style='background-color: #fff59d'>aff</span>

# %%
for n, v in H.nodes(data=True):
    print(n, v)
# Out:
# 8710 {'text': 'A serially underachieving economy, repeatedly trumped by dynamic Brazil? ', 'topic': 'repeatedly_underachieving_trumped_brazil', 'topicrank': 0}
# 3433 {'text': 'As, the United States moves to reshape the geopolitical terrain of the world, \'Nith hundreds of military bases in 130 countries added to hundreds of installations stretched across its own territorial confines, the vast majority of Americans refuse to admit their nation possesses anything resembling an Empire. Yet U.S. global expansion is far more ambitious than anything pursued or even imagined by previous imperial powers. It might be argued that the "new militarism" is rooted in a "new imperialism" that aspires to nothing short of world domination, a project earlier outlined by its exuberant proponents and given new life by the Bush II presidency, which has set out to remove all vestiges of ideological and material impediments to worldwide corporate power-by every means at its disposal. It is hard to resist the conclusion that the United States, its strong fusion of national exceptionalism, patriotic chauvinism, and neoliberal fundamentalism fully in place, has evolved into something of an outlaw, rogue state--the kind of fearsome entity conjured up by its own incessant propaganda. Celebrations of power, violence, and conquest long associated with warfare inevitably take its architects and practitioners into the dark side of human experience, into a zone marked by unbridled fanaticism and destructive ventures requiring a culture of lies, duplicity, and double standards. Militarism as a tool of global power ultimately leads to a jettisoning of fixed and universal values, the corruption of human purpose, the degradation of those who embrace it, and finally social disintegration. As Chris Hedges writes in liVtzr Is a Force That Gives Us Meaning: "War never creates the society or harmony we desire, especially the harmony we briefly attain during wartime."1 Here the critical observer is entitled to ask whether the staggering costs and consequences of U.S. imperial domination can possibly be worth any of the goals or ideals invoked as their political justification. We seem to have reached a point where U.S. leaders see themselves as uniquely entitled to carry out warfare and imperial agendas simply owing to the country\'s status as the world\'s lone superpower and its preponderance of military force. In the wake of 9/11 and the onset of Bush\'s war against terrorism, the trajectory of U.S. militarism encounters fewer limits in time and space as it becomes amorphous and endless, galvanized by the threat of far-flung enemies.As at the height of the cold war, the power structure embellishes an image of the globe where two apocalyptic forces-good versus evil, civilized versus primitiv~e locked in a batde to the death. U.S. expansionism is thereby justified through its quest, its apparent need, for an increase in both domestic and global power-a quest destined to bring the superpower to work against even its own interestsc Empires across history have disintegrated on the shoals of their boundless elite hubris, accelerated by global overreach, internal decay, and collapse oflegirimacy, and there is little reason to think that Pax Americana will be able to avoid the same fate. While a feverish nationalism might sustain elite domestic legitimacy temporarily, it cannot secure the same kind of popular support internationally, any more than could a United States-managed world economy that sows its own dysfunctions in the form of mounting chaos, poverty. and inequality. To the extent the United States is determined to set itself above the rest of the world, brandishing technologically awesome military power and threatening planetary survival in the process, it winds up subverting its own requirements for international stability and hegemony. In a perpetual struggle to legitimate their actions, American leaders invoke the familiar and trusted, but increasingly hollow, pretext of exporting democracy and human rights. With the eclipse of the Communist threat, U.S. foreign policy followed the path of "humanitarian intervention," cy ...
# 8972 {'text': 'Put simply, having an ally in such a strategically important country trumped the rights of U.S. property owners. ', 'topic': 'ally_rights_trumped_simply', 'topicrank': 0}
# 5077 {'text': '39 In times of war, especially, the claims of any particular state are liable to 40 trump any other claim, to justify the priority of the obligations of citizenship 41 over any obligations to some broader humanity, indeed to legitimize practices 42 of inhumanity (even if under the rubric of just war), to trample over claims 43 about freedom with claims about security, to privilege friend over enemy, and 44 to celebrate one’s own modern self both over all others and over all other 45 forms of subjectivity. ', 'topic': 'especially_liable_practices_justify', 'topicrank': 0}
# 8986 {'text': 'The strategic factor in the bilateral relationship thus trumps other policy concerns. ', 'topic': 'strategic_trumps_thus_relationship', 'topicrank': 0}

# %%
# Out:
# {(0, 493): 0.9345860481262207,
#  (0, 4270): 0.9336660504341125,
#  (0, 338): 0.9322676062583923,
#  (0, 5280): 0.9321309328079224,
#  (0, 366): 0.9293317198753357,
#  (0, 4860): 0.9284900426864624,
#  (0, 3484): 0.9280604124069214,
#  (0, 89): 0.9261342287063599,
#  (0, 4367): 0.9253823161125183,
#  (0, 503): 0.925256073474884,
#  (0, 4315): 0.9241577386856079,
#  (0, 355): 0.9238387942314148,
#  (0, 4395): 0.9236840605735779,
#  (0, 349): 0.9233704805374146,
#  (0, 6762): 0.923163890838623,
#  (0, 4816): 0.9229990243911743,
#  (0, 3023): 0.9227140545845032,
#  (0, 4256): 0.9225206971168518,
#  (0, 502): 0.9224455952644348,
#  (0, 98): 0.9223863482475281,
#  (0, 106): 0.922357976436615,
#  (0, 5907): 0.9223538041114807,
#  (0, 4705): 0.9223498106002808,
#  (0, 813): 0.9222754836082458,
#  (0, 4815): 0.9222575426101685,
#  (0, 5456): 0.9221648573875427,
#  (0, 4042): 0.9221648573875427,
#  (0, 4803): 0.9221494793891907,
#  (0, 54): 0.9221062064170837,
#  (0, 4591): 0.9220341444015503,
#  (0, 4193): 0.9218004941940308,
#  (0, 64): 0.9216164350509644,
#  (0, 4798): 0.9213976263999939,
#  (0, 4727): 0.9213650822639465,
#  (0, 519): 0.9212726950645447,
#  (0, 532): 0.9212095141410828,
#  (0, 6486): 0.9212031364440918,
#  (0, 5473): 0.9211858510971069,
#  (0, 4059): 0.9211856722831726,
#  (0, 566): 0.9206550717353821,
#  (0, 2582): 0.9204155206680298,
#  (0, 2): 0.9202835559844971,
#  (0, 6717): 0.9202006459236145,
#  (0, 298): 0.9201856851577759,
#  (0, 4553): 0.9197691082954407,
#  (0, 4769): 0.9197382926940918,
#  (0, 1): 0.9197093844413757,
#  (0, 4534): 0.919522762298584,
#  (0, 559): 0.9193517565727234,
#  (0, 6966): 0.9192293286323547,
#  (0, 2683): 0.9191656112670898,
#  (0, 3): 0.9188117980957031,
#  (0, 3199): 0.9185856580734253,
#  (0, 4604): 0.9185394048690796,
#  (0, 4397): 0.91853928565979,
#  (0, 4818): 0.9184679388999939,
#  (0, 5194): 0.9183233380317688,
#  (0, 494): 0.9182682037353516,
#  (0, 130): 0.9181709289550781,
#  (0, 572): 0.9179021716117859,
#  (0, 750): 0.9176727533340454,
#  (0, 352): 0.9176382422447205,
#  (0, 6491): 0.917618989944458,
#  (0, 630): 0.9175339341163635,
#  (0, 3196): 0.9175199270248413,
#  (0, 4314): 0.9174814224243164,
#  (0, 2996): 0.9174798727035522,
#  (0, 368): 0.9174366593360901,
#  (0, 159): 0.9172673225402832,
#  (0, 354): 0.9171940684318542,
#  (0, 5957): 0.917080283164978,
#  (0, 842): 0.9169802069664001,
#  (0, 5): 0.9169031977653503,
#  (0, 5056): 0.9168493151664734,
#  (0, 2770): 0.9168464541435242,
#  (0, 410): 0.9168370366096497,
#  (0, 5047): 0.9166477918624878,
#  (0, 169): 0.9165648818016052,
#  (0, 4426): 0.916404664516449,
#  (0, 73): 0.9164016246795654,
#  (0, 589): 0.9161614775657654,
#  (0, 4839): 0.9160254001617432,
#  (0, 7035): 0.9159133434295654,
#  (0, 4813): 0.9158735871315002,
#  (0, 5086): 0.9158515334129333,
#  (0, 544): 0.9157891869544983,
#  (0, 682): 0.9157448410987854,
#  (0, 4812): 0.915702760219574,
#  (0, 6971): 0.9156573414802551,
#  (0, 353): 0.915590763092041,
#  (0, 6433): 0.9154884815216064,
#  (0, 5972): 0.9154835343360901,
#  (0, 5978): 0.9154835343360901,
#  (0, 602): 0.9154642224311829,
#  (0, 513): 0.9154616594314575,
#  (0, 906): 0.9154309034347534,
#  (0, 6663): 0.915401041507721,
#  (0, 100): 0.9153335690498352,
#  (0, 156): 0.915319561958313,
#  (0, 370): 0.9152778387069702,
#  (0, 449): 0.9151889085769653,
#  (0, 4398): 0.9151873588562012,
#  (0, 340): 0.9151471257209778,
#  (0, 6070): 0.9151085019111633,
#  (0, 7029): 0.9151080846786499,
#  (0, 4814): 0.9150498509407043,
#  (0, 556): 0.914962649345398,
#  (0, 2771): 0.9149550199508667,
#  (0, 5069): 0.9148685336112976,
#  (0, 4394): 0.9147043228149414,
#  (0, 638): 0.914665699005127,
#  (0, 4576): 0.9146493077278137,
#  (0, 6): 0.9145868420600891,
#  (0, 6780): 0.9145239591598511,
#  (0, 4232): 0.914499819278717,
#  (0, 816): 0.9144579172134399,
#  (0, 629): 0.9144301414489746,
#  (0, 4525): 0.9142807126045227,
#  (0, 578): 0.914264440536499,
#  (0, 289): 0.9142214059829712,
#  (0, 439): 0.9142001271247864,
#  (0, 5313): 0.9141690135002136,
#  (0, 870): 0.9140690565109253,
#  (0, 4431): 0.9140586853027344,
#  (0, 44): 0.9140069484710693,
#  (0, 585): 0.9139381051063538,
#  (0, 334): 0.9139236807823181,
#  (0, 356): 0.9139115214347839,
#  (0, 1111): 0.9138476252555847,
#  (0, 1324): 0.9138476252555847,
#  (0, 4836): 0.9137771725654602,
#  (0, 443): 0.91375732421875,
#  (0, 49): 0.9137295484542847,
#  (0, 5816): 0.9136585593223572,
#  (0, 4244): 0.9136021137237549,
#  (0, 4804): 0.9135603904724121,
#  (0, 6633): 0.9135368466377258,
#  (0, 141): 0.9135000109672546,
#  (0, 844): 0.9134942293167114,
#  (0, 4286): 0.9134828448295593,
#  (0, 510): 0.9134058356285095,
#  (0, 4618): 0.9133734703063965,
#  (0, 5794): 0.9133633375167847,
#  (0, 210): 0.9133535623550415,
#  (0, 7034): 0.9133152961730957,
#  (0, 582): 0.9132553935050964,
#  (0, 20): 0.9131782650947571,
#  (0, 4412): 0.9131170511245728,
#  (0, 6419): 0.9131162166595459,
#  (0, 5399): 0.9130182862281799,
#  (0, 4400): 0.9129871129989624,
#  (0, 5802): 0.9129775762557983,
#  (0, 464): 0.9129101037979126,
#  (0, 6701): 0.9129090905189514,
#  (0, 4404): 0.9127984046936035,
#  (0, 6826): 0.912773609161377,
#  (0, 6476): 0.9127480387687683,
#  (0, 4840): 0.9126889109611511,
#  (0, 4279): 0.9126587510108948,
#  (0, 2899): 0.9126449823379517,
#  (0, 4038): 0.912619411945343,
#  (0, 5452): 0.9126193523406982,
#  (0, 4061): 0.9125542044639587,
#  (0, 5854): 0.9125213623046875,
#  (0, 438): 0.9125199913978577,
#  (0, 4316): 0.9124718308448792,
#  (0, 6980): 0.9124055504798889,
#  (0, 2662): 0.912344217300415,
#  (0, 6380): 0.912316083908081,
#  (0, 4119): 0.9122195243835449,
#  (0, 6381): 0.9122174382209778,
#  (0, 5066): 0.9121818542480469,
#  (0, 6853): 0.9121401309967041,
#  (0, 521): 0.9121318459510803,
#  (0, 6471): 0.9121257066726685,
#  (0, 3324): 0.912106990814209,
#  (0, 798): 0.9121034145355225,
#  (0, 5912): 0.9120542407035828,
#  (0, 262): 0.9120028018951416,
#  (0, 8): 0.911998450756073,
#  (0, 2769): 0.9119924306869507,
#  (0, 4277): 0.9119837284088135,
#  (0, 680): 0.9119742512702942,
#  (0, 6996): 0.9119606018066406,
#  (0, 7030): 0.911918044090271,
#  (0, 4242): 0.9119016528129578,
#  (0, 16): 0.9118645787239075,
#  (0, 6968): 0.9118510484695435,
#  (0, 596): 0.9118195176124573,
#  (0, 427): 0.911806046962738,
#  (0, 220): 0.9117969274520874,
#  (0, 6782): 0.9117966890335083,
#  (0, 5271): 0.9117591381072998,
#  (0, 369): 0.911727786064148,
#  (0, 3968): 0.911577582359314,
#  (0, 6475): 0.9115233421325684,
#  (0, 830): 0.9114236235618591,
#  (0, 284): 0.9114139080047607,
#  (0, 4419): 0.9113715291023254,
#  (0, 841): 0.911329448223114,
#  (0, 6565): 0.9111875295639038,
#  (0, 272): 0.9111573100090027,
#  (0, 7025): 0.9110928773880005,
#  (0, 462): 0.9110332727432251,
#  (0, 853): 0.9110163450241089,
#  (0, 5148): 0.9109948873519897,
#  (0, 6685): 0.9109939336776733,
#  (0, 894): 0.9109553694725037,
#  (0, 2906): 0.9109151363372803,
#  (0, 6506): 0.9108994603157043,
#  (0, 4862): 0.9108923077583313,
#  (0, 6647): 0.9108771681785583,
#  (0, 4532): 0.9108470678329468,
#  (0, 251): 0.9108455181121826,
#  (0, 834): 0.9108280539512634,
#  (0, 6668): 0.9108253717422485,
#  (0, 23): 0.9108234643936157,
#  (0, 6288): 0.9108114838600159,
#  (0, 818): 0.9108042120933533,
#  (0, 4971): 0.9107515215873718,
#  (0, 361): 0.9107494354248047,
#  (0, 588): 0.9107329249382019,
#  (0, 6482): 0.9106788635253906,
#  (0, 4390): 0.9106096029281616,
#  (0, 5905): 0.9105968475341797,
#  (0, 768): 0.9105204343795776,
#  (0, 3001): 0.9105175733566284,
#  (0, 5916): 0.9105021357536316,
#  (0, 4260): 0.9104577302932739,
#  (0, 837): 0.9104114174842834,
#  (0, 6016): 0.9104090332984924,
#  (0, 114): 0.9103655815124512,
#  (0, 847): 0.9103606343269348,
#  (0, 716): 0.9103282690048218,
#  (0, 6951): 0.910272479057312,
#  (0, 3574): 0.9102523922920227,
#  (0, 458): 0.9102292060852051,
#  (0, 6020): 0.9101196527481079,
#  (0, 4239): 0.910083532333374,
#  (0, 5470): 0.9099258184432983,
#  (0, 4056): 0.9099258184432983,
#  (0, 5089): 0.9098759293556213,
#  (0, 280): 0.9098383784294128,
#  (0, 5242): 0.9097591042518616,
#  (0, 6109): 0.9096851944923401,
#  (0, 535): 0.909667432308197,
#  (0, 5088): 0.909598708152771,
#  (0, 681): 0.9095087647438049,
#  (0, 761): 0.909479558467865,
#  (0, 7023): 0.9094283580780029,
#  (0, 2894): 0.9093319773674011,
#  (0, 278): 0.9093032479286194,
#  (0, 508): 0.9092697501182556,
#  (0, 279): 0.9092526435852051,
#  (0, 10): 0.9092242121696472,
#  (0, 4825): 0.9091876149177551,
#  (0, 290): 0.9090980291366577,
#  (0, 799): 0.9090532064437866,
#  (0, 6783): 0.9090362191200256,
#  (0, 4504): 0.9088754057884216,
#  (0, 3482): 0.9087481498718262,
#  (0, 5993): 0.9087218046188354,
#  (0, 4531): 0.908708930015564,
#  (0, 2697): 0.9087018966674805,
#  (0, 4380): 0.9086935520172119,
#  (0, 461): 0.9086894989013672,
#  (0, 373): 0.9086780548095703,
#  (0, 6198): 0.9086648225784302,
#  (0, 357): 0.908647358417511,
#  (0, 836): 0.9086422324180603,
#  (0, 7061): 0.9085509181022644,
#  (0, 5245): 0.9083552956581116,
#  (0, 211): 0.9083422422409058,
#  (0, 7031): 0.9083362817764282,
#  (0, 893): 0.9082822203636169,
#  (0, 4577): 0.9081742763519287,
#  (0, 68): 0.9081403017044067,
#  (0, 2883): 0.908090353012085,
#  (0, 4034): 0.9080355763435364,
#  (0, 5448): 0.9080354571342468,
#  (0, 6297): 0.9080236554145813,
#  (0, 6632): 0.907993733882904,
#  (0, 6528): 0.9079850316047668,
#  (0, 5097): 0.9079751968383789,
#  (0, 4243): 0.9079750776290894,
#  (0, 6746): 0.9079633951187134,
#  (0, 4771): 0.9078983068466187,
#  (0, 4410): 0.9078502655029297,
#  (0, 4005): 0.9078159928321838,
#  (0, 4183): 0.9077088236808777,
#  (0, 319): 0.9076955318450928,
#  (0, 495): 0.9076806902885437,
#  (0, 4249): 0.9076787233352661,
#  (0, 6461): 0.9076488614082336,
#  (0, 574): 0.9076341986656189,
#  (0, 246): 0.9075104594230652,
#  (0, 6495): 0.9074721932411194,
#  (0, 5776): 0.9074577689170837,
#  (0, 5057): 0.9073781967163086,
#  (0, 7012): 0.9073602557182312,
#  (0, 570): 0.9073370695114136,
#  (0, 6946): 0.9073331356048584,
#  (0, 6062): 0.9073269963264465,
#  (0, 5283): 0.9072768092155457,
#  (0, 6145): 0.9072276949882507,
#  (0, 3197): 0.907221794128418,
#  (0, 171): 0.9071848392486572,
#  (0, 172): 0.9071183800697327,
#  (0, 2974): 0.907102644443512,
#  (0, 6035): 0.9070835709571838,
#  (0, 6807): 0.9070714712142944,
#  (0, 4435): 0.9070109724998474,
#  (0, 6096): 0.9069920182228088,
#  (0, 6711): 0.9069662690162659,
#  (0, 45): 0.906947672367096,
#  (0, 161): 0.9069162607192993,
#  (0, 529): 0.9068564772605896,
#  (0, 506): 0.9068476557731628,
#  (0, 5813): 0.9068278074264526,
#  (0, 6470): 0.9067978262901306,
#  (0, 6134): 0.9067635536193848,
#  (0, 4733): 0.9067413210868835,
#  (0, 6778): 0.9067091345787048,
#  (0, 282): 0.9066818952560425,
#  (0, 4396): 0.9065404534339905,
#  (0, 4393): 0.9065139889717102,
#  (0, 5077): 0.9064890146255493,
#  (0, 6107): 0.9064399600028992,
#  (0, 6046): 0.9062349200248718,
#  (0, 5022): 0.9062330722808838,
#  (0, 6507): 0.9062329530715942,
#  (0, 277): 0.906183660030365,
#  (0, 4291): 0.9061658382415771,
#  (0, 1939): 0.906151294708252,
#  (0, 850): 0.9061467051506042,
#  (0, 884): 0.9061309099197388,
#  (0, 4820): 0.9061055779457092,
#  (0, 483): 0.9060908555984497,
#  (0, 490): 0.9060860872268677,
#  (0, 91): 0.9060850143432617,
#  (0, 452): 0.9060585498809814,
#  (0, 4819): 0.9060333967208862,
#  (0, 6097): 0.9060215353965759,
#  (0, 886): 0.9060213565826416,
#  (0, 4443): 0.9059957265853882,
#  (0, 75): 0.9059819579124451,
#  (0, 4418): 0.9059480428695679,
#  (0, 4884): 0.905942976474762,
#  (0, 543): 0.9059187173843384,
#  (0, 247): 0.9058926701545715,
#  (0, 6450): 0.9058650135993958,
#  (0, 6965): 0.9058627486228943,
#  (0, 209): 0.9058523774147034,
#  (0, 6693): 0.9058042764663696,
#  (0, 5514): 0.905803382396698,
#  (0, 5908): 0.9058017730712891,
#  (0, 590): 0.905739963054657,
#  (0, 4641): 0.905722975730896,
#  (0, 4664): 0.9056977033615112,
#  (0, 6084): 0.9056732058525085,
#  (0, 5876): 0.9056611657142639,
#  (0, 7153): 0.9056519865989685,
#  (0, 5917): 0.9055653214454651,
#  (0, 3529): 0.9055231809616089,
#  (0, 5095): 0.9055185317993164,
#  (0, 6720): 0.9055159091949463,
#  (0, 6277): 0.9054954648017883,
#  (0, 5772): 0.9054454565048218,
#  (0, 4845): 0.9054418206214905,
#  (0, 4806): 0.9054276943206787,
#  (0, 425): 0.9054023027420044,
#  (0, 335): 0.905364990234375,
#  (0, 4967): 0.9053379893302917,
#  (0, 4383): 0.9053187370300293,
#  (0, 808): 0.9053136706352234,
#  (0, 4597): 0.9052514433860779,
#  (0, 6479): 0.9051755666732788,
#  (0, 5048): 0.9051434397697449,
#  (0, 5914): 0.9050877094268799,
#  (0, 512): 0.9050267338752747,
#  (0, 189): 0.9050165414810181,
#  (0, 522): 0.9050029516220093,
#  (0, 6487): 0.9049949645996094,
#  (0, 2890): 0.9048633575439453,
#  (0, 4269): 0.904845118522644,
#  (0, 5287): 0.9046869277954102,
#  (0, 391): 0.9046849608421326,
#  (0, 726): 0.9045752882957458,
#  (0, 77): 0.9045649170875549,
#  (0, 3977): 0.9045441150665283,
#  (0, 1108): 0.9045163989067078,
#  (0, 1321): 0.9045163989067078,
#  (0, 4841): 0.904497504234314,
#  (0, 778): 0.9044670462608337,
#  (0, 714): 0.9044414162635803,
#  (0, 5780): 0.9043367505073547,
#  (0, 5926): 0.9043367505073547,
#  (0, 4282): 0.9042866826057434,
#  (0, 6175): 0.9042742252349854,
#  (0, 527): 0.9041592478752136,
#  (0, 3016): 0.9041547775268555,
#  (0, 6480): 0.9041509032249451,
#  (0, 892): 0.9041171669960022,
#  (0, 3433): 0.9041072726249695,
#  (0, 6057): 0.9040567874908447,
#  (0, 5137): 0.9040155410766602,
#  (0, 4969): 0.9039180278778076,
#  (0, 4800): 0.9038378000259399,
#  (0, 315): 0.9038345217704773,
#  (0, 4471): 0.9037964344024658,
#  (0, 5874): 0.9037726521492004,
#  (0, 6560): 0.9037052989006042,
#  (0, 6099): 0.9036615490913391,
#  (0, 546): 0.9035993814468384,
#  (0, 142): 0.9035906791687012,
#  (0, 6964): 0.9034753441810608,
#  (0, 9713): 0.9034497141838074,
#  (0, 2898): 0.9033946990966797,
#  (0, 6933): 0.9032690525054932,
#  (0, 6716): 0.9032385945320129,
#  (0, 705): 0.9032049179077148,
#  (0, 4241): 0.9031980633735657,
#  (0, 291): 0.9031636118888855,
#  (0, 6975): 0.9031305313110352,
#  (0, 6022): 0.9031205773353577,
#  (0, 3419): 0.9030847549438477,
#  (0, 194): 0.9030815958976746,
#  (0, 631): 0.9030374884605408,
#  (0, 5872): 0.9030284881591797,
#  (0, 912): 0.9030267000198364,
#  (0, 4638): 0.9030232429504395,
#  (0, 6542): 0.9029695987701416,
#  (0, 4826): 0.9028860330581665,
#  (0, 4275): 0.9028111696243286,
#  (0, 109): 0.902760922908783,
#  (0, 694): 0.9027383327484131,
#  (0, 883): 0.9027023911476135,
#  (0, 4487): 0.9027000069618225,
#  (0, 7027): 0.9026616215705872,
#  (0, 4559): 0.9025485515594482,
#  (0, 4428): 0.9025070071220398,
#  (0, 4413): 0.9025062918663025,
#  (0, 5100): 0.9024937748908997,
#  (0, 3169): 0.9024876356124878,
#  (0, 4430): 0.9024764895439148,
#  (0, 5129): 0.9024577736854553,
#  (0, 6385): 0.9024011492729187,
#  (0, 2182): 0.9023881554603577,
#  (0, 6089): 0.9023582935333252,
#  (0, 101): 0.9023481607437134,
#  (0, 6841): 0.9023213386535645,
#  (0, 540): 0.9022579193115234,
#  (0, 163): 0.9022449254989624,
#  (0, 6488): 0.902239203453064,
#  (0, 4842): 0.902233898639679,
#  (0, 409): 0.9022301435470581,
#  (0, 228): 0.9021374583244324,
#  (0, 832): 0.9021309614181519,
#  (0, 6357): 0.9020856618881226,
#  (0, 6775): 0.9020854234695435,
#  (0, 579): 0.9020624756813049,
#  (0, 6285): 0.9020565748214722,
#  (0, 4432): 0.9020461440086365,
#  (0, 829): 0.902040421962738,
#  (0, 3994): 0.9020310640335083,
#  (0, 453): 0.9020204544067383,
#  (0, 917): 0.9018933773040771,
#  (0, 4595): 0.901884913444519,
#  (0, 511): 0.901875376701355,
#  (0, 561): 0.9018424153327942,
#  (0, 6849): 0.9018133282661438,
#  (0, 5507): 0.9018070101737976,
#  (0, 764): 0.9017955660820007,
#  (0, 6893): 0.9017339944839478,
#  (0, 927): 0.9017168879508972,
#  (0, 5228): 0.9016798138618469,
#  (0, 802): 0.9016779065132141,
#  (0, 4076): 0.901598334312439,
#  (0, 551): 0.9015865921974182,
#  (0, 4616): 0.9015435576438904,
#  (0, 1526): 0.9015331268310547,
#  (0, 4986): 0.9014331698417664,
#  (0, 531): 0.9013956189155579,
#  (0, 6014): 0.9013333320617676,
#  (0, 4402): 0.9012954235076904,
#  (0, 3194): 0.9012672901153564,
#  (0, 866): 0.9012588262557983,
#  (0, 692): 0.9012265205383301,
#  (0, 5060): 0.901207447052002,
#  (0, 4294): 0.901176393032074,
#  (0, 707): 0.9011601209640503,
#  (0, 4186): 0.9011586904525757,
#  (0, 6756): 0.9011346101760864,
#  (0, 3979): 0.9010923504829407,
#  (0, 4109): 0.9010658860206604,
#  (0, 900): 0.9009771347045898,
#  (0, 6509): 0.9009623527526855,
#  (0, 6477): 0.9009554386138916,
#  (0, 6839): 0.9009144902229309,
#  (0, 3180): 0.9008559584617615,
#  (0, 2897): 0.9008182287216187,
#  (0, 4254): 0.9007500410079956,
#  (0, 903): 0.9007248878479004,
#  (0, 3188): 0.9007240533828735,
#  (0, 191): 0.9007011651992798,
#  (0, 858): 0.9006686210632324,
#  (0, 5079): 0.9006445407867432,
#  (0, 2887): 0.9006310701370239,
#  (0, 4567): 0.9006206393241882,
#  (0, 5932): 0.9005500674247742,
#  (0, 5052): 0.900489330291748,
#  (0, 4850): 0.9004588723182678,
#  (0, 678): 0.9003909826278687,
#  (0, 4607): 0.9003660678863525,
#  (0, 1446): 0.9002919793128967,
#  (0, 852): 0.9002436995506287,
#  (0, 190): 0.9002419710159302,
#  (0, 685): 0.9001110792160034,
#  (0, 4206): 0.9001023173332214,
#  (0, 5076): 0.9000983834266663,
#  (0, 6512): 0.9000838994979858,
#  (0, 4951): 0.9000575542449951,
#  (0, 565): 0.9000112414360046,
#  (0, 5046): 0.8999471068382263,
#  (0, 4416): 0.899937093257904,
#  (0, 6140): 0.8999341726303101,
#  (0, 885): 0.8999325037002563,
#  (0, 552): 0.8999039530754089,
#  (0, 468): 0.8999038338661194,
#  (0, 533): 0.8998932242393494,
#  (0, 575): 0.8997879028320312,
#  (0, 4972): 0.8997586965560913,
#  (0, 6805): 0.8996966481208801,
#  (0, 5933): 0.8996497392654419,
#  (0, 6011): 0.8996325135231018,
#  (0, 4808): 0.8996310830116272,
#  (0, 3236): 0.899619460105896,
#  (0, 6920): 0.899542510509491,
#  (0, 878): 0.8995362520217896,
#  (0, 657): 0.8995348811149597,
#  (0, 6468): 0.899490475654602,
#  (0, 4520): 0.899486243724823,
#  (0, 320): 0.8994641900062561,
#  (0, 643): 0.8994561433792114,
#  (0, 4598): 0.8994559645652771,
#  (0, 748): 0.8994331955909729,
#  (0, 7787): 0.8993623852729797,
#  (0, 6677): 0.8993494510650635,
#  (0, 645): 0.8993324637413025,
#  (0, 6771): 0.8993289470672607,
#  (0, 90): 0.8992995619773865,
#  (0, 6691): 0.8992982506752014,
#  (0, 6680): 0.8992899656295776,
#  (0, 37): 0.8991364240646362,
#  (0, 898): 0.8990906476974487,
#  (0, 2973): 0.8990176916122437,
#  (0, 5855): 0.8989757895469666,
#  (0, 5934): 0.8989449739456177,
#  (0, 4625): 0.8989212512969971,
#  (0, 5798): 0.8989190459251404,
#  (0, 3627): 0.8989118933677673,
#  (0, 6931): 0.8988886475563049,
#  (0, 4280): 0.8988442420959473,
#  (0, 5330): 0.8988230228424072,
#  (0, 123): 0.8988043665885925,
#  (0, 5892): 0.8987997770309448,
#  (0, 4799): 0.8987873196601868,
#  (0, 4763): 0.8987836837768555,
#  (0, 4526): 0.8987382650375366,
#  (0, 786): 0.898719310760498,
#  (0, 4250): 0.8986879587173462,
#  (0, 6671): 0.8986716270446777,
#  (0, 926): 0.8986441493034363,
#  (0, 6820): 0.8986064791679382,
#  (0, 6056): 0.89859938621521,
#  (0, 4779): 0.8985931873321533,
#  (0, 5444): 0.8985905051231384,
#  (0, 4030): 0.8985905051231384,
#  (0, 2886): 0.8985719680786133,
#  (0, 4512): 0.8985499143600464,
#  (0, 3980): 0.8985326886177063,
#  (0, 5210): 0.8985284566879272,
#  (0, 911): 0.8985254764556885,
#  (0, 3165): 0.89852374792099,
#  (0, 4555): 0.8983790278434753,
#  (0, 6559): 0.8983440399169922,
#  (0, 914): 0.8983422517776489,
#  (0, 4459): 0.8983264565467834,
#  (0, 6713): 0.8982774615287781,
#  (0, 542): 0.8982689380645752,
#  (0, 4068): 0.8982376456260681,
#  (0, 2777): 0.8982265591621399,
#  (0, 592): 0.8981255292892456,
#  (0, 6021): 0.898115873336792,
#  (0, 4757): 0.8980809450149536,
#  (0, 6757): 0.8980754017829895,
#  (0, 3187): 0.8980495929718018,
#  (0, 5396): 0.8979960083961487,
#  (0, 642): 0.8979740142822266,
#  (0, 715): 0.8979623913764954,
#  (0, 769): 0.8979340195655823,
#  (0, 6754): 0.8978769183158875,
#  (0, 4299): 0.8977936506271362,
#  (0, 5884): 0.8977493047714233,
#  (0, 5948): 0.8977472186088562,
#  (0, 5963): 0.8977472186088562,
#  (0, 7152): 0.8977034091949463,
#  (0, 4208): 0.8976985216140747,
#  (0, 358): 0.8976735472679138,
#  (0, 2995): 0.89764803647995,
#  (0, 6263): 0.897629976272583,
#  (0, 350): 0.8976090550422668,
#  (0, 4594): 0.8975882530212402,
#  (0, 4756): 0.8975635766983032,
#  (0, 6025): 0.8975096344947815,
#  (0, 792): 0.8975045680999756,
#  (0, 823): 0.8974816799163818,
#  (0, 399): 0.8974718451499939,
#  (0, 4184): 0.897424578666687,
#  (0, 683): 0.8973900079727173,
#  (0, 2672): 0.8973632454872131,
#  (0, 5254): 0.897301435470581,
#  (0, 3200): 0.8971759676933289,
#  (0, 6356): 0.8970597386360168,
#  (0, 4538): 0.8970407843589783,
#  (0, 6989): 0.8970198631286621,
#  (0, 3087): 0.8969879150390625,
#  (0, 52): 0.8968893885612488,
#  (0, 4439): 0.8968622088432312,
#  (0, 5087): 0.8968583345413208,
#  (0, 4006): 0.8968505859375,
#  (0, 5455): 0.896801769733429,
#  (0, 4041): 0.896801769733429,
#  (0, 6929): 0.8967860341072083,
#  (0, 663): 0.8967423439025879,
#  (0, 4240): 0.8967233896255493,
#  (0, 500): 0.8966980576515198,
#  (0, 675): 0.8966516256332397,
#  (0, 6268): 0.8966298699378967,
#  (0, 6038): 0.8966101408004761,
#  (0, 6643): 0.8966017961502075,
#  (0, 4706): 0.8965957760810852,
#  (0, 6570): 0.8965724110603333,
#  (0, 5094): 0.8965523838996887,
#  (0, 891): 0.8964942693710327,
#  (0, 6334): 0.8964875340461731,
#  (0, 3998): 0.8964511752128601,
#  (0, 2774): 0.8964324593544006,
#  (0, 831): 0.8963645696640015,
#  (0, 725): 0.8963159918785095,
#  (0, 3970): 0.896293580532074,
#  (0, 4025): 0.8962875008583069,
#  (0, 5439): 0.8962873816490173,
#  (0, 4111): 0.8962444067001343,
#  (0, 6187): 0.8962387442588806,
#  (0, 3442): 0.8962297439575195,
#  (0, 12): 0.8962265253067017,
#  (0, 359): 0.8961233496665955,
#  (0, 18): 0.8960118889808655,
#  (0, 4541): 0.8959332704544067,
#  (0, 3021): 0.8959264159202576,
#  (0, 5051): 0.895889937877655,
#  (0, 6814): 0.8958834409713745,
#  (0, 426): 0.8958595395088196,
#  (0, 182): 0.8958444595336914,
#  (0, 4004): 0.8958360552787781,
#  (0, 4446): 0.8958314657211304,
#  (0, 6501): 0.8958066701889038,
#  (0, 3516): 0.8957889676094055,
#  (0, 4391): 0.8957515954971313,
#  (0, 4121): 0.8957281708717346,
#  (0, 4619): 0.8956754803657532,
#  (0, 5930): 0.895653486251831,
#  (0, 5784): 0.895653486251831,
#  (0, 6287): 0.8956108093261719,
#  (0, 662): 0.8955696821212769,
#  (0, 3201): 0.8955476880073547,
#  (0, 6983): 0.8954600691795349,
#  (0, 15): 0.8954247236251831,
#  (0, 4888): 0.8953887820243835,
#  (0, 5081): 0.8953772783279419,
#  (0, 593): 0.895351767539978,
#  (0, 530): 0.8953295350074768,
#  (0, 6492): 0.8953177332878113,
#  (0, 4513): 0.8952796459197998,
#  (0, 600): 0.8952661156654358,
#  (0, 3247): 0.8952239155769348,
#  (0, 4568): 0.8952150344848633,
#  (0, 6121): 0.8951436281204224,
#  (0, 92): 0.8951376080513,
#  (0, 4759): 0.8951281905174255,
#  (0, 6788): 0.895114541053772,
#  (0, 664): 0.8950315713882446,
#  (0, 2888): 0.8950254917144775,
#  (0, 7088): 0.8950241208076477,
#  (0, 851): 0.8950138688087463,
#  (0, 6162): 0.894996702671051,
#  (0, 81): 0.8949522972106934,
#  (0, 6817): 0.8949204683303833,
#  (0, 195): 0.8949198722839355,
#  (0, 4409): 0.8949151635169983,
#  (0, 242): 0.8949062824249268,
#  (0, 5103): 0.8948144316673279,
#  (0, 791): 0.8948013186454773,
#  (0, 347): 0.8945989608764648,
#  (0, 4403): 0.8945736289024353,
#  (0, 5230): 0.8945460319519043,
#  (0, 925): 0.8945300579071045,
#  (0, 5243): 0.8945195078849792,
#  (0, 254): 0.8945040106773376,
#  (0, 5415): 0.894421398639679,
#  (0, 864): 0.8944081664085388,
#  (0, 4311): 0.894402027130127,
#  (0, 520): 0.8943421244621277,
#  (0, 5021): 0.8943355679512024,
#  (0, 336): 0.8942838311195374,
#  (0, 5856): 0.8942838311195374,
#  (0, 6289): 0.8942756056785583,
#  (0, 482): 0.8942487239837646,
#  (0, 5873): 0.8942485451698303,
#  (0, 6291): 0.8941500782966614,
#  (0, 4209): 0.8941126465797424,
#  (0, 2693): 0.8940988779067993,
#  (0, 8075): 0.8940955996513367,
#  (0, 429): 0.8940858840942383,
#  (0, 3004): 0.8940740823745728,
#  (0, 4079): 0.8940697908401489,
#  (0, 2867): 0.8940631747245789,
#  (0, 6777): 0.8939940929412842,
#  (0, 2682): 0.893986701965332,
#  (0, 5885): 0.8939746022224426,
#  (0, 4844): 0.8938380479812622,
#  (0, 904): 0.893796980381012,
#  (0, 6332): 0.8937163352966309,
#  (0, 5988): 0.8937041163444519,
#  (0, 3493): 0.8936637043952942,
#  (0, 4510): 0.8936142921447754,
#  (0, 26): 0.8935333490371704,
#  (0, 41): 0.8935322761535645,
#  (0, 5434): 0.8934327363967896,
#  (0, 4020): 0.8934327363967896,
#  (0, 7624): 0.893395185470581,
#  (0, 8398): 0.8933946490287781,
#  (0, 793): 0.8933895826339722,
#  (0, 4897): 0.8932631611824036,
#  (0, 2988): 0.8932555913925171,
#  (0, 5918): 0.8932477235794067,
#  (0, 2869): 0.8931079506874084,
#  (0, 5244): 0.8929972648620605,
#  (0, 6095): 0.8929956555366516,
#  (0, 674): 0.8929229378700256,
#  (0, 6399): 0.8929018974304199,
#  (0, 3971): 0.8928989171981812,
#  (0, 24): 0.8928765654563904,
#  (0, 6136): 0.8928480744361877,
#  (0, 880): 0.8927357792854309,
#  (0, 496): 0.8927294611930847,
#  (0, 2785): 0.8927252292633057,
#  (0, 4753): 0.8927079439163208,
#  (0, 5017): 0.8926791548728943,
#  (0, 5923): 0.8926662802696228,
#  (0, 6774): 0.8926516175270081,
#  (0, 673): 0.8926492929458618,
#  (0, 6721): 0.8926137089729309,
#  (0, 4767): 0.8925129175186157,
#  (0, 902): 0.8925034999847412,
#  (0, 323): 0.89246666431427,
#  (0, 4276): 0.8924199938774109,
#  (0, 810): 0.8923808336257935,
#  (0, 924): 0.8923726081848145,
#  (0, 2737): 0.8922448754310608,
#  (0, 4821): 0.8921862244606018,
#  (0, 396): 0.8921717405319214,
#  (0, 2900): 0.8920841813087463,
#  (0, 8500): 0.8919959664344788,
#  (0, 6105): 0.8919095993041992,
#  (0, 789): 0.8918088674545288,
#  (0, 6890): 0.8917914032936096,
#  (0, 4444): 0.8917456269264221,
#  (0, 4190): 0.8917362689971924,
#  (0, 5920): 0.8917199969291687,
#  (0, 5883): 0.8916564583778381,
#  (0, 4015): 0.8916419148445129,
#  (0, 27): 0.8915947675704956,
#  (0, 3030): 0.8915848731994629,
#  (0, 6504): 0.8915550112724304,
#  (0, 2875): 0.8914749622344971,
#  (0, 4462): 0.8914695382118225,
#  (0, 250): 0.891440749168396,
#  (0, 5555): 0.8914217352867126,
#  (0, 827): 0.8914127349853516,
#  (0, 2694): 0.8913623690605164,
#  (0, 6682): 0.891348659992218,
#  (0, 6661): 0.891299307346344,
#  (0, 4830): 0.891194224357605,
#  (0, 679): 0.8911669254302979,
#  (0, 360): 0.8911237716674805,
#  (0, 2639): 0.8909671902656555,
#  (0, 7015): 0.8909035325050354,
#  (0, 276): 0.8908888697624207,
#  (0, 2910): 0.8908742070198059,
#  (0, 4424): 0.8908655047416687,
#  (0, 879): 0.8908639550209045,
#  (0, 5431): 0.8908266425132751,
#  (0, 4017): 0.8908265233039856,
#  (0, 80): 0.8907998204231262,
#  (0, 6439): 0.8907577991485596,
#  (0, 5019): 0.8907108306884766,
#  (0, 200): 0.8907015919685364,
#  (0, 5098): 0.8906732797622681,
#  (0, 5602): 0.8906312584877014,
#  (0, 5676): 0.8906312584877014,
#  (0, 5950): 0.8905556797981262,
#  (0, 5965): 0.8905556797981262,
#  (0, 4458): 0.8903998732566833,
#  (0, 4108): 0.8903671503067017,
#  (0, 198): 0.8903295993804932,
#  (0, 4852): 0.8902889490127563,
#  (0, 6763): 0.8902803659439087,
#  (0, 5267): 0.8902517557144165,
#  (0, 895): 0.8902469873428345,
#  (0, 5946): 0.8902105093002319,
#  (0, 5961): 0.8902105093002319,
#  (0, 867): 0.8901655673980713,
#  (0, 488): 0.890117883682251,
#  (0, 515): 0.8900725841522217,
#  (0, 4586): 0.8900123834609985,
#  (0, 25): 0.8898770809173584,
#  (0, 6999): 0.8898627758026123,
#  (0, 5887): 0.8898033499717712,
#  (0, 4557): 0.8897197842597961,
#  (0, 4511): 0.8896005153656006,
#  (0, 6449): 0.8895897269248962,
#  (0, 877): 0.8895231485366821,
#  (0, 4440): 0.889519989490509,
#  (0, 4694): 0.8895171880722046,
#  (0, 862): 0.8894966840744019,
#  (0, 7026): 0.8894296288490295,
#  (0, 6997): 0.8893896341323853,
#  (0, 275): 0.8893827795982361,
#  (0, 3494): 0.8893459439277649,
#  (0, 6702): 0.8893306255340576,
#  (0, 929): 0.889293372631073,
#  (0, 58): 0.8892577290534973,
#  (0, 287): 0.8892479538917542,
#  (0, 268): 0.8891050219535828,
#  (0, 5998): 0.8888954520225525,
#  (0, 2976): 0.8888813853263855,
#  (0, 134): 0.8887938857078552,
#  (0, 3325): 0.8887453079223633,
#  (0, 6797): 0.8887279033660889,
#  (0, 6037): 0.8887228965759277,
#  (0, 6637): 0.8886422514915466,
#  (0, 6426): 0.888573169708252,
#  (0, 5903): 0.8885176181793213,
#  (0, 3492): 0.8884718418121338,
#  (0, 6790): 0.8883248567581177,
#  (0, 4257): 0.8881491422653198,
#  (0, 4762): 0.8880812525749207,
#  (0, 6518): 0.8880484700202942,
#  (0, 70): 0.8879308700561523,
#  (0, 86): 0.8879027366638184,
#  (0, 5790): 0.8878092169761658,
#  (0, 6158): 0.8878077864646912,
#  (0, 105): 0.8877009749412537,
#  (0, 5207): 0.8876006603240967,
#  (0, 528): 0.8874691724777222,
#  (0, 286): 0.8874198198318481,
#  (0, 479): 0.8874163627624512,
#  (0, 2669): 0.8873289227485657,
#  (0, 128): 0.8872308135032654,
#  (0, 4044): 0.8872146606445312,
#  (0, 5458): 0.8872145414352417,
#  (0, 9427): 0.8872140049934387,
#  (0, 4548): 0.8871620297431946,
#  (0, 110): 0.887107789516449,
#  (0, 6986): 0.8870930671691895,
#  (0, 581): 0.8870912790298462,
#  (0, 222): 0.8870893716812134,
#  (0, 430): 0.8870384097099304,
#  (0, 709): 0.8869919776916504,
#  (0, 6178): 0.8869616389274597,
#  (0, 3179): 0.8869464993476868,
#  (0, 670): 0.8869104981422424,
#  (0, 4717): 0.8868036270141602,
#  (0, 7039): 0.8867699503898621,
#  (0, 263): 0.8867409229278564,
#  (0, 747): 0.8867347836494446,
#  (0, 2491): 0.8866890072822571,
#  (0, 6898): 0.8866783976554871,
#  (0, 6665): 0.88665372133255,
#  (0, 624): 0.8866460919380188,
#  (0, 138): 0.8866382241249084,
#  (0, 838): 0.8866376876831055,
#  (0, 6511): 0.8865641355514526,
#  (0, 2881): 0.886542797088623,
#  (0, 93): 0.8864703178405762,
#  (0, 3025): 0.8864350318908691,
#  (0, 267): 0.8863062262535095,
#  (0, 4226): 0.886298418045044,
#  (0, 231): 0.8862720727920532,
#  (0, 6938): 0.8862234950065613,
#  (0, 5184): 0.8860875368118286,
#  (0, 817): 0.8860851526260376,
#  (0, 5875): 0.8860605359077454,
#  (0, 6534): 0.886054277420044,
#  (0, 3539): 0.8860442042350769,
#  (0, 4929): 0.8858917355537415,
#  (0, 5799): 0.8858746290206909,
#  (0, 909): 0.8858668208122253,
#  (0, 5924): 0.8858591914176941,
#  (0, 188): 0.8858490586280823,
#  (0, 4527): 0.8857148289680481,
#  (0, 196): 0.8856215476989746,
#  (0, 6705): 0.8856024742126465,
#  (0, 5729): 0.885427713394165,
#  (0, 5936): 0.8852275013923645,
#  (0, 62): 0.885152280330658,
#  (0, 6987): 0.885049045085907,
#  (0, 421): 0.8849984407424927,
#  (0, 3008): 0.8848933577537537,
#  (0, 557): 0.884819507598877,
#  (0, 7047): 0.8847302198410034,
#  (0, 6371): 0.8846994042396545,
#  (0, 856): 0.8846933245658875,
#  (0, 3198): 0.8846727609634399,
#  (0, 633): 0.8845237493515015,
#  (0, 3534): 0.8844570517539978,
#  (0, 456): 0.8844435214996338,
#  (0, 872): 0.8843783140182495,
#  (0, 4077): 0.8843759298324585,
#  (0, 5689): 0.8843381404876709,
#  (0, 6023): 0.884006679058075,
#  (0, 704): 0.883935809135437,
#  (0, 4994): 0.8835921287536621,
#  (0, 2740): 0.8834736943244934,
#  (0, 387): 0.8833863735198975,
#  (0, 2905): 0.8833649754524231,
#  (0, 400): 0.883201003074646,
#  (0, 5416): 0.8829616904258728,
#  (0, 6802): 0.8829437494277954,
#  (0, 615): 0.8829135894775391,
#  (0, 5943): 0.8828638195991516,
#  (0, 4620): 0.8828104734420776,
#  (0, 5871): 0.8827714323997498,
#  (0, 367): 0.8827372789382935,
#  (0, 3496): 0.8826668858528137,
#  (0, 5061): 0.88245689868927,
#  (0, 576): 0.8824193477630615,
#  (0, 676): 0.882377564907074,
#  (0, 238): 0.882285475730896,
#  (0, 4802): 0.8822820782661438,
#  (0, 4491): 0.8822817802429199,
#  (0, 918): 0.8822119235992432,
#  (0, 6432): 0.8821982741355896,
#  (0, 6575): 0.8821804523468018,
#  (0, 21): 0.8821448087692261,
#  (0, 2667): 0.8821073174476624,
#  (0, 4736): 0.8820637464523315,
#  (0, 2671): 0.8819562792778015,
#  (0, 4603): 0.8818470239639282,
#  (0, 4704): 0.8817621469497681,
#  (0, 4436): 0.8817193508148193,
#  (0, 6978): 0.8816522359848022,
#  (0, 4627): 0.8816410899162292,
#  (0, 4831): 0.881470263004303,
#  (0, 4549): 0.8814593553543091,
#  (0, 545): 0.8814038634300232,
#  (0, 4234): 0.8813971877098083,
#  (0, 332): 0.8813557624816895,
#  (0, 5852): 0.8813556432723999,
#  (0, 4474): 0.8813456296920776,
#  (0, 2692): 0.8813439011573792,
#  (0, 4517): 0.8813377022743225,
#  (0, 3061): 0.8810681104660034,
#  (0, 819): 0.8810193538665771,
#  (0, 4518): 0.8809506297111511,
#  (0, 8220): 0.8807870745658875,
#  (0, 4125): 0.880780041217804,
#  (0, 6186): 0.8807780146598816,
#  (0, 2993): 0.8806954026222229,
#  (0, 6979): 0.8806368708610535,
#  (0, 2975): 0.8805579543113708,
#  (0, 597): 0.880526065826416,
#  (0, 517): 0.8804810643196106,
#  (0, 5139): 0.8804312348365784,
#  (0, 826): 0.8802229166030884,
#  (0, 3119): 0.8801668882369995,
#  (0, 6672): 0.880151093006134,
#  (0, 4473): 0.8800926804542542,
#  (0, 4312): 0.8800321221351624,
#  (0, 876): 0.8799958825111389,
#  (0, 9632): 0.8799681067466736,
#  (0, 4714): 0.8798698782920837,
#  (0, 6840): 0.8798242211341858,
#  (0, 6928): 0.8797085285186768,
#  (0, 157): 0.8796665072441101,
#  (0, 4689): 0.879530131816864,
#  (0, 4300): 0.879518449306488,
#  (1, 2): 0.971584141254425,
#  ...}

# %%
starting_argument = int(question("Evidence that global warming is real which is long and detailed", "", "", 100)[0]["id"])
middle_argument = int(question("Airplanes cause pollution","", "", 100)[0]["id"])
#print(starting_argument, middle_argument, ending_argument)
showpath_any([starting_argument, middle_argument])
# Out:
# [116790, 55806, 32391, 44755, 32295, 221833, 132284, 59445]
# 1. Warming is real and the product of anthropogenic carbon emissions.<br/><br/>2. Continuing consumption and <span style='background-color: #fff59d'>growth</span> <span style='background-color: #fff59d'>kills</span> <span style='background-color: #fff59d'>the</span> <span style='background-color: #fff59d'>warming</span> <br/><br/>3. <span style='background-color: #fff59d'>Warming</span> <span style='background-color: #fff59d'>prevents</span> drought <span style='background-color: #fff59d'>and</span> <span style='background-color: #fff59d'>famine</span> <br/><br/>4. <span style='background-color: #fff59d'>Warming</span> <span style='background-color: #fff59d'>leads</span> <span style='background-color: #fff59d'>to</span> marine life <span style='background-color: #fff59d'>extinction</span> <br/><br/>5. <span style='background-color: #fff59d'>Extinction</span> – <span style='background-color: #fff59d'>oxygen</span> <span style='background-color: #fff59d'>depletion</span> <span style='background-color: #fff59d'>and</span> <span style='background-color: #fff59d'>food</span> <span style='background-color: #fff59d'>chains</span> <br/><br/>6. Economic growth <span style='background-color: #fff59d'>depletes</span> water resources – recent studies <br/><br/>7. <span style='background-color: #fff59d'>Economic</span> <span style='background-color: #fff59d'>development</span> <span style='background-color: #fff59d'>causes</span> <span style='background-color: #fff59d'>resource</span> <span style='background-color: #fff59d'>depletion</span> <br/><br/>8. Air <span style='background-color: #fff59d'>pollution</span> <span style='background-color: #fff59d'>causes</span> <span style='background-color: #fff59d'>extinction</span>

# %%
embeddings.search(f"select evidence_id from txtai where similar('hello') limit 1")[0]['evidence_id']
# Out:
# 50743

# %%
showpath_list([10, 33, 60], strip_punctuation = True)
# Out:
# [1, 2, 4]
# 1. First, there was a separation or break in time - the contrast between a modern now and a traditional, backward past, so that the societies of the Third World were located in another, previous time and their co-presence in modern time was effectively erased (Fabian 1983). <br/><br/>Use of the term modernization is a blanket to cover colonization <br/><br/>Slater 2004 (David, Professor of Social and Political Geography at Loughborough University, “Geopolitics and the Post-colonial: Rethinking North-South Relations”, p 57-58)<br/><br/>Modernization theory provided post-war society in the West, and especially the US, with a temporal and spatial identity, an identity that could only be effectively constructed in a relation of difference with another time and another space. In this sense the will to be modern designated two forms of separation. First, there was a separation or break in time - the contrast between a modern now and a traditional, backward past, so that the societies of the Third World were located in another, previous time and their co-presence in modern time was effectively erased (Fabian 1983). Second, there was a separation in space - a geopolitical distinction made between the modern societies of the West and the 'traditional societies' of Africa, Asia and Latin America. These processes of separation were seen as being accompanied by transformations in science, technology, administration and economy, which were portrayed as opening up the future to limitless advancement and improvement (Adas [ 990, Latour 1993). The second kind of separation which reflected the existence of a geopolitical divide was further accentuated by the emergence of the Cold War, which gave a new kind of conflictual significance to the spatial separation between the modern and traditional spheres of world development. . Sakai (1997), in a discussion of the universal and the particular, Illuminates significant facets of the connection between the modern! non-modern difference and geopolitics. Thus, while we may wish to keep in mind that the modern has always been opposed to its historical precedent, the pre-modern, geopolitically the modern has been contrasted to the non-West, so that a historical condition is translated into a geopolitical one and vice versa. Although the West is particular in itself, it has been constructed as the universal point of reference through which others arc encouraged to recognize themselves as particularities. In the context of post-war modernization theory, the particular universality of the West came to be founded in a process of Americanization, so that as Sakai (1997: 157) puts it, whereas, in the pre-I 940 period the process of modernization had been the approximate equivalent of Europeanization, after the Second World War, modernization theory was deployed in a way that reflected the shifting of the centre of geopolitical gravity from Western Europe to the United States. The emphasis on modernization in the United States can be interpreted as a reflection of a new ethos of national purpose. Emerging at the end of the Second World 'War as the key Western power, there was a sense within the US that its burgeoning power was the result of the combination of its scientific and technological prowess, its military capacity, its democratic and open traditions and its expansive modernity. The US was the world's number one modern nation with a way of life that other less advanced nations would benefit from following and adopting. In its economic, political and cultural spheres, the US was seen as being ahead of other nations, as the nation that could and should offer leadership to the world. Its contemporaneity, rationality, innovation, dynamism, opportunity, mobility and freedom - in a nutshell, its modern being - was a beacon to the world. But there was another factor which helps to explain the focus on modernization in the context of West/non-West encounters. The term 'modernization' would, according to Walt Ro ...

# %%
def question(text, rerank_word = "", rerank_topic = "", limit = 100):
  return embeddings.search(f"select id, text, topic, evidence_id, score from txtai where similar('{text}') and text like '%{rerank_word}%' and topic like '%{rerank_topic}%' limit {limit}")

# %%
starting_argument = int(question("Capitalism protects the environment", "", "", 100)[0]["id"])

ending_argument = int(question("Communism will damage the environment", "", "", 100)[0]["id"])

# %%
starting_argument
# Out:
# 540963

# %%
question("Capitalism protects the environment", "", "", 100)
# Out:
# [{'id': '2736722',
#   'text': 'IS CAPITALISM GOOD FOR THE ENVIRONMENT? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 148178,
#   'score': 0.8689208626747131},
#  {'id': '2071893',
#   'text': "Doesn't capitalism destroy the environment? ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 118460,
#   'score': 0.85222327709198},
#  {'id': '3175460',
#   'text': 'If you want to protect the environment, you should love capitalism. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 166810,
#   'score': 0.8346022367477417},
#  {'id': '4205710',
#   'text': 'Truth be told, capitalism has helped cleanse our planet — improving living standards while protecting the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 213100,
#   'score': 0.8308689594268799},
#  {'id': '2071918',
#   'text': 'WHY CAPITALISM PROTECTS THE ENVIRONMENT What has made this vast improvement in environmental quality possible in the United States? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 118462,
#   'score': 0.8308149576187134},
#  {'id': '3807622',
#   'text': 'Does this mean that capitalism is unavoidably bad for the environment? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 193921,
#   'score': 0.8038803339004517},
#  {'id': '3133304',
#   'text': 'History, statistical data, and countless real-life examples all agree: to protect the environment, embrace capitalism.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 165164,
#   'score': 0.8016663193702698},
#  {'id': '3175510',
#   'text': 'History, statistical data, and countless real-life examples all agree: to protect the environment, embrace capitalism.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 166810,
#   'score': 0.8016663193702698},
#  {'id': '3175459',
#   'text': 'Not only has capitalism lifted more people out of poverty than any system ever implemented in the history of civilization, but in so doing, it has done more to protect the environment than any socialist or communist initiative. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 166810,
#   'score': 0.8001832365989685},
#  {'id': '1716308',
#   'text': "Indeed, we wouldn't even have environmentalists in our midst were it not for capitalism. ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 100540,
#   'score': 0.7940645217895508},
#  {'id': '324012',
#   'text': "Indeed, we wouldn't even have environmentalists in our midst were it not for capitalism. ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 21599,
#   'score': 0.794064462184906},
#  {'id': '639175',
#   'text': 'Capitalism freely appropriates nature, as it organizes the environment and labor for the production of commodities for sale on the market. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41215,
#   'score': 0.7928208112716675},
#  {'id': '324046',
#   'text': 'Capitalism can save more lives threatened by environmental pollution than all the environmental organizations combined.',
#   'topic': 'socialism_socialist_social_capitalism',
#   'evidence_id': 21599,
#   'score': 0.7923184037208557},
#  {'id': '1716342',
#   'text': 'Capitalism can save more lives threatened by environmental pollution than all the environmental organizations combined.',
#   'topic': 'socialism_socialist_social_capitalism',
#   'evidence_id': 100540,
#   'score': 0.7923182249069214},
#  {'id': '658821',
#   'text': 'Capitalism brings three advantages to the environmental task: ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 42272,
#   'score': 0.789282500743866},
#  {'id': '4415980',
#   'text': 'Capitalism profits the powerful, and they are not the ones affected by the oil spills, earthquakes from mining, or the polluted water sources. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 225104,
#   'score': 0.7866396903991699},
#  {'id': '2071905',
#   'text': 'CAPITALISM HARMS THE ENVIRONMENT Today most of us are environmentalists, so the environmental effects of capitalism concern us greatly. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 118461,
#   'score': 0.7857262492179871},
#  {'id': '323211',
#   'text': 'The reason for capitalism’s high economic impact on the environment is to be found in its double character. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 21559,
#   'score': 0.7836652398109436},
#  {'id': '835162',
#   'text': 'The reason for capitalism’s high economic impact on the environment is to be found in its double character. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 52963,
#   'score': 0.7836652398109436},
#  {'id': '658811',
#   'text': 'It is also the case that capitalism makes it easier to deal with environmental problems. ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 42272,
#   'score': 0.7829358577728271},
#  {'id': '2071920',
#   'text': 'The security of personal possessions made possible by the capitalist institution of private-property rights is a key reason why capitalism protects the environment. ',
#   'topic': 'environmental_rights_law_nature',
#   'evidence_id': 118462,
#   'score': 0.7790893912315369},
#  {'id': '3216466',
#   'text': 'Capitalism posits that there is a fundamental separation between humans and the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 168454,
#   'score': 0.7778369784355164},
#  {'id': '640637',
#   'text': 'Capitalism posits that there is a fundamental separation between humans and the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41247,
#   'score': 0.7778369188308716},
#  {'id': '1452419',
#   'text': 'Capitalism posits that there is a fundamental separation between humans and the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 86755,
#   'score': 0.7778369188308716},
#  {'id': '1640807',
#   'text': 'Capitalism posits that there is a fundamental separation between humans and the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 96841,
#   'score': 0.7778369188308716},
#  {'id': '2314647',
#   'text': 'Capitalism posits that there is a fundamental separation between humans and the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 129468,
#   'score': 0.7778369188308716},
#  {'id': '3406398',
#   'text': 'Most people are given to thinking that the profit motive in a capitalist economy can only drive environmental destruction, but I am here to say that the profit motive has been acting as a massive bulwark against the kind of environmental destruction which was seen in the communist nations during the 20th century which far outstripped the damage done to the environment here in the west. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 176364,
#   'score': 0.7776667475700378},
#  {'id': '4573725',
#   'text': 'Advanced capitalism monopolizes control and in so doing so increases detrimental environmental practice which are dysfunctional to the environment. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 233907,
#   'score': 0.777354896068573},
#  {'id': '4573739',
#   'text': 'The environmental harms of capitalism do not simply result from greed and lack of effective environmental regulation or indifference, though these undoubtedly exacerbate the situation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 233909,
#   'score': 0.7766721248626709},
#  {'id': '4374840',
#   'text': 'As a result, when it comes to the environment, capitalism has no limits (Magdoff and Foster, 20] l). ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 223073,
#   'score': 0.7714741826057434},
#  {'id': '2246374',
#   'text': 'Very often, environmental improvements are due to the very capitalism so often blamed for the problems. ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 126037,
#   'score': 0.7671529054641724},
#  {'id': '662708',
#   'text': '” Capitalism and the destruction of the environment are inextricably linked, to the extent that it is becoming increasingly apparent that saving the environment is dependent on the destruction of capitalism. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 42461,
#   'score': 0.7659314870834351},
#  {'id': '4313279',
#   'text': 'Global capitalism is not only creating climate change but bringing about the extinction of millions of animal and plant species. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 218994,
#   'score': 0.7557125687599182},
#  {'id': '809721',
#   'text': 'Nevertheless, the extreme dangers that capitalism inherently poses to the environment are often inadequately understood, giving rise to the belief that it is possible to create a new “natural capitalism” or “climate capitalism” in which the system is turned from being the enemy of the environment into its savior.1 ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 51313,
#   'score': 0.7556988000869751},
#  {'id': '4573704',
#   'text': "I appreciated the flood of critical scholarship that accounted for capitalism's environmental depredations, but after a certain point, I wasn't learning anything that most of us didn't already know: Capitalism is bad news for the birds and bees, the water, the soil, and pretty much all living creatures on the planet. ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 233905,
#   'score': 0.7543931007385254},
#  {'id': '3339140',
#   'text': 'Capitalism vs. Nature? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 173636,
#   'score': 0.7540620565414429},
#  {'id': '1184215',
#   'text': 'Capitalism vs. Nature? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 72163,
#   'score': 0.7540618777275085},
#  {'id': '2777939',
#   'text': 'Capitalism vs. Nature? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 150083,
#   'score': 0.7540616989135742},
#  {'id': '4372297',
#   'text': 'Capitalism did not ignore environmental risk; it made it the central problem of its survival. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 222923,
#   'score': 0.7493996024131775},
#  {'id': '2071908',
#   'text': 'The record clearly shows environmental conditions are improving in every capitalist country in the world and deteriorating only in noncapitalist countries.36 ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 118461,
#   'score': 0.7479029893875122},
#  {'id': '2759349',
#   'text': 'Only through capitalism can we have a realistic expectation of a cleaner Earth. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 149199,
#   'score': 0.7437839508056641},
#  {'id': '2794820',
#   'text': 'Only through capitalism can we have a realistic expectation of a cleaner Earth. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 150802,
#   'score': 0.7437835931777954},
#  {'id': '640421',
#   'text': '“Capitalism is incapable of regulating its social metabolism with nature in an environmentally sustainable manner. Its very operations violate the laws of restitution and metabolic restoration. The solution to each environmental problem generates new environmental problems (while often not curtailing the old ones). One crisis follows another, in an endless succession of failure, stemming from the internal contradictions of the system”. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41245,
#   'score': 0.743590235710144},
#  {'id': '1452494',
#   'text': '“Capitalism is incapable of regulating its social metabolism with nature in an environmentally sustainable manner. Its very operations violate the laws of restitution and metabolic restoration. The solution to each environmental problem generates new environmental problems (while often not curtailing the old ones). One crisis follows another, in an endless succession of failure, stemming from the internal contradictions of the system”. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 86758,
#   'score': 0.743590235710144},
#  {'id': '2314417',
#   'text': '“Capitalism is incapable of regulating its social metabolism with nature in an environmentally sustainable manner. Its very operations violate the laws of restitution and metabolic restoration. The solution to each environmental problem generates new environmental problems (while often not curtailing the old ones). One crisis follows another, in an endless succession of failure, stemming from the internal contradictions of the system”. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 129466,
#   'score': 0.743590235710144},
#  {'id': '3216640',
#   'text': '“Capitalism is incapable of regulating its social metabolism with nature in an environmentally sustainable manner. Its very operations violate the laws of restitution and metabolic restoration. The solution to each environmental problem generates new environmental problems (while often not curtailing the old ones). One crisis follows another, in an endless succession of failure, stemming from the internal contradictions of the system”. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 168458,
#   'score': 0.743590235710144},
#  {'id': '4462433',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis, it is difficult to imagine that the environmental catastrophe can be resolved within the capitalist system given capital’s implacable impulse to accumulate and its accelerated commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 227851,
#   'score': 0.7429004907608032},
#  {'id': '3544422',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis,\xa0it is difficult to\xa0imagine that the environmental catastrophe can be\xa0resolved within\xa0the\xa0capitalist system given\xa0capital’s implacable impulse to accumulate and\xa0its accelerated\xa0commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 182440,
#   'score': 0.7429003715515137},
#  {'id': '3822139',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis, it is difficult to imagine that the environmental catastrophe can be resolved within the capitalist system given capital’s implacable impulse to accumulate and its accelerated commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 194468,
#   'score': 0.7429003715515137},
#  {'id': '4025574',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis, it is difficult to imagine that the environmental catastrophe can be resolved within the capitalist system given capital’s implacable impulse to accumulate and its accelerated commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 203707,
#   'score': 0.7429003715515137},
#  {'id': '4052753',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis, it is difficult to imagine that the environmental catastrophe can be resolved within the capitalist system given capital’s implacable impulse to accumulate and its accelerated commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 205126,
#   'score': 0.7429003715515137},
#  {'id': '3586308',
#   'text': 'While capitalism cannot be held solely responsible for the ecological crisis, it is difficult to imagine that the environmental catastrophe can be resolved within the capitalist system given capital’s implacable impulse to accumulate and its accelerated commodification of nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 184302,
#   'score': 0.7429003119468689},
#  {'id': '658844',
#   'text': 'But they can regulate firms, and so when firms are producing wealth and people decide that the distribution of wealth ought to be made to accord to an environmental ethic, capitalism makes that possible.',
#   'topic': 'environmental_rights_law_nature',
#   'evidence_id': 42272,
#   'score': 0.7424387335777283},
#  {'id': '878612',
#   'text': 'Capitalism is not interested in carrying the environmental costs unless it must to compete effectively: “While governments and civil society will need to be part of the solution to these challenges, ultimately it will be companies and investors that will mobilize the capital needed to overcome them.” ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 55402,
#   'score': 0.7423389554023743},
#  {'id': '4412848',
#   'text': 'Capitalism has prospered for centuries by exploiting nature, either as an “inexhaustible” supply of resources to produce commodities, or as a waste dump. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 224942,
#   'score': 0.7422513961791992},
#  {'id': '4279522',
#   'text': 'A capitalist does not make a profit simply by exploiting workers—he also makes profit by polluting without paying, benefiting from the unpaid work of subsistence farmers and women, and appropriating the free work of nature (fossil fuels or ecosystem services) that do not belong to him (Moore 2015). ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 217058,
#   'score': 0.7416427135467529},
#  {'id': '3405456',
#   'text': 'In this paper, I argue that capitalism and long-term environmental sustainability are incompatible. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 176327,
#   'score': 0.7387816905975342},
#  {'id': '878385',
#   'text': 'I would like to start by pointing to the seriousness of our current environmental problem and then turn to the question of how this relates to capitalism. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 55397,
#   'score': 0.7382454872131348},
#  {'id': '3404250',
#   'text': 'Thus, we agree with others that bringing the question of capitalism to the forefront of social-environmental analysis, as opposed to assuming capitalism’s naturalness or immutability, is crucial for explaining environmental harms, shedding light on unsustainable solutions to the environmental crisis, and locating more sustainable social futures [145]. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 176282,
#   'score': 0.7347437739372253},
#  {'id': '639918',
#   'text': 'For several hundred years, capitalism has been the global hegemonic economic system, influencing human interactions with nature. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41234,
#   'score': 0.734512984752655},
#  {'id': '4313662',
#   'text': 'In this paper, we argued that capitalism is not only much more robust than presumed by its critics, but moreover features promising capabilities with regard to solving the environmental crisis. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 219011,
#   'score': 0.7325661778450012},
#  {'id': '4205626',
#   'text': 'In this paper, we argued that capitalism is not only much more robust than presumed by its critics, but moreover features promising capabilities with regard to solving the environmental crisis.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 213095,
#   'score': 0.7325659394264221},
#  {'id': '3821197',
#   'text': 'Capitalism, it is clear, cannot solve the environmental crises it is causing.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 194445,
#   'score': 0.7320978045463562},
#  {'id': '4673526',
#   'text': 'Capitalism is the only system through which competition enables both the economy and the environment to thrive. ',
#   'topic': 'capitalism_capitalist_its_has',
#   'evidence_id': 239341,
#   'score': 0.7312684655189514},
#  {'id': '809720',
#   'text': 'It is no secret today that we are facing a planetary environmental emergency, endangering most species on the planet, including our own, and that this impending catastrophe has its roots in the capitalist economic system. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 51313,
#   'score': 0.7308611869812012},
#  {'id': '2759319',
#   'text': 'In fact, not only can capitalism and environmentalism co-exist, but only with free market capitalism can the environment ever hope to be clean. ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 149199,
#   'score': 0.730431318283081},
#  {'id': '2794790',
#   'text': 'In fact, not only can capitalism and environmentalism co-exist, but only with free market capitalism can the environment ever hope to be clean. ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 150802,
#   'score': 0.730431318283081},
#  {'id': '3048548',
#   'text': 'Without the intervention of non-market entities such as the state, international organizations and social forces, capitalism as an economic system simply will not safeguard our planet.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 161813,
#   'score': 0.7297407388687134},
#  {'id': '3808271',
#   'text': 'Without the intervention of non-market entities such as the state, international organizations and social forces, capitalism as an economic system simply will not safeguard our planet.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 193931,
#   'score': 0.7297407388687134},
#  {'id': '4379682',
#   'text': 'Capitalism is not only incapable of responding adequately to the environmental crisis, it is the very cause of the crisis and can only make matters worse. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 223201,
#   'score': 0.729246199131012},
#  {'id': '3807759',
#   'text': 'Capitalism isn’t just “bad at” fighting climate change. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 193922,
#   'score': 0.7289623022079468},
#  {'id': '3823237',
#   'text': 'Capitalism might thereby be provided with the chance to reduce its ecological exploitation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 194497,
#   'score': 0.7276181578636169},
#  {'id': '4214568',
#   'text': 'Capitalism might thereby be provided with the chance to reduce its ecological exploitation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 213503,
#   'score': 0.7276181578636169},
#  {'id': '803509',
#   'text': 'A mutually reinforcing set of forces associated with today’s capitalism combines to yield economic activity inimical to environmental sustainability. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 50875,
#   'score': 0.7270199656486511},
#  {'id': '804075',
#   'text': 'Mark Hertsgaard in Earth Odyssey addresses this issue well: “The profit motive is what makes capitalism go, but it is so basic to the working of the system that it tends to override other social goals. . . . In theory, governments are supposed to police corporate greed, channeling it . . . away from the corner-cutting that threatens public health and safety. But regulation is an iffy thing. Corporations are constantly pressuring governments to relax environmental regulations if not eliminate them altogether. This pressure is often supplemented by bribery— most commonly, the legal bribery known as campaign contributions, which has turned so many politicians in the United States into spineless corporate supplicants unwilling to bite the hands that feed them. . . . Capitalism needs and promotes ceaseless expansion, yet the evidence that human activity is already overwhelming the earth’s ecosystems is all around us.”40 Also overwhelmed is the capacity of environmental efforts to cope.',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 50906,
#   'score': 0.7264366745948792},
#  {'id': '2071907',
#   'text': 'One way to judge the impact of capitalism on the environment is to compare the environmental records of capitalist countries with those of countries with precapitalist, socialist, or communist economies.35 ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 118461,
#   'score': 0.725898027420044},
#  {'id': '658834',
#   'text': 'Environmental policies in capitalist systems will vary greatly – from the inconsequential through the prudent to the loony – but they will scarcely exist at all in non-capitalist ones. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 42272,
#   'score': 0.7240858674049377},
#  {'id': '641238',
#   'text': 'Capitalism is inherently anti-ecological as it systematically subordinates nature in its pursuit of endless accumulation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41257,
#   'score': 0.7237319946289062},
#  {'id': '1452939',
#   'text': 'Capitalism is inherently anti-ecological as it systematically subordinates nature in its pursuit of endless accumulation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 86767,
#   'score': 0.7237319946289062},
#  {'id': '2315326',
#   'text': 'Capitalism is inherently anti-ecological as it systematically subordinates nature in its pursuit of endless accumulation. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 129479,
#   'score': 0.7237319946289062},
#  {'id': '2673040',
#   'text': 'But the natural world isn’t the only thing that is commodified by capitalism. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 145107,
#   'score': 0.7222086191177368},
#  {'id': '658832',
#   'text': 'The prosperity induced by capitalism produces of necessity an environmental movement. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 42272,
#   'score': 0.722206711769104},
#  {'id': '3126875',
#   'text': 'What about loss of habitat for the wild animals due to deforestation, intensive agriculture, polar ice melting, oceans polluting… all these things that capitalism is responsible for… where does it stop? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 164901,
#   'score': 0.721699595451355},
#  {'id': '4487477',
#   'text': 'Given that a capitalist economy is predicated on the constant pursuit of profit and expansion, its operations have "direct implications for natural resource extraction," the generation of pollution, and the overall state of environmental conditions (Gould et al. 2004: 297). ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 229188,
#   'score': 0.7207992672920227},
#  {'id': '3939909',
#   'text': 'While it is conventional to think of capitalism and environmentalism as opposing each other for economic expansion to continue, in corrections they seem to co-exist happily. ',
#   'topic': 'environmental_growth_economic_environment',
#   'evidence_id': 199706,
#   'score': 0.7207015752792358},
#  {'id': '323085',
#   'text': 'It becomes rather clear from the preceding analysis and an increasing number of studies that capitalism, as a specific mode of production, tends to undermine the most basic conditions of ecological sustainability, jeopardizing thus the survival of human beings and of the capitalist system itself [14,15,43,44]. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 21550,
#   'score': 0.7204558849334717},
#  {'id': '4372268',
#   'text': 'It is no secret that capitalism, guided by its growth imperative, is organized to control, process and consume the natural resources of the planet, hence its qualification as “The Worldeater.” ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 222920,
#   'score': 0.7201038599014282},
#  {'id': '658819',
#   'text': 'It is not that capitalists believe in the environment or have a wish to improve the world. ',
#   'topic': 'environmental_have_environment_environmentalists',
#   'evidence_id': 42272,
#   'score': 0.7197079658508301},
#  {'id': '4162299',
#   'text': 'As a result of its destructive production methods, capitalism releases millions of tons of sulphur dioxide into the atmosphere, increases the level of radioactivity in the environment saturates the land with industrial chemicals, creates deserts, pollutes the rivers and seas. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 210618,
#   'score': 0.7192045450210571},
#  {'id': '323117',
#   'text': "This essence of capitalism is one reason why capitalism creates environmental problems: while the majority of the world's people have a material interest in maintaining a healthy planet, the small capitalist ruling class is not accountable to this majority, except in the indirect sense that the ruling class seeks to co-opt the demands of the majority in order to maintain the capitalist system. ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 21552,
#   'score': 0.7186794281005859},
#  {'id': '835149',
#   'text': "This essence of capitalism is one reason why capitalism creates environmental problems: while the majority of the world's people have a material interest in maintaining a healthy planet, the small capitalist ruling class is not accountable to this majority, except in the indirect sense that the ruling class seeks to co-opt the demands of the majority in order to maintain the capitalist system. ",
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 52962,
#   'score': 0.7186791896820068},
#  {'id': '3404757',
#   'text': 'This book concentrates on the way that environmental issues are socially constructed under capitalism because, in general, little consideration has been given to the impact of capitalist development on the environment in any of the perspectives discussed. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 176301,
#   'score': 0.7184301614761353},
#  {'id': '4252123',
#   'text': 'This link between environmental protection and economic development sustains an anthropocentric bias in policy, and opens the way to ‘green capitalist’ policies based on a market economy, while closing the door on no-growth approaches that recognise the environmental harm that capitalism’s endless search for growth and profit brings. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 215646,
#   'score': 0.7164120078086853},
#  {'id': '4372288',
#   'text': 'In effect, while “green capitalist” approaches to the environment have myriad evident weaknesses impeding their ability to address environmental crisis, they perfectly package environmental concern in terms friendly to the environmentally destructive profit-and-growth priorities of firms and states within the CWS. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 222922,
#   'score': 0.7162660956382751},
#  {'id': '642505',
#   'text': 'Capitalism, in turn, is at the heart of the dramatic ecological changes and crises unleashed in the last two centuries (O’Connor 1998; Foster 2007; Kovel 2002; Burkett 2006).6 ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 41302,
#   'score': 0.7161953449249268},
#  {'id': '807773',
#   'text': 'Capitalism, in turn, is at the heart of the dramatic ecological changes and crises unleashed in the last two centuries (O’Connor 1998; Foster 2007; Kovel 2002; Burkett 2006).6 ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 51109,
#   'score': 0.7161949276924133},
#  {'id': '460362',
#   'text': 'The uncontrolled growth of capitalism now threatens the sustainability of the global ecosystem and global society. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 30597,
#   'score': 0.7154268026351929},
#  {'id': '599518',
#   'text': 'Precisely because capitalism keeps inventing new ways to muck up the planet, the environmental movement--or at least large chunks of it--is constantly engaged in challenging the right of corporations to make money by whatever eco-destructive means are most profitable. ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 38973,
#   'score': 0.7154034972190857},
#  {'id': '1408879',
#   'text': 'Is ecological moder nisation a true way out of the contradictions of capitalism? ',
#   'topic': 'capitalism_ecological_environmental_capitalist',
#   'evidence_id': 84123,
#   'score': 0.7144374847412109},
#  {'id': '4162287',
#   'text': 'In capitalism, when we view the natural environment, we not only see land, seas, forests, river valleys and deserts as spectacular and beautiful landscapes, but we are also aware that they contain resources such as coal, oil, natural gas, various metals such as iron ore, copper, tin and many other materials. ',
#   'topic': 'resources_resource_natural_more',
#   'evidence_id': 210618,
#   'score': 0.7142115831375122}]

# %%
showpath(starting_argument, ending_argument)
# Out:
# [406, 194, 465, 65, 184]
# 1. Borders help constitute the way we conceive the world. <br/><br/>These exclusionary borders help reinforce this epistemology inherent in the us/them dichotomy that leads to the otherization of anyone that is on the “outside”<br/><br/>Sanchez and Sholar ’12 [December 2012, Peter, PhD Loyola University Chicago, and Megan, PhD Loyola University Chicago, “Power and Principle: A New US Policy for Latin America”, http://www.ijhssnet.com/journals/Vol_2_No_23_December_2012/3.pdf]<br/><br/>We can ﬁrst observe that borders help fulﬁl epistemological conditions. Borders produce particular conditions for understanding ‘reality’. We who¶ are inside the border are also expected to possess greater knowledge of insiders than of outsiders, which in turn reduces uncertainties regarding our common knowledge on the inside. The border is frequently a bulwark sustaining commonly agreed measures of reality (such as national-currency measures for inﬂation or relative welfare). The border slices the world up into different pieces of reality that we cannot know equally well. That increases as well the plausibility of any assertion regarding the circumstances, gains or losses within our border. Hence, other things being equal, borders help promote the idea that there are fewer uncertainties in communications between insiders by comparison with communications with those on the outside. This leads to an assumption that we will be able to agree on the terms used to evaluate changes and preferences – even the order of priorities, which is a pre-condition of political decisions. Put in a nutshell, the border provides conditions for greater certainty and agreement for those within it. Thompson also makes explicit an ontological claim for the border/boundary which is implicit in post-structuralism’s prioritisation of dif- ferences as against commonalities: namely, that ‘...borders exist “before” entities ...’ – that is to say, borders are ontologically prior to speciﬁc enti- ties. Borders help constitute the way we conceive the world. This can be demonstrated, inter alia, on the basis of the epistemological claims above. For those epistemological consequences of boundaries provide key onto- logical pre-conditions for the continuity of the given social particular as an integrated entity; and hence also for its identity.14 The ‘fact’ of the border helps produce shared understandings of the identities of particulars, both internal and external to the particular itself. This includes understandings of internal variations and sub-categories (constituencies, classes ... ) between insiders/members of the given social particular. The self-identities of mem- bers and sub-categories are grounded in, and thus far validated, by seeing those particulars in relation to each other.15 Likewise, the boundary sustains any determination of the collectivity (the ‘nation’, or whatever it may be) whose interests may be the basis for decisions and actions on its behalf. This, as Rokkan noted,16 is especially signiﬁcant in democratic collectivities, where a large self-aware demos is postulated as the ground for decisions that need to accord in some way with the preference of an indeterminable category, the ordinary mass of the people. The above ontological effects of borders yield yet further consequences. For borders provide pre-conditions for determinations of the situation of insiders relative to outsiders: claims regarding presumed and/or potential different conditions (be it better or worse) for insiders than for outsiders.17 The same could be said of any impression of greater/lesser (or poten- tially greater/lesser) welfare than outsiders. Only with these kinds of claims and impressions in place, can an additional, politically important category of knowledge have meaning: assertions about potential improvements or¶ deteriorations in conditions for the inside.18 If the existence of the subjects who experience comparative well-being were not given, we would not ﬁnd meaning in  ...

# %%
graph.centrality().items() ##

# %%
dir(graph)

# %%
graph.louvain()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import igraph as ig

# %% [markdown]
# This shows how text about a `famous squirrel` and the `Red Sox winning the world series` are connected. Notice how the first match pivots to a node about a squirrel running on the field during a baseball game. From there, it's a relatively logical path to the end node.
#
# This is reminiscent of the game "six degrees of Kevin Bacon". Try running `showpath` with calls to `random.randint(0, len(rows) - 1)`, it's oddly addicting. This is a fun way to explore the interconnectivity of a dataset.

# %%
igraph_graph = ig.Graph.from_networkx(graph.backend)

# %%
def score_with_keyword_number(query):
    new_sorted_list = []
    list_of_results = question(query)
    for row in list_of_results:
        returned_text = row["text"]
        length_of_text = len(returned_text)
        matching_words = [i for i in query.split() if i in returned_text.split()]
        row["matching_words_percentage"] = len(matching_words) / length_of_text
    return list_of_results
    #sorted_by_matching_words = [x for _, x in sorted(zip(list_of_results, new_sorted_list))]

        
sorted_question = sorted(score_with_keyword_number("Education Policy is good"), key=lambda d: d['matching_words_percentage'], reverse = True)
sorted_question

# %%
layout = igraph_graph.layout_umap(epochs = 50)

ig.plot(igraph_graph, target='myfile.pdf',vertex_size=5, edge_width = igraph_graph.es["weight"])

# %%
dir(layout)

# %%
vids = igraph_graph.random_walk(0, 7)

# %%
vids

# %%
igraph_graph.pagerank()
